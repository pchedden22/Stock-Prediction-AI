# %%
import os
import time
import requests
import pandas as pd
import numpy as np

class StockDataHandler:
    def __init__(self, tickers, api_key, outputsize="full", cache_dir="cached_data"):
        self.tickers = tickers
        self.api_key = api_key
        self.outputsize = outputsize  # Use "full" to get long-term data
        self.cache_dir = cache_dir
        os.makedirs(cache_dir, exist_ok=True)  # Ensure cache directory exists
        self.data = {}

    def fetch_data(self):
        """Fetch and cache 10 years of stock data from Alpha Vantage."""
        base_url = "https://www.alphavantage.co/query"
    
        for ticker in self.tickers:
            cache_file = os.path.join(self.cache_dir, f"{ticker}.csv")
    
            # ✅ **Check Cache First**
            if os.path.exists(cache_file):
                print(f"📂 Loading cached data for {ticker}...")
                df = pd.read_csv(cache_file, index_col=0, parse_dates=True).squeeze("columns")  # 🔥 **Fix Here**
                recent_date = df.index.max()
    
                # **If cached data is recent, skip API call**
                if recent_date >= pd.Timestamp.today() - pd.DateOffset(days=7):  
                    self.data[ticker] = df  # ✅ Store properly formatted data
                    continue
    
            print(f"🌐 Fetching 10 years of data for {ticker} from API...")
            params = {
                "function": "TIME_SERIES_DAILY",
                "symbol": ticker,
                "outputsize": self.outputsize,  # "full" gets 20+ years
                "datatype": "json",
                "apikey": self.api_key
            }
    
            response = requests.get(base_url, params=params)
            data = response.json()
    
            if "Time Series (Daily)" not in data:
                print(f"❌ Error fetching {ticker}: {data.get('Note', 'No data available.')}")
                continue
    
            # ✅ Convert API Response to DataFrame
            df = pd.DataFrame.from_dict(data["Time Series (Daily)"], orient="index")
            df.index = pd.to_datetime(df.index)
            df = df.sort_index()
    
            # ✅ Keep Only the Last **10 Years**
            ten_years_ago = pd.Timestamp.today() - pd.DateOffset(years=10)
            df = df[df.index >= ten_years_ago]
    
            # ✅ Store Only "Close" Prices & Save to Cache
            df = df["4. close"].astype(float).squeeze("columns")  # 🔥 **Ensure 1D**
            df.to_csv(cache_file)
            self.data[ticker] = df  # ✅ Store correctly
    
            # 🕒 **Wait to avoid hitting API limit**
            time.sleep(12)  # Alpha Vantage allows ~5 calls/min


    def get_data(self):
        """Return stock data as a pandas DataFrame."""
        if not self.data:
            raise ValueError("No valid stock data found. Check API key and ticker symbols.")
    
        # Convert each ticker's cached data into a Pandas Series and flatten if needed
        for ticker in self.data:
            if isinstance(self.data[ticker], np.ndarray):
                self.data[ticker] = self.data[ticker].flatten()  # Ensure 1D
            if not isinstance(self.data[ticker], pd.Series):
                self.data[ticker] = pd.Series(self.data[ticker])  
    
        df = pd.DataFrame(self.data)
        df.dropna(how="all", inplace=True)  # Drop rows where all tickers have NaN
    
        if df.empty:
            raise ValueError("Stock data is empty after processing. Check cache or API response.")
    
        return df




# ✅ **Example Usage**
if __name__ == "__main__":
    tickers = ["AAPL", "GOOGL", "MSFT", "TSLA"]
    api_key = "I3QFMBJXM0I1YYSF"  # 🔑 Replace with your Alpha Vantage API key

    data_handler = StockDataHandler(tickers, api_key, outputsize="full")
    data_handler.fetch_data()

    try:
        df = data_handler.get_data()
        print(df.head())  # 📊 Preview stock data
    except ValueError as e:
        print(f"Error: {e}")
# Out:
# 📂 Loading cached data for AAPL...
# 📂 Loading cached data for GOOGL...
# 📂 Loading cached data for MSFT...
# 📂 Loading cached data for TSLA...
#               AAPL    GOOGL   MSFT    TSLA
# 2015-02-02  118.63  532.200  41.28  210.94
# 2015-02-03  118.65  533.300  41.60  218.36
# 2015-02-04  119.56  526.100  41.84  218.55
# 2015-02-05  119.94  529.830  42.45  220.99
# 2015-02-06  118.93  533.875  42.41  217.36

# %%
import gym
import numpy as np
from gym import spaces

class StockTradingEnv(gym.Env):
    def __init__(self, tickers, stock_data, initial_cash=10000):
        super(StockTradingEnv, self).__init__()
        self.tickers = [t for t in tickers if t in stock_data.columns]  # Only use tickers with data
        self.df = stock_data[self.tickers].copy().sort_index()  # Ensure oldest data first
        self.initial_cash = initial_cash
        self.cash = initial_cash
        self.shares = {ticker: 0 for ticker in self.tickers}
        self.current_step = 0

        # ✅ Check if we have data before proceeding
        if self.df.empty:
            raise ValueError("❌ No stock data available in the DataFrame!")

        # ✅ Define action and observation spaces
        self.action_space = spaces.MultiDiscrete([3] * len(self.tickers))  # 0 = Hold, 1 = Buy, 2 = Sell
        self.observation_space = spaces.Box(low=0, high=np.inf, shape=(len(self.tickers) * 2 + 1,), dtype=np.float32)

    def reset(self):
        """Reset environment to initial state."""
        self.cash = self.initial_cash
        self.shares = {ticker: 0 for ticker in self.tickers}
        self.current_step = 0
        return self._get_obs()

    def step(self, action):
        """Execute a step in the environment based on the action taken for multiple stocks."""
        if self.current_step >= len(self.df) - 1:
            return self._get_obs(), 0, True, {}  # Return last state if we're out of data

        prices = self.df.iloc[self.current_step]

        for i, ticker in enumerate(self.tickers):
            if action[i] == 1 and self.cash >= prices[ticker]:  # Buy stock
                self.shares[ticker] += 1
                self.cash -= prices[ticker]
            elif action[i] == 2 and self.shares[ticker] > 0:  # Sell stock
                self.shares[ticker] -= 1
                self.cash += prices[ticker]

        # Move to next step
        self.current_step += 1
        done = self.current_step >= len(self.df) - 1

        # ✅ Reward = Portfolio Value Change (to encourage profit)
        portfolio_value = self.cash + sum(self.shares[t] * prices[t] for t in self.tickers)
        reward = portfolio_value - self.initial_cash  # Profit = reward

        return self._get_obs(), reward, done, {}

    def _get_obs(self):
        """Return observation: cash balance + stock prices + shares owned for all stocks."""
        prices = np.array([self.df.iloc[self.current_step][t] for t in self.tickers], dtype=np.float32)
        holdings = np.array([self.shares[t] for t in self.tickers], dtype=np.float32)

        obs = np.concatenate(([self.cash], prices, holdings), axis=0)
        return obs

    def render(self):
        """Prints current cash, stock holdings, and total portfolio value."""
        portfolio_value = self.cash + sum(self.shares[t] * self.df.iloc[self.current_step][t] for t in self.tickers)

        print(f"📊 Step: {self.current_step}")
        print(f"💰 Cash: ${self.cash:.2f}")
        print("📈 Holdings:", {t: self.shares[t] for t in self.tickers})
        print(f"📉 Total Portfolio Value: ${portfolio_value:.2f}")

    def seed(self, seed=None):
        """Sets the random seed for reproducibility."""
        np.random.seed(seed)

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
#from data_handler import StockDataHandler
#from trading_env import StockTradingEnv

# ✅ Step 1: Load or Fetch Stock Data
tickers = ["AAPL", "GOOGL", "MSFT", "TSLA"]
api_key = "I3QFMBJXM0I1YYSF"

data_handler = StockDataHandler(tickers, api_key, outputsize="full")

try:
    df = data_handler.get_data()  # Try loading cached data
except ValueError:
    data_handler.fetch_data()  # Fetch new data if cache is missing
    df = data_handler.get_data()

# ✅ Step 2: Create the RL Training Environment
env = make_vec_env(lambda: StockTradingEnv(tickers, df), n_envs=1)

# ✅ Step 3: Train the AI Model
model = PPO(
    "MlpPolicy",           # MLP (Multi-Layer Perceptron) policy network
    env,                    # The environment you're training in
    learning_rate=2.5e-4,   # The learning rate of the optimizer
    n_steps=2048,           # The number of steps to run for each environment per update
    batch_size=64,          # The batch size used for training
    n_epochs=10,            # Number of epochs per update (how many times to optimize the model on the sampled data)
    gamma=0.99,             # The discount factor for future rewards
    gae_lambda=0.95,        # The factor for Generalized Advantage Estimation (GAE)
    ent_coef=0.01,          # Coefficient for the entropy bonus (encourages exploration)
    vf_coef=0.5,            # Coefficient for the value function loss
    max_grad_norm=0.5,      # Gradient clipping to prevent gradient explosion
    clip_range=0.2,         # The clip range for the PPO objective to stabilize training
    target_kl=0.01,         # Target KL divergence for early stopping
    verbose=1,              # Display training information
    tensorboard_log="./ppo_tensorboard", # Optional: Log to TensorBoard for monitoring
    seed=42,                # For reproducibility, set the random seed
)
model.learn(total_timesteps=500000)  # Adjust timesteps for better learning
model.save("stock_trading_ppo")

# ✅ Step 4: Load the Trained Model for Evaluation or Further Training
model = PPO.load("stock_trading_ppo")
# Out:
# 📂 Loading cached data for AAPL...
# 📂 Loading cached data for GOOGL...
# 📂 Loading cached data for MSFT...
# 📂 Loading cached data for TSLA...
# Using cpu device
# C:\Users\pched\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Logging to ./ppo_tensorboard\PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 1464 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 1.71e+07      |
# | time/                   |               |
# |    fps                  | 1153          |
# |    iterations           | 2             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 1.3405806e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 7.01e+09      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -6.39e-05     |
# |    value_loss           | 2.07e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 1.74e+07      |
# | time/                   |               |
# |    fps                  | 1084          |
# |    iterations           | 3             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 3.0655647e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -1.67e-06     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.07e+10      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000123     |
# |    value_loss           | 2.52e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 1.54e+07      |
# | time/                   |               |
# |    fps                  | 1049          |
# |    iterations           | 4             |
# |    time_elapsed         | 7             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 2.7744973e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 2.98e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.64e+10      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000103     |
# |    value_loss           | 2.45e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 1.71e+07      |
# | time/                   |               |
# |    fps                  | 1028          |
# |    iterations           | 5             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 4.9031514e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 7.44e+09      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000128     |
# |    value_loss           | 1.41e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 1.71e+07      |
# | time/                   |               |
# |    fps                  | 1014          |
# |    iterations           | 6             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 4.6749483e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.08e+10      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -4.08e-05     |
# |    value_loss           | 4.43e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 1.82e+07      |
# | time/                   |               |
# |    fps                  | 1006          |
# |    iterations           | 7             |
# |    time_elapsed         | 14            |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 1.2738165e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.58e+10      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -7.34e-05     |
# |    value_loss           | 5.7e+10       |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.45e+07      |
# | time/                   |               |
# |    fps                  | 997           |
# |    iterations           | 8             |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 3.2721437e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 7.03e+10      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -2.83e-05     |
# |    value_loss           | 1.3e+11       |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.51e+03     |
# |    ep_rew_mean          | 2.29e+07     |
# | time/                   |              |
# |    fps                  | 993          |
# |    iterations           | 9            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 3.516907e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.84e+10     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -3.34e-05    |
# |    value_loss           | 1.54e+11     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.27e+07      |
# | time/                   |               |
# |    fps                  | 990           |
# |    iterations           | 10            |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 4.6844943e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 9.73e+09      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000143     |
# |    value_loss           | 1.66e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.51e+03     |
# |    ep_rew_mean          | 2.27e+07     |
# | time/                   |              |
# |    fps                  | 988          |
# |    iterations           | 11           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 6.359478e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.55e+10     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -4.46e-05    |
# |    value_loss           | 4.03e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.19e+07      |
# | time/                   |               |
# |    fps                  | 985           |
# |    iterations           | 12            |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 1.9554282e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.82e+09      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -9.2e-05      |
# |    value_loss           | 2.14e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.51e+03     |
# |    ep_rew_mean          | 2.12e+07     |
# | time/                   |              |
# |    fps                  | 980          |
# |    iterations           | 13           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 9.766372e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.36e+10     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -5.74e-05    |
# |    value_loss           | 2.69e+10     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.51e+03     |
# |    ep_rew_mean          | 2e+07        |
# | time/                   |              |
# |    fps                  | 980          |
# |    iterations           | 14           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 5.639944e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.05e+09     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000139    |
# |    value_loss           | 5.61e+09     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.51e+03     |
# |    ep_rew_mean          | 2.03e+07     |
# | time/                   |              |
# |    fps                  | 978          |
# |    iterations           | 15           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 9.116542e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.62e+09     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000176    |
# |    value_loss           | 3.2e+09      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.03e+07      |
# | time/                   |               |
# |    fps                  | 978           |
# |    iterations           | 16            |
# |    time_elapsed         | 33            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 7.0623355e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.75e+10      |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -4.28e-05     |
# |    value_loss           | 5.32e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.03e+07      |
# | time/                   |               |
# |    fps                  | 973           |
# |    iterations           | 17            |
# |    time_elapsed         | 35            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 3.0139927e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.25e+10      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -2.66e-05     |
# |    value_loss           | 3.24e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.21e+07      |
# | time/                   |               |
# |    fps                  | 972           |
# |    iterations           | 18            |
# |    time_elapsed         | 37            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 3.8344297e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.67e+10      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -3.36e-05     |
# |    value_loss           | 1.03e+11      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.51e+03     |
# |    ep_rew_mean          | 2.19e+07     |
# | time/                   |              |
# |    fps                  | 971          |
# |    iterations           | 19           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 8.409843e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.86e+10     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -6.67e-05    |
# |    value_loss           | 1.09e+11     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.19e+07      |
# | time/                   |               |
# |    fps                  | 970           |
# |    iterations           | 20            |
# |    time_elapsed         | 42            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 1.1145312e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 9.07e+09      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -4.36e-05     |
# |    value_loss           | 2.07e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.27e+07      |
# | time/                   |               |
# |    fps                  | 969           |
# |    iterations           | 21            |
# |    time_elapsed         | 44            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 3.4464756e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.5e+10       |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -2.61e-05     |
# |    value_loss           | 4.14e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.51e+03     |
# |    ep_rew_mean          | 2.27e+07     |
# | time/                   |              |
# |    fps                  | 969          |
# |    iterations           | 22           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 2.127199e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.53e+10     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -2.81e-05    |
# |    value_loss           | 1.1e+11      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.39e+07      |
# | time/                   |               |
# |    fps                  | 969           |
# |    iterations           | 23            |
# |    time_elapsed         | 48            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 1.4033867e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 9.36e+10      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -1.99e-05     |
# |    value_loss           | 1.55e+11      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.34e+07      |
# | time/                   |               |
# |    fps                  | 969           |
# |    iterations           | 24            |
# |    time_elapsed         | 50            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 7.5413845e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.03e+10      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -6.58e-05     |
# |    value_loss           | 7.1e+10       |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 2.51e+03       |
# |    ep_rew_mean          | 2.36e+07       |
# | time/                   |                |
# |    fps                  | 968            |
# |    iterations           | 25             |
# |    time_elapsed         | 52             |
# |    total_timesteps      | 51200          |
# | train/                  |                |
# |    approx_kl            | 1.44379155e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -4.39          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.00025        |
# |    loss                 | 5.46e+09       |
# |    n_updates            | 240            |
# |    policy_gradient_loss | -0.000319      |
# |    value_loss           | 1.86e+10       |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.32e+07      |
# | time/                   |               |
# |    fps                  | 968           |
# |    iterations           | 26            |
# |    time_elapsed         | 54            |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 1.2074306e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.11e+10      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -8.17e-05     |
# |    value_loss           | 6.63e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.33e+07      |
# | time/                   |               |
# |    fps                  | 968           |
# |    iterations           | 27            |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 1.2799865e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.35e+10      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -6.15e-05     |
# |    value_loss           | 2.46e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.51e+03     |
# |    ep_rew_mean          | 2.33e+07     |
# | time/                   |              |
# |    fps                  | 965          |
# |    iterations           | 28           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 4.962203e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.75e+10     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -5.04e-05    |
# |    value_loss           | 5.06e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.33e+07      |
# | time/                   |               |
# |    fps                  | 963           |
# |    iterations           | 29            |
# |    time_elapsed         | 61            |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 2.9079383e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 8.62e+09      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000108     |
# |    value_loss           | 2.12e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.35e+07      |
# | time/                   |               |
# |    fps                  | 962           |
# |    iterations           | 30            |
# |    time_elapsed         | 63            |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 1.2953242e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.18e+10      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -7.91e-05     |
# |    value_loss           | 4.78e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.34e+07      |
# | time/                   |               |
# |    fps                  | 962           |
# |    iterations           | 31            |
# |    time_elapsed         | 65            |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 5.0564995e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.97e+10      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -3.41e-05     |
# |    value_loss           | 5.43e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.37e+07      |
# | time/                   |               |
# |    fps                  | 961           |
# |    iterations           | 32            |
# |    time_elapsed         | 68            |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 1.1356606e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.91e+10      |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -6.41e-05     |
# |    value_loss           | 3.65e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.37e+07      |
# | time/                   |               |
# |    fps                  | 961           |
# |    iterations           | 33            |
# |    time_elapsed         | 70            |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 3.5649282e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.96e+10      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -3.67e-05     |
# |    value_loss           | 9.85e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.4e+07       |
# | time/                   |               |
# |    fps                  | 961           |
# |    iterations           | 34            |
# |    time_elapsed         | 72            |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 6.3335756e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.7e+10       |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -4.21e-05     |
# |    value_loss           | 5.78e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.51e+03     |
# |    ep_rew_mean          | 2.4e+07      |
# | time/                   |              |
# |    fps                  | 959          |
# |    iterations           | 35           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 7.932249e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.55e+10     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -5.58e-05    |
# |    value_loss           | 6.58e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.44e+07      |
# | time/                   |               |
# |    fps                  | 959           |
# |    iterations           | 36            |
# |    time_elapsed         | 76            |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 2.0722218e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 7.08e+09      |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -8.72e-05     |
# |    value_loss           | 1.93e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.44e+07      |
# | time/                   |               |
# |    fps                  | 959           |
# |    iterations           | 37            |
# |    time_elapsed         | 79            |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 2.0922744e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 6.33e+10      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -2.47e-05     |
# |    value_loss           | 1.34e+11      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.44e+07      |
# | time/                   |               |
# |    fps                  | 959           |
# |    iterations           | 38            |
# |    time_elapsed         | 81            |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 1.3413955e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.25e+10      |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -7.96e-05     |
# |    value_loss           | 4.05e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.43e+07      |
# | time/                   |               |
# |    fps                  | 959           |
# |    iterations           | 39            |
# |    time_elapsed         | 83            |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 1.0684598e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.74e+10      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -6.5e-05      |
# |    value_loss           | 3.74e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.4e+07       |
# | time/                   |               |
# |    fps                  | 959           |
# |    iterations           | 40            |
# |    time_elapsed         | 85            |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 1.3083045e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.07e+10      |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -5.19e-05     |
# |    value_loss           | 2.04e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.43e+07      |
# | time/                   |               |
# |    fps                  | 959           |
# |    iterations           | 41            |
# |    time_elapsed         | 87            |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 3.6339625e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.6e+10       |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.000137     |
# |    value_loss           | 2.62e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.44e+07      |
# | time/                   |               |
# |    fps                  | 959           |
# |    iterations           | 42            |
# |    time_elapsed         | 89            |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 1.9025174e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.34e+10      |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -2e-05        |
# |    value_loss           | 8.66e+10      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.51e+03    |
# |    ep_rew_mean          | 2.42e+07    |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 43          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 3.77564e-07 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.39       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 2.45e+10    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -3.27e-05   |
# |    value_loss           | 7.08e+10    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.42e+07      |
# | time/                   |               |
# |    fps                  | 958           |
# |    iterations           | 44            |
# |    time_elapsed         | 93            |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 1.0306248e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.06e+10      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -6.04e-05     |
# |    value_loss           | 2.44e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.39e+07      |
# | time/                   |               |
# |    fps                  | 958           |
# |    iterations           | 45            |
# |    time_elapsed         | 96            |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 1.5939295e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.09e+10      |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.000102     |
# |    value_loss           | 2.55e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.41e+07      |
# | time/                   |               |
# |    fps                  | 958           |
# |    iterations           | 46            |
# |    time_elapsed         | 98            |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 6.8277586e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.53e+10      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -4.17e-05     |
# |    value_loss           | 4.22e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.39e+07      |
# | time/                   |               |
# |    fps                  | 958           |
# |    iterations           | 47            |
# |    time_elapsed         | 100           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 5.9517333e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.28e+10      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -2.71e-05     |
# |    value_loss           | 4.12e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.38e+07      |
# | time/                   |               |
# |    fps                  | 958           |
# |    iterations           | 48            |
# |    time_elapsed         | 102           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 1.1726224e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.45e+10      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -6.55e-05     |
# |    value_loss           | 3.13e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.38e+07      |
# | time/                   |               |
# |    fps                  | 958           |
# |    iterations           | 49            |
# |    time_elapsed         | 104           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 7.8440644e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.6e+10       |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -5.03e-05     |
# |    value_loss           | 2.68e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.37e+07      |
# | time/                   |               |
# |    fps                  | 957           |
# |    iterations           | 50            |
# |    time_elapsed         | 106           |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 9.1511174e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.86e+10      |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -6.47e-05     |
# |    value_loss           | 4.37e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.51e+03     |
# |    ep_rew_mean          | 2.37e+07     |
# | time/                   |              |
# |    fps                  | 957          |
# |    iterations           | 51           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 7.111521e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.58e+10     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -4.32e-05    |
# |    value_loss           | 4.2e+10      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.35e+07      |
# | time/                   |               |
# |    fps                  | 957           |
# |    iterations           | 52            |
# |    time_elapsed         | 111           |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 7.0988317e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.32e+09      |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -0.000193     |
# |    value_loss           | 7.61e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.34e+07      |
# | time/                   |               |
# |    fps                  | 957           |
# |    iterations           | 53            |
# |    time_elapsed         | 113           |
# ...
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.41e+10      |
# |    n_updates            | 2270          |
# |    policy_gradient_loss | -2.48e-05     |
# |    value_loss           | 1.08e+11      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.51e+03     |
# |    ep_rew_mean          | 2.49e+07     |
# | time/                   |              |
# |    fps                  | 952          |
# |    iterations           | 229          |
# |    time_elapsed         | 492          |
# |    total_timesteps      | 468992       |
# | train/                  |              |
# |    approx_kl            | 4.847243e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.29e+10     |
# |    n_updates            | 2280         |
# |    policy_gradient_loss | -3.54e-05    |
# |    value_loss           | 7.69e+10     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.51e+03     |
# |    ep_rew_mean          | 2.49e+07     |
# | time/                   |              |
# |    fps                  | 952          |
# |    iterations           | 230          |
# |    time_elapsed         | 494          |
# |    total_timesteps      | 471040       |
# | train/                  |              |
# |    approx_kl            | 6.800401e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.66e+10     |
# |    n_updates            | 2290         |
# |    policy_gradient_loss | -4.25e-05    |
# |    value_loss           | 7.85e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.48e+07      |
# | time/                   |               |
# |    fps                  | 952           |
# |    iterations           | 231           |
# |    time_elapsed         | 496           |
# |    total_timesteps      | 473088        |
# | train/                  |               |
# |    approx_kl            | 4.1315798e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.61e+10      |
# |    n_updates            | 2300          |
# |    policy_gradient_loss | -2.83e-05     |
# |    value_loss           | 7.87e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.49e+07      |
# | time/                   |               |
# |    fps                  | 952           |
# |    iterations           | 232           |
# |    time_elapsed         | 498           |
# |    total_timesteps      | 475136        |
# | train/                  |               |
# |    approx_kl            | 1.9970175e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.67e+10      |
# |    n_updates            | 2310          |
# |    policy_gradient_loss | -9.52e-05     |
# |    value_loss           | 3.66e+10      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.51e+03    |
# |    ep_rew_mean          | 2.49e+07    |
# | time/                   |             |
# |    fps                  | 953         |
# |    iterations           | 233         |
# |    time_elapsed         | 500         |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 6.46658e-07 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.39       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.59e+10    |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | -4.33e-05   |
# |    value_loss           | 6.84e+10    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.48e+07      |
# | time/                   |               |
# |    fps                  | 953           |
# |    iterations           | 234           |
# |    time_elapsed         | 502           |
# |    total_timesteps      | 479232        |
# | train/                  |               |
# |    approx_kl            | 3.4724362e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.64e+10      |
# |    n_updates            | 2330          |
# |    policy_gradient_loss | -0.000145     |
# |    value_loss           | 3.03e+10      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.51e+03    |
# |    ep_rew_mean          | 2.47e+07    |
# | time/                   |             |
# |    fps                  | 953         |
# |    iterations           | 235         |
# |    time_elapsed         | 504         |
# |    total_timesteps      | 481280      |
# | train/                  |             |
# |    approx_kl            | 8.09526e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.39       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.35e+09    |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.000229   |
# |    value_loss           | 7.37e+09    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.47e+07      |
# | time/                   |               |
# |    fps                  | 952           |
# |    iterations           | 236           |
# |    time_elapsed         | 507           |
# |    total_timesteps      | 483328        |
# | train/                  |               |
# |    approx_kl            | 3.8515427e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.56e+09      |
# |    n_updates            | 2350          |
# |    policy_gradient_loss | -0.000113     |
# |    value_loss           | 9.43e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.47e+07      |
# | time/                   |               |
# |    fps                  | 952           |
# |    iterations           | 237           |
# |    time_elapsed         | 509           |
# |    total_timesteps      | 485376        |
# | train/                  |               |
# |    approx_kl            | 1.3965764e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.28e+10      |
# |    n_updates            | 2360          |
# |    policy_gradient_loss | -7.29e-05     |
# |    value_loss           | 4.25e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.47e+07      |
# | time/                   |               |
# |    fps                  | 952           |
# |    iterations           | 238           |
# |    time_elapsed         | 511           |
# |    total_timesteps      | 487424        |
# | train/                  |               |
# |    approx_kl            | 7.5271237e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.71e+10      |
# |    n_updates            | 2370          |
# |    policy_gradient_loss | -6.88e-05     |
# |    value_loss           | 7.49e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.47e+07      |
# | time/                   |               |
# |    fps                  | 952           |
# |    iterations           | 239           |
# |    time_elapsed         | 513           |
# |    total_timesteps      | 489472        |
# | train/                  |               |
# |    approx_kl            | 4.3938053e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 7.67e+10      |
# |    n_updates            | 2380          |
# |    policy_gradient_loss | -4.26e-05     |
# |    value_loss           | 1.45e+11      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.46e+07      |
# | time/                   |               |
# |    fps                  | 952           |
# |    iterations           | 240           |
# |    time_elapsed         | 515           |
# |    total_timesteps      | 491520        |
# | train/                  |               |
# |    approx_kl            | 1.0193035e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.21e+10      |
# |    n_updates            | 2390          |
# |    policy_gradient_loss | -6.29e-05     |
# |    value_loss           | 3.72e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.47e+07      |
# | time/                   |               |
# |    fps                  | 953           |
# |    iterations           | 241           |
# |    time_elapsed         | 517           |
# |    total_timesteps      | 493568        |
# | train/                  |               |
# |    approx_kl            | 2.1655287e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.8e+10       |
# |    n_updates            | 2400          |
# |    policy_gradient_loss | -8.72e-05     |
# |    value_loss           | 3.13e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.46e+07      |
# | time/                   |               |
# |    fps                  | 953           |
# |    iterations           | 242           |
# |    time_elapsed         | 520           |
# |    total_timesteps      | 495616        |
# | train/                  |               |
# |    approx_kl            | 3.3932156e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.61e+10      |
# |    n_updates            | 2410          |
# |    policy_gradient_loss | -2.74e-05     |
# |    value_loss           | 8.95e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.47e+07      |
# | time/                   |               |
# |    fps                  | 952           |
# |    iterations           | 243           |
# |    time_elapsed         | 522           |
# |    total_timesteps      | 497664        |
# | train/                  |               |
# |    approx_kl            | 1.0013464e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.08e+10      |
# |    n_updates            | 2420          |
# |    policy_gradient_loss | -6.55e-05     |
# |    value_loss           | 5.01e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.47e+07      |
# | time/                   |               |
# |    fps                  | 952           |
# |    iterations           | 244           |
# |    time_elapsed         | 524           |
# |    total_timesteps      | 499712        |
# | train/                  |               |
# |    approx_kl            | 3.7089922e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.49e+10      |
# |    n_updates            | 2430          |
# |    policy_gradient_loss | -3.57e-05     |
# |    value_loss           | 1.09e+11      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.51e+03      |
# |    ep_rew_mean          | 2.45e+07      |
# | time/                   |               |
# |    fps                  | 952           |
# |    iterations           | 245           |
# |    time_elapsed         | 526           |
# |    total_timesteps      | 501760        |
# | train/                  |               |
# |    approx_kl            | 3.4872792e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.97e+09      |
# |    n_updates            | 2440          |
# |    policy_gradient_loss | -0.000113     |
# |    value_loss           | 1.47e+10      |
# -------------------------------------------

# %%
from stable_baselines3 import PPO

class TradingAgent:
    def __init__(self, model_path="stock_trading_ppo"):
        """Initialize the trading agent with a trained PPO model."""
        try:
            self.model = PPO.load(model_path)  # ✅ Load trained AI model
            print("✅ Successfully loaded AI trading model.")
        except Exception as e:
            print(f"❌ Error loading model: {e}")
            self.model = None  # Ensure model is None if loading fails

    def act(self, obs):
        """Use the trained RL model to make decisions instead of random choices."""
        if self.model is None:
            raise ValueError("❌ No trained AI model found. Ensure PPO model is trained and saved.")

        action, _ = self.model.predict(obs)  # ✅ Predict using PPO
        return action

# %%
# Load stock data (Use Cached Data if Available)
tickers = ["AAPL", "GOOGL", "MSFT", "TSLA"]
api_key = "I3QFMBJXM0I1YYSF"  # Replace with your real API key
data_handler = StockDataHandler(tickers, api_key, outputsize="full")

# ✅ Check if cached data exists, otherwise fetch new data
try:
    df = data_handler.get_data()  # Load cached data
except ValueError:
    data_handler.fetch_data()  # Fetch new data
    df = data_handler.get_data()

# ✅ Create Trading Environment
env = StockTradingEnv(tickers, df)
agent = TradingAgent("stock_trading_ppo")  # Change to "llm" to use an LLM-powered agent

# ✅ Run Simulation
obs = env.reset()
for _ in range(1000):
    action = agent.act(obs)  # Get action from agent
    obs, reward, done, _ = env.step(action)  # Take a step
    env.render()  # Show results
    if done:
        break

# ✅ Calculate Final Portfolio Value
final_cash = env.cash
portfolio_value = final_cash + sum(env.shares[t] * df.iloc[-1][t] for t in tickers)

print("\n==== 📊 Final Results ====")
print(f"💰 Final Cash: ${final_cash:.2f}")
print(f"📈 Total Portfolio Value: ${portfolio_value:.2f}")
print(f"💵 Profit/Loss: ${portfolio_value - env.initial_cash:.2f}")
print(f"📅 Trading Days Simulated: {env.current_step}")
# Out:
# 📂 Loading cached data for AAPL...
# 📂 Loading cached data for GOOGL...
# 📂 Loading cached data for MSFT...
# 📂 Loading cached data for TSLA...
# ✅ Successfully loaded AI trading model.
# 📊 Step: 1
# 💰 Cash: $10000.00
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 0}
# 📉 Total Portfolio Value: $10000.00
# 📊 Step: 2
# 💰 Cash: $9348.05
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 1, 'MSFT': 0, 'TSLA': 0}
# 📉 Total Portfolio Value: $9993.71
# 📊 Step: 3
# 💰 Cash: $9874.15
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 0}
# 📉 Total Portfolio Value: $9994.09
# 📊 Step: 4
# 💰 Cash: $9773.10
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 1}
# 📉 Total Portfolio Value: $9990.46
# 📊 Step: 5
# 💰 Cash: $9555.74
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 2}
# 📉 Total Portfolio Value: $9990.70
# 📊 Step: 6
# 💰 Cash: $9513.38
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 2}
# 📉 Total Portfolio Value: $9988.56
# 📊 Step: 7
# 💰 Cash: $8799.53
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 1, 'MSFT': 0, 'TSLA': 3}
# 📉 Total Portfolio Value: $9975.93
# 📊 Step: 8
# 💰 Cash: $9295.15
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 3}
# 📉 Total Portfolio Value: $9946.88
# 📊 Step: 9
# 💰 Cash: $9252.06
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 3}
# 📉 Total Portfolio Value: $9951.11
# 📊 Step: 10
# 💰 Cash: $9328.75
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 2}
# 📉 Total Portfolio Value: $9952.44
# 📊 Step: 11
# 💰 Cash: $9080.82
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 3}
# 📉 Total Portfolio Value: $9953.51
# 📊 Step: 12
# 💰 Cash: $8961.55
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 4}
# 📉 Total Portfolio Value: $9982.37
# 📊 Step: 13
# 💰 Cash: $8961.55
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 4}
# 📉 Total Portfolio Value: $10005.41
# 📊 Step: 14
# 💰 Cash: $8917.69
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 4}
# 📉 Total Portfolio Value: $9967.78
# 📊 Step: 15
# 💰 Cash: $8577.36
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 5}
# 📉 Total Portfolio Value: $9950.53
# 📊 Step: 16
# 💰 Cash: $7702.43
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 1, 'MSFT': 5, 'TSLA': 6}
# 📉 Total Portfolio Value: $9949.85
# 📊 Step: 17
# 💰 Cash: $7155.10
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 2, 'MSFT': 5, 'TSLA': 6}
# 📉 Total Portfolio Value: $9997.92
# 📊 Step: 18
# 💰 Cash: $7362.29
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 2, 'MSFT': 5, 'TSLA': 5}
# 📉 Total Portfolio Value: $9980.42
# 📊 Step: 19
# 💰 Cash: $7074.34
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 2, 'MSFT': 4, 'TSLA': 6}
# 📉 Total Portfolio Value: $9971.12
# 📊 Step: 20
# 💰 Cash: $7315.54
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 2, 'MSFT': 3, 'TSLA': 5}
# 📉 Total Portfolio Value: $9988.85
# 📊 Step: 21
# 💰 Cash: $6666.55
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 3, 'MSFT': 3, 'TSLA': 6}
# 📉 Total Portfolio Value: $10002.39
# 📊 Step: 22
# 💰 Cash: $6538.01
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 3, 'MSFT': 3, 'TSLA': 6}
# 📉 Total Portfolio Value: $9994.65
# 📊 Step: 23
# 💰 Cash: $6082.98
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 4, 'MSFT': 3, 'TSLA': 6}
# 📉 Total Portfolio Value: $9918.14
# 📊 Step: 24
# 💰 Cash: $5889.10
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 4, 'MSFT': 3, 'TSLA': 7}
# 📉 Total Portfolio Value: $9904.49
# 📊 Step: 25
# 💰 Cash: $5633.02
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 5, 'MSFT': 3, 'TSLA': 6}
# 📉 Total Portfolio Value: $9824.79
# 📊 Step: 26
# 💰 Cash: $5550.54
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 5, 'MSFT': 2, 'TSLA': 6}
# 📉 Total Portfolio Value: $9819.87
# 📊 Step: 27
# 💰 Cash: $4923.35
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 6, 'MSFT': 2, 'TSLA': 7}
# 📉 Total Portfolio Value: $9834.35
# 📊 Step: 28
# 💰 Cash: $4798.90
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 2, 'TSLA': 7}
# 📉 Total Portfolio Value: $9767.60
# 📊 Step: 29
# 💰 Cash: $5416.99
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 5, 'MSFT': 2, 'TSLA': 6}
# 📉 Total Portfolio Value: $9857.36
# 📊 Step: 30
# 💰 Cash: $5937.07
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 4, 'MSFT': 3, 'TSLA': 6}
# 📉 Total Portfolio Value: $9842.10
# 📊 Step: 31
# 💰 Cash: $5700.65
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 4, 'MSFT': 4, 'TSLA': 7}
# 📉 Total Portfolio Value: $9925.67
# 📊 Step: 32
# 💰 Cash: $5743.15
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 4, 'MSFT': 3, 'TSLA': 7}
# 📉 Total Portfolio Value: $9876.72
# 📊 Step: 33
# 💰 Cash: $5912.93
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 4, 'MSFT': 2, 'TSLA': 7}
# 📉 Total Portfolio Value: $9896.85
# 📊 Step: 34
# 💰 Cash: $6560.90
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 3, 'MSFT': 3, 'TSLA': 7}
# 📉 Total Portfolio Value: $9910.19
# 📊 Step: 35
# 💰 Cash: $6445.62
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 3, 'MSFT': 4, 'TSLA': 8}
# 📉 Total Portfolio Value: $9963.60
# 📊 Step: 36
# 💰 Cash: $7023.16
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 4, 'TSLA': 8}
# 📉 Total Portfolio Value: $9877.40
# 📊 Step: 37
# 💰 Cash: $7023.16
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 4, 'TSLA': 8}
# 📉 Total Portfolio Value: $9838.52
# 📊 Step: 38
# 💰 Cash: $6459.52
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 3, 'MSFT': 4, 'TSLA': 8}
# 📉 Total Portfolio Value: $9776.05
# 📊 Step: 39
# 💰 Cash: $6708.82
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 2, 'MSFT': 4, 'TSLA': 9}
# 📉 Total Portfolio Value: $9836.43
# 📊 Step: 40
# 💰 Cash: $6644.62
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 4, 'TSLA': 10}
# 📉 Total Portfolio Value: $9804.34
# 📊 Step: 41
# 💰 Cash: $5941.81
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 3, 'MSFT': 3, 'TSLA': 11}
# 📉 Total Portfolio Value: $9775.93
# 📊 Step: 42
# 💰 Cash: $6303.71
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 3, 'TSLA': 12}
# 📉 Total Portfolio Value: $9799.20
# 📊 Step: 43
# 💰 Cash: $7076.31
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 1, 'MSFT': 2, 'TSLA': 11}
# 📉 Total Portfolio Value: $9937.45
# 📊 Step: 44
# 💰 Cash: $6370.80
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 1, 'TSLA': 12}
# 📉 Total Portfolio Value: $9941.05
# 📊 Step: 45
# 💰 Cash: $6209.08
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 0, 'TSLA': 13}
# 📉 Total Portfolio Value: $10006.47
# 📊 Step: 46
# 💰 Cash: $6550.25
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 1, 'MSFT': 0, 'TSLA': 14}
# 📉 Total Portfolio Value: $10039.53
# 📊 Step: 47
# 💰 Cash: $6720.14
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 15}
# 📉 Total Portfolio Value: $10052.46
# 📊 Step: 48
# 💰 Cash: $6678.06
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 16}
# 📉 Total Portfolio Value: $10034.54
# 📊 Step: 49
# 💰 Cash: $6339.20
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 1, 'MSFT': 0, 'TSLA': 15}
# 📉 Total Portfolio Value: $9990.88
# 📊 Step: 50
# 💰 Cash: $6671.52
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 16}
# 📉 Total Portfolio Value: $9996.80
# 📊 Step: 51
# 💰 Cash: $6671.52
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 16}
# 📉 Total Portfolio Value: $9978.72
# 📊 Step: 52
# 💰 Cash: $6671.52
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 16}
# 📉 Total Portfolio Value: $9980.16
# 📊 Step: 53
# 💰 Cash: $6464.73
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 17}
# 📉 Total Portfolio Value: $9954.32
# 📊 Step: 54
# 💰 Cash: $6421.83
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 17}
# 📉 Total Portfolio Value: $10024.43
# 📊 Step: 55
# 💰 Cash: $6255.05
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 18}
# 📉 Total Portfolio Value: $10204.97
# 📊 Step: 56
# 💰 Cash: $6474.49
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 17}
# 📉 Total Portfolio Value: $10190.69
# 📊 Step: 57
# 💰 Cash: $5744.02
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 17}
# 📉 Total Portfolio Value: $10209.06
# 📊 Step: 58
# 💰 Cash: $5040.08
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 2, 'MSFT': 1, 'TSLA': 17}
# 📉 Total Portfolio Value: $10422.00
# 📊 Step: 59
# 💰 Cash: $4675.88
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 2, 'MSFT': 1, 'TSLA': 18}
# 📉 Total Portfolio Value: $10394.10
# 📊 Step: 60
# 💰 Cash: $4260.59
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 3, 'MSFT': 0, 'TSLA': 17}
# 📉 Total Portfolio Value: $10410.97
# 📊 Step: 61
# 💰 Cash: $3466.75
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 4, 'MSFT': 0, 'TSLA': 18}
# 📉 Total Portfolio Value: $10231.33
# 📊 Step: 62
# 💰 Cash: $3341.60
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 4, 'MSFT': 0, 'TSLA': 18}
# 📉 Total Portfolio Value: $10259.53
# 📊 Step: 63
# 💰 Cash: $2838.86
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 5, 'MSFT': 1, 'TSLA': 17}
# 📉 Total Portfolio Value: $10342.17
# 📊 Step: 64
# 💰 Cash: $2414.72
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 6, 'MSFT': 1, 'TSLA': 17}
# 📉 Total Portfolio Value: $10309.74
# 📊 Step: 65
# 💰 Cash: $2103.57
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 18}
# 📉 Total Portfolio Value: $10211.85
# 📊 Step: 66
# 💰 Cash: $1647.22
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 18}
# 📉 Total Portfolio Value: $10376.90
# 📊 Step: 67
# 💰 Cash: $1837.32
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 7, 'MSFT': 2, 'TSLA': 17}
# 📉 Total Portfolio Value: $10435.94
# 📊 Step: 68
# 💰 Cash: $1885.07
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 17}
# 📉 Total Portfolio Value: $10455.83
# 📊 Step: 69
# 💰 Cash: $1260.34
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 8, 'MSFT': 0, 'TSLA': 17}
# 📉 Total Portfolio Value: $10485.95
# 📊 Step: 70
# 💰 Cash: $1630.95
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 8, 'MSFT': 0, 'TSLA': 16}
# 📉 Total Portfolio Value: $10467.80
# 📊 Step: 71
# 💰 Cash: $1513.78
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 8, 'MSFT': 0, 'TSLA': 17}
# 📉 Total Portfolio Value: $10572.88
# 📊 Step: 72
# 💰 Cash: $671.76
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 9, 'MSFT': 1, 'TSLA': 18}
# 📉 Total Portfolio Value: $10632.66
# 📊 Step: 73
# 💰 Cash: $591.28
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 9, 'MSFT': 0, 'TSLA': 18}
# 📉 Total Portfolio Value: $10639.76
# 📊 Step: 74
# 💰 Cash: $472.72
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 9, 'MSFT': 0, 'TSLA': 19}
# 📉 Total Portfolio Value: $10632.18
# 📊 Step: 75
# 💰 Cash: $1139.07
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 8, 'MSFT': 0, 'TSLA': 18}
# 📉 Total Portfolio Value: $10607.75
# 📊 Step: 76
# 💰 Cash: $586.56
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 9, 'MSFT': 0, 'TSLA': 18}
# 📉 Total Portfolio Value: $10675.96
# 📊 Step: 77
# 💰 Cash: $963.57
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 9, 'MSFT': 0, 'TSLA': 17}
# 📉 Total Portfolio Value: $10695.82
# 📊 Step: 78
# 💰 Cash: $1096.11
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 9, 'MSFT': 0, 'TSLA': 17}
# 📉 Total Portfolio Value: $10616.42
# 📊 Step: 79
# 💰 Cash: $678.54
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 10, 'MSFT': 0, 'TSLA': 17}
# 📉 Total Portfolio Value: $10691.44
# 📊 Step: 80
# 💰 Cash: $8.91
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 11, 'MSFT': 0, 'TSLA': 18}
# 📉 Total Portfolio Value: $10762.77
# 📊 Step: 81
# 💰 Cash: $140.69
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 11, 'MSFT': 0, 'TSLA': 18}
# 📉 Total Portfolio Value: $10653.61
# 📊 Step: 82
# 💰 Cash: $258.07
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 10, 'MSFT': 1, 'TSLA': 19}
# 📉 Total Portfolio Value: $10667.48
# 📊 Step: 83
# 💰 Cash: $258.07
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 10, 'MSFT': 1, 'TSLA': 19}
# 📉 Total Portfolio Value: $10693.10
# 📊 Step: 84
# 💰 Cash: $941.98
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 9, 'MSFT': 1, 'TSLA': 19}
# 📉 Total Portfolio Value: $10717.25
# 📊 Step: 85
# 💰 Cash: $1699.41
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 8, 'MSFT': 2, 'TSLA': 18}
# 📉 Total Portfolio Value: $10632.21
# 📊 Step: 86
# 💰 Cash: $1829.46
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 3, 'TSLA': 19}
# 📉 Total Portfolio Value: $10676.90
# 📊 Step: 87
# 💰 Cash: $1405.53
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 7, 'MSFT': 4, 'TSLA': 20}
# 📉 Total Portfolio Value: $10774.21
# 📊 Step: 88
# 💰 Cash: $523.69
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 8, 'MSFT': 3, 'TSLA': 21}
# 📉 Total Portfolio Value: $10756.18
# 📊 Step: 89
# 💰 Cash: $779.69
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 8, 'MSFT': 3, 'TSLA': 20}
# 📉 Total Portfolio Value: $10740.96
# 📊 Step: 90
# 💰 Cash: $704.48
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 8, 'MSFT': 2, 'TSLA': 21}
# 📉 Total Portfolio Value: $10734.47
# 📊 Step: 91
# 💰 Cash: $329.47
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 9, 'MSFT': 1, 'TSLA': 21}
# 📉 Total Portfolio Value: $10694.33
# 📊 Step: 92
# 💰 Cash: $453.11
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 8, 'MSFT': 2, 'TSLA': 22}
# 📉 Total Portfolio Value: $10650.26
# 📊 Step: 93
# 💰 Cash: $284.17
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 8, 'MSFT': 3, 'TSLA': 23}
# 📉 Total Portfolio Value: $10729.98
# 📊 Step: 94
# 💰 Cash: $703.52
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 3, 'TSLA': 24}
# 📉 Total Portfolio Value: $10917.47
# 📊 Step: 95
# 💰 Cash: $371.36
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 8, 'MSFT': 4, 'TSLA': 23}
# 📉 Total Portfolio Value: $11031.15
# 📊 Step: 96
# 💰 Cash: $1142.71
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 5, 'TSLA': 22}
# 📉 Total Portfolio Value: $11051.07
# 📊 Step: 97
# 💰 Cash: $1324.72
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 4, 'TSLA': 21}
# 📉 Total Portfolio Value: $11010.60
# 📊 Step: 98
# 💰 Cash: $1370.95
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 3, 'TSLA': 21}
# 📉 Total Portfolio Value: $11200.51
# 📊 Step: 99
# 💰 Cash: $2247.92
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 6, 'MSFT': 2, 'TSLA': 20}
# 📉 Total Portfolio Value: $11122.12
# 📊 Step: 100
# 💰 Cash: $1341.71
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 21}
# 📉 Total Portfolio Value: $11192.60
# 📊 Step: 101
# 💰 Cash: $2341.60
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 20}
# 📉 Total Portfolio Value: $11128.51
# 📊 Step: 102
# 💰 Cash: $2735.44
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 19}
# 📉 Total Portfolio Value: $10961.32
# 📊 Step: 103
# 💰 Cash: $2473.42
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 20}
# 📉 Total Portfolio Value: $11078.85
# 📊 Step: 104
# 💰 Cash: $2745.20
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $11113.85
# 📊 Step: 105
# 💰 Cash: $2471.05
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 20}
# 📉 Total Portfolio Value: $11355.49
# 📊 Step: 106
# 💰 Cash: $3018.39
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 0, 'TSLA': 20}
# 📉 Total Portfolio Value: $11340.89
# 📊 Step: 107
# 💰 Cash: $2892.39
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 5, 'MSFT': 0, 'TSLA': 20}
# 📉 Total Portfolio Value: $11125.83
# 📊 Step: 108
# 💰 Cash: $2610.24
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 19}
# 📉 Total Portfolio Value: $10827.25
# 📊 Step: 109
# 💰 Cash: $1813.58
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 0, 'TSLA': 20}
# 📉 Total Portfolio Value: $10904.60
# 📊 Step: 110
# 💰 Cash: $1526.85
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 8, 'MSFT': 0, 'TSLA': 19}
# 📉 Total Portfolio Value: $11022.85
# 📊 Step: 111
# 💰 Cash: $1358.96
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 8, 'MSFT': 1, 'TSLA': 19}
# 📉 Total Portfolio Value: $11210.70
# 📊 Step: 112
# 💰 Cash: $2056.35
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 19}
# 📉 Total Portfolio Value: $11364.19
# 📊 Step: 113
# 💰 Cash: $1930.74
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 19}
# 📉 Total Portfolio Value: $11317.52
# 📊 Step: 114
# 💰 Cash: $2904.66
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 6, 'MSFT': 1, 'TSLA': 18}
# 📉 Total Portfolio Value: $11490.75
# 📊 Step: 115
# 💰 Cash: $3089.49
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 17}
# 📉 Total Portfolio Value: $12215.67
# 📊 Step: 116
# 💰 Cash: $2213.63
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 17}
# 📉 Total Portfolio Value: $12305.06
# 📊 Step: 117
# 💰 Cash: $2756.28
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 1, 'TSLA': 18}
# 📉 Total Portfolio Value: $12039.02
# 📊 Step: 118
# 💰 Cash: $3582.38
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 5, 'MSFT': 1, 'TSLA': 18}
# 📉 Total Portfolio Value: $12050.30
# 📊 Step: 119
# 💰 Cash: $3189.29
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 5, 'MSFT': 1, 'TSLA': 19}
# 📉 Total Portfolio Value: $11936.17
# 📊 Step: 120
# 💰 Cash: $2685.83
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 19}
# 📉 Total Portfolio Value: $11781.74
# 📊 Step: 121
# 💰 Cash: $2826.74
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 18}
# 📉 Total Portfolio Value: $11576.08
# 📊 Step: 122
# 💰 Cash: $2038.23
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 0, 'TSLA': 19}
# 📉 Total Portfolio Value: $11810.81
# 📊 Step: 123
# 💰 Cash: $2264.35
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 1, 'TSLA': 20}
# 📉 Total Portfolio Value: $11801.60
# 📊 Step: 124
# 💰 Cash: $2046.82
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $11881.51
# 📊 Step: 125
# 💰 Cash: $1610.78
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 6, 'MSFT': 1, 'TSLA': 22}
# 📉 Total Portfolio Value: $11821.67
# 📊 Step: 126
# 💰 Cash: $1387.43
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 7, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $11737.14
# 📊 Step: 127
# 💰 Cash: $1054.33
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 8, 'MSFT': 1, 'TSLA': 20}
# 📉 Total Portfolio Value: $11832.35
# 📊 Step: 128
# 💰 Cash: $1763.15
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 0, 'TSLA': 20}
# 📉 Total Portfolio Value: $11994.18
# 📊 Step: 129
# 💰 Cash: $1608.42
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $11468.20
# 📊 Step: 130
# 💰 Cash: $2032.44
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 22}
# 📉 Total Portfolio Value: $11354.00
# 📊 Step: 131
# 💰 Cash: $1789.93
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $11314.99
# 📊 Step: 132
# 💰 Cash: $2453.07
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $11364.08
# 📊 Step: 133
# 💰 Cash: $3143.37
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 4, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $11387.16
# 📊 Step: 134
# 💰 Cash: $3028.13
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 4, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $11467.05
# 📊 Step: 135
# 💰 Cash: $2912.98
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 4, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $11494.83
# 📊 Step: 136
# 💰 Cash: $2912.98
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 4, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $11788.51
# 📊 Step: 137
# 💰 Cash: $2309.38
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 5, 'MSFT': 1, 'TSLA': 22}
# 📉 Total Portfolio Value: $11885.64
# 📊 Step: 138
# 💰 Cash: $1407.20
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $11787.22
# 📊 Step: 139
# 💰 Cash: $1266.96
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 24}
# 📉 Total Portfolio Value: $11381.46
# 📊 Step: 140
# 💰 Cash: $829.66
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 7, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $10857.10
# 📊 Step: 141
# 💰 Cash: $79.87
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 8, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $10368.12
# 📊 Step: 142
# 💰 Cash: $79.87
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 8, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $10351.54
# 📊 Step: 143
# 💰 Cash: $431.84
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 24}
# 📉 Total Portfolio Value: $10817.96
# 📊 Step: 144
# 💰 Cash: $1164.02
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 6, 'MSFT': 2, 'TSLA': 23}
# 📉 Total Portfolio Value: $11300.03
# 📊 Step: 145
# 💰 Cash: $1563.83
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 6, 'MSFT': 1, 'TSLA': 22}
# 📉 Total Portfolio Value: $11372.33
# 📊 Step: 146
# 💰 Cash: $2132.26
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 5, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $11325.26
# 📊 Step: 147
# 💰 Cash: $2245.02
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 5, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $10989.03
# 📊 Step: 148
# 💰 Cash: $1856.85
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 5, 'MSFT': 1, 'TSLA': 24}
# 📉 Total Portfolio Value: $11294.00
# 📊 Step: 149
# 💰 Cash: $1764.86
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 5, 'MSFT': 0, 'TSLA': 25}
# 📉 Total Portfolio Value: $11199.73
# 📊 Step: 150
# 💰 Cash: $2603.98
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 4, 'MSFT': 1, 'TSLA': 24}
# 📉 Total Portfolio Value: $11078.02
# 📊 Step: 151
# 💰 Cash: $3033.62
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 3, 'MSFT': 0, 'TSLA': 25}
# 📉 Total Portfolio Value: $11281.82
# 📊 Step: 152
# 💰 Cash: $3565.19
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 2, 'MSFT': 0, 'TSLA': 25}
# 📉 Total Portfolio Value: $11295.06
# 📊 Step: 153
# 💰 Cash: $2768.56
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 3, 'MSFT': 1, 'TSLA': 25}
# 📉 Total Portfolio Value: $11314.80
# 📊 Step: 154
# 💰 Cash: $2947.76
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 3, 'MSFT': 0, 'TSLA': 24}
# 📉 Total Portfolio Value: $11376.26
# 📊 Step: 155
# 💰 Cash: $3853.30
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 2, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $11442.85
# 📊 Step: 156
# 💰 Cash: $4831.23
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 22}
# 📉 Total Portfolio Value: $11467.66
# 📊 Step: 157
# 💰 Cash: $5656.56
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 22}
# 📉 Total Portfolio Value: $11658.88
# 📊 Step: 158
# 💰 Cash: $5394.31
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $11649.76
# 📊 Step: 159
# 💰 Cash: $4564.47
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 23}
# 📉 Total Portfolio Value: $11603.48
# 📊 Step: 160
# 💰 Cash: $5442.53
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 22}
# 📉 Total Portfolio Value: $11688.78
# 📊 Step: 161
# 💰 Cash: $5063.12
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 23}
# 📉 Total Portfolio Value: $11606.14
# 📊 Step: 162
# 💰 Cash: $4846.08
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 24}
# 📉 Total Portfolio Value: $11612.67
# 📊 Step: 163
# 💰 Cash: $5004.27
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 24}
# 📉 Total Portfolio Value: $11664.15
# 📊 Step: 164
# 💰 Cash: $5004.27
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 24}
# 📉 Total Portfolio Value: $11514.24
# 📊 Step: 165
# 💰 Cash: $5375.89
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $11314.66
# 📊 Step: 166
# 💰 Cash: $5263.45
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $11263.58
# 📊 Step: 167
# 💰 Cash: $5082.42
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 24}
# 📉 Total Portfolio Value: $11308.12
# 📊 Step: 168
# 💰 Cash: $4241.02
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 1, 'MSFT': 0, 'TSLA': 25}
# 📉 Total Portfolio Value: $11099.18
# 📊 Step: 169
# 💰 Cash: $4883.02
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 25}
# 📉 Total Portfolio Value: $11293.03
# 📊 Step: 170
# 💰 Cash: $4043.27
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 26}
# 📉 Total Portfolio Value: $11272.26
# 📊 Step: 171
# 💰 Cash: $3843.75
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 1, 'MSFT': 0, 'TSLA': 27}
# 📉 Total Portfolio Value: $11146.12
# 📊 Step: 172
# 💰 Cash: $4273.93
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 28}
# 📉 Total Portfolio Value: $10879.59
# 📊 Step: 173
# 💰 Cash: $4116.35
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 28}
# 📉 Total Portfolio Value: $10730.96
# 📊 Step: 174
# 💰 Cash: $3959.40
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 28}
# 📉 Total Portfolio Value: $10569.30
# 📊 Step: 175
# 💰 Cash: $4071.52
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 28}
# 📉 Total Portfolio Value: $10424.96
# 📊 Step: 176
# 💰 Cash: $4014.54
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 29}
# 📉 Total Portfolio Value: $10531.47
# 📊 Step: 177
# 💰 Cash: $4345.58
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 28}
# 📉 Total Portfolio Value: $10464.90
# 📊 Step: 178
# 💰 Cash: $4175.38
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 29}
# 📉 Total Portfolio Value: $10593.37
# 📊 Step: 179
# 💰 Cash: $3795.20
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 30}
# 📉 Total Portfolio Value: $10764.05
# 📊 Step: 180
# 💰 Cash: $3747.69
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 30}
# 📉 Total Portfolio Value: $10797.66
# 📊 Step: 181
# 💰 Cash: $3211.73
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 29}
# 📉 Total Portfolio Value: $10344.91
# 📊 Step: 182
# 💰 Cash: $4170.76
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 28}
# 📉 Total Portfolio Value: $10261.44
# 📊 Step: 183
# 💰 Cash: $4284.52
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 28}
# 📉 Total Portfolio Value: $10308.74
# 📊 Step: 184
# 💰 Cash: $3863.13
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 27}
# 📉 Total Portfolio Value: $10280.76
# 📊 Step: 185
# 💰 Cash: $3090.93
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 2, 'TSLA': 27}
# 📉 Total Portfolio Value: $10473.69
# 📊 Step: 186
# 💰 Cash: $3306.19
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 2, 'TSLA': 26}
# 📉 Total Portfolio Value: $10348.31
# 📊 Step: 187
# 💰 Cash: $4039.01
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 1, 'MSFT': 2, 'TSLA': 26}
# 📉 Total Portfolio Value: $10420.85
# 📊 Step: 188
# 💰 Cash: $3182.82
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 2, 'MSFT': 2, 'TSLA': 26}
# 📉 Total Portfolio Value: $10402.15
# 📊 Step: 189
# 💰 Cash: $3595.51
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 1, 'MSFT': 2, 'TSLA': 27}
# 📉 Total Portfolio Value: $10264.29
# 📊 Step: 190
# 💰 Cash: $2770.69
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 2, 'MSFT': 2, 'TSLA': 28}
# 📉 Total Portfolio Value: $10479.95
# 📊 Step: 191
# 💰 Cash: $3450.49
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 28}
# 📉 Total Portfolio Value: $10332.40
# 📊 Step: 192
# 💰 Cash: $3382.07
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 1, 'MSFT': 0, 'TSLA': 28}
# 📉 Total Portfolio Value: $10989.02
# 📊 Step: 193
# 💰 Cash: $2572.36
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 2, 'MSFT': 1, 'TSLA': 28}
# 📉 Total Portfolio Value: $11000.40
# 📊 Step: 194
# 💰 Cash: $2870.67
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 2, 'MSFT': 2, 'TSLA': 27}
# 📉 Total Portfolio Value: $11019.55
# 📊 Step: 195
# 💰 Cash: $3798.49
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 26}
# 📉 Total Portfolio Value: $10827.71
# 📊 Step: 196
# 💰 Cash: $4090.23
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 1, 'MSFT': 2, 'TSLA': 25}
# 📉 Total Portfolio Value: $10601.55
# 📊 Step: 197
# 💰 Cash: $3919.95
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 1, 'MSFT': 3, 'TSLA': 25}
# 📉 Total Portfolio Value: $10671.48
# 📊 Step: 198
# 💰 Cash: $4904.28
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 24}
# 📉 Total Portfolio Value: $10521.96
# 📊 Step: 199
# 💰 Cash: $4948.18
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 23}
# 📉 Total Portfolio Value: $10374.27
# 📊 Step: 200
# 💰 Cash: $4362.46
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 1, 'MSFT': 5, 'TSLA': 22}
# 📉 Total Portfolio Value: $10553.22
# 📊 Step: 201
# 💰 Cash: $3712.17
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 2, 'MSFT': 5, 'TSLA': 21}
# 📉 Total Portfolio Value: $10531.43
# 📊 Step: 202
# 💰 Cash: $3812.48
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 2, 'MSFT': 5, 'TSLA': 20}
# 📉 Total Portfolio Value: $10726.89
# 📊 Step: 203
# 💰 Cash: $3336.98
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 3, 'MSFT': 6, 'TSLA': 19}
# 📉 Total Portfolio Value: $10748.54
# 📊 Step: 204
# 💰 Cash: $4264.78
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 2, 'MSFT': 7, 'TSLA': 18}
# 📉 Total Portfolio Value: $10754.79
# 📊 Step: 205
# 💰 Cash: $3761.98
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 3, 'MSFT': 6, 'TSLA': 17}
# 📉 Total Portfolio Value: $10707.72
# 📊 Step: 206
# 💰 Cash: $4702.24
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 2, 'MSFT': 7, 'TSLA': 16}
# 📉 Total Portfolio Value: $10707.65
# 📊 Step: 207
# 💰 Cash: $4429.74
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 2, 'MSFT': 8, 'TSLA': 17}
# 📉 Total Portfolio Value: $10891.81
# 📊 Step: 208
# 💰 Cash: $4135.76
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 2, 'MSFT': 7, 'TSLA': 18}
# 📉 Total Portfolio Value: $10933.05
# 📊 Step: 209
# 💰 Cash: $4504.38
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 1, 'MSFT': 8, 'TSLA': 19}
# 📉 Total Portfolio Value: $10905.07
# 📊 Step: 210
# 💰 Cash: $3795.88
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 2, 'MSFT': 7, 'TSLA': 19}
# 📉 Total Portfolio Value: $11077.99
# 📊 Step: 211
# 💰 Cash: $4752.23
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 1, 'MSFT': 6, 'TSLA': 19}
# 📉 Total Portfolio Value: $10966.83
# 📊 Step: 212
# 💰 Cash: $3802.89
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 2, 'MSFT': 7, 'TSLA': 19}
# 📉 Total Portfolio Value: $10946.58
# 📊 Step: 213
# 💰 Cash: $3382.60
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 3, 'MSFT': 7, 'TSLA': 18}
# 📉 Total Portfolio Value: $10972.62
# 📊 Step: 214
# 💰 Cash: $3319.48
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 3, 'MSFT': 6, 'TSLA': 18}
# 📉 Total Portfolio Value: $10961.61
# 📊 Step: 215
# 💰 Cash: $2315.36
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 4, 'MSFT': 6, 'TSLA': 19}
# 📉 Total Portfolio Value: $10885.95
# 📊 Step: 216
# 💰 Cash: $3152.94
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 3, 'MSFT': 7, 'TSLA': 19}
# 📉 Total Portfolio Value: $10785.05
# 📊 Step: 217
# 💰 Cash: $4086.09
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 2, 'MSFT': 6, 'TSLA': 19}
# 📉 Total Portfolio Value: $10832.97
# 📊 Step: 218
# 💰 Cash: $4563.79
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 1, 'MSFT': 7, 'TSLA': 20}
# 📉 Total Portfolio Value: $10598.93
# 📊 Step: 219
# 💰 Cash: $4450.61
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 1, 'MSFT': 7, 'TSLA': 20}
# 📉 Total Portfolio Value: $10645.61
# 📊 Step: 220
# 💰 Cash: $3520.45
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 2, 'MSFT': 8, 'TSLA': 20}
# 📉 Total Portfolio Value: $10677.46
# 📊 Step: 221
# 💰 Cash: $2539.27
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 3, 'MSFT': 8, 'TSLA': 21}
# 📉 Total Portfolio Value: $11022.17
# 📊 Step: 222
# 💰 Cash: $1941.06
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 4, 'MSFT': 9, 'TSLA': 20}
# 📉 Total Portfolio Value: $10952.34
# 📊 Step: 223
# 💰 Cash: $2312.82
# 📈 Holdings: {'AAPL': 8, 'GOOGL': 3, 'MSFT': 10, 'TSLA': 21}
# 📉 Total Portfolio Value: $10812.57
# 📊 Step: 224
# 💰 Cash: $2963.64
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 2, 'MSFT': 10, 'TSLA': 21}
# 📉 Total Portfolio Value: $10883.27
# 📊 Step: 225
# 💰 Cash: $2382.90
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 3, 'MSFT': 9, 'TSLA': 20}
# 📉 Total Portfolio Value: $10853.74
# 📊 Step: 226
# 💰 Cash: $2152.95
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 3, 'MSFT': 9, 'TSLA': 21}
# 📉 Total Portfolio Value: $10870.66
# 📊 Step: 227
# 💰 Cash: $1098.92
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 4, 'MSFT': 10, 'TSLA': 22}
# 📉 Total Portfolio Value: $10871.82
# 📊 Step: 228
# 💰 Cash: $2259.03
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 3, 'MSFT': 9, 'TSLA': 21}
# 📉 Total Portfolio Value: $10878.63
# 📊 Step: 229
# 💰 Cash: $2152.21
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 3, 'MSFT': 9, 'TSLA': 21}
# 📉 Total Portfolio Value: $11111.43
# 📊 Step: 230
# 💰 Cash: $1466.99
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 4, 'MSFT': 9, 'TSLA': 21}
# 📉 Total Portfolio Value: $11100.75
# 📊 Step: 231
# 💰 Cash: $2439.07
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 3, 'MSFT': 10, 'TSLA': 20}
# 📉 Total Portfolio Value: $11075.44
# 📊 Step: 232
# 💰 Cash: $2149.28
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 3, 'MSFT': 9, 'TSLA': 21}
# 📉 Total Portfolio Value: $10665.91
# 📊 Step: 233
# 💰 Cash: $1284.49
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 4, 'MSFT': 9, 'TSLA': 21}
# 📉 Total Portfolio Value: $10647.90
# 📊 Step: 234
# 💰 Cash: $1980.35
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 3, 'MSFT': 8, 'TSLA': 22}
# 📉 Total Portfolio Value: $10516.62
# 📊 Step: 235
# 💰 Cash: $1321.72
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 4, 'MSFT': 8, 'TSLA': 22}
# 📉 Total Portfolio Value: $10315.43
# 📊 Step: 236
# 💰 Cash: $580.72
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 5, 'MSFT': 8, 'TSLA': 22}
# 📉 Total Portfolio Value: $10168.55
# 📊 Step: 237
# 💰 Cash: $1056.00
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 4, 'MSFT': 7, 'TSLA': 23}
# 📉 Total Portfolio Value: $10120.23
# 📊 Step: 238
# 💰 Cash: $2147.75
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 3, 'MSFT': 6, 'TSLA': 22}
# 📉 Total Portfolio Value: $10219.43
# 📊 Step: 239
# 💰 Cash: $1402.41
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 4, 'MSFT': 6, 'TSLA': 22}
# 📉 Total Portfolio Value: $9873.86
# 📊 Step: 240
# 💰 Cash: $1247.85
# 📈 Holdings: {'AAPL': 8, 'GOOGL': 4, 'MSFT': 7, 'TSLA': 23}
# 📉 Total Portfolio Value: $10083.48
# 📊 Step: 241
# 💰 Cash: $1979.24
# 📈 Holdings: {'AAPL': 8, 'GOOGL': 3, 'MSFT': 7, 'TSLA': 23}
# 📉 Total Portfolio Value: $9959.45
# 📊 Step: 242
# 💰 Cash: $2632.86
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 2, 'MSFT': 6, 'TSLA': 24}
# 📉 Total Portfolio Value: $9964.28
# 📊 Step: 243
# 💰 Cash: $2582.30
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 2, 'MSFT': 7, 'TSLA': 24}
# 📉 Total Portfolio Value: $9821.28
# 📊 Step: 244
# 💰 Cash: $3448.77
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 1, 'MSFT': 8, 'TSLA': 23}
# 📉 Total Portfolio Value: $9852.69
# 📊 Step: 245
# 💰 Cash: $2972.55
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 2, 'MSFT': 7, 'TSLA': 22}
# 📉 Total Portfolio Value: $9995.54
# 📊 Step: 246
# 💰 Cash: $2076.83
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 3, 'MSFT': 6, 'TSLA': 23}
# 📉 Total Portfolio Value: $9801.25
# 📊 Step: 247
# 💰 Cash: $2025.04
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 3, 'MSFT': 7, 'TSLA': 23}
# 📉 Total Portfolio Value: $9743.41
# 📊 Step: 248
# 💰 Cash: $2517.45
# 📈 Holdings: {'AAPL': 8, 'GOOGL': 2, 'MSFT': 6, 'TSLA': 24}
# 📉 Total Portfolio Value: $9520.97
# 📊 Step: 249
# 💰 Cash: $1756.44
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 3, 'MSFT': 5, 'TSLA': 25}
# 📉 Total Portfolio Value: $9662.75
# 📊 Step: 250
# 💰 Cash: $860.48
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 4, 'MSFT': 6, 'TSLA': 26}
# 📉 Total Portfolio Value: $9791.66
# 📊 Step: 251
# 💰 Cash: $1813.03
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 3, 'MSFT': 6, 'TSLA': 25}
# 📉 Total Portfolio Value: $9955.68
# 📊 Step: 252
# 💰 Cash: $1854.75
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 3, 'MSFT': 7, 'TSLA': 25}
# 📉 Total Portfolio Value: $9610.38
# 📊 Step: 253
# 💰 Cash: $1038.54
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 4, 'MSFT': 6, 'TSLA': 26}
# 📉 Total Portfolio Value: $9244.90
# 📊 Step: 254
# 💰 Cash: $1917.21
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 3, 'MSFT': 5, 'TSLA': 25}
# 📉 Total Portfolio Value: $9233.55
# 📊 Step: 255
# 💰 Cash: $1961.81
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 3, 'MSFT': 6, 'TSLA': 25}
# 📉 Total Portfolio Value: $8815.13
# 📊 Step: 256
# 💰 Cash: $2571.55
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 2, 'MSFT': 6, 'TSLA': 25}
# 📉 Total Portfolio Value: $8451.13
# 📊 Step: 257
# 💰 Cash: $1669.99
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 3, 'MSFT': 7, 'TSLA': 26}
# 📉 Total Portfolio Value: $8447.46
# 📊 Step: 258
# 💰 Cash: $2367.03
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 2, 'MSFT': 6, 'TSLA': 27}
# 📉 Total Portfolio Value: $8335.16
# 📊 Step: 259
# 💰 Cash: $2416.74
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 2, 'MSFT': 5, 'TSLA': 27}
# 📉 Total Portfolio Value: $8515.40
# 📊 Step: 260
# 💰 Cash: $1954.55
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 3, 'MSFT': 5, 'TSLA': 26}
# 📉 Total Portfolio Value: $8536.73
# 📊 Step: 261
# 💰 Cash: $2553.89
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 2, 'MSFT': 6, 'TSLA': 27}
# 📉 Total Portfolio Value: $8678.58
# 📊 Step: 262
# 💰 Cash: $2139.15
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 3, 'MSFT': 5, 'TSLA': 26}
# 📉 Total Portfolio Value: $9080.96
# 📊 Step: 263
# 💰 Cash: $2458.37
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 3, 'MSFT': 4, 'TSLA': 25}
# 📉 Total Portfolio Value: $8988.91
# 📊 Step: 264
# 💰 Cash: $3246.39
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 2, 'MSFT': 4, 'TSLA': 24}
# 📉 Total Portfolio Value: $8991.85
# 📊 Step: 265
# 💰 Cash: $3227.67
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 3, 'TSLA': 25}
# 📉 Total Portfolio Value: $9287.22
# 📊 Step: 266
# 💰 Cash: $3102.58
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 2, 'TSLA': 26}
# 📉 Total Portfolio Value: $9246.98
# 📊 Step: 267
# 💰 Cash: $2976.55
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 1, 'TSLA': 27}
# 📉 Total Portfolio Value: $9302.71
# 📊 Step: 268
# 💰 Cash: $3748.81
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 1, 'MSFT': 0, 'TSLA': 27}
# 📉 Total Portfolio Value: $9538.54
# 📊 Step: 269
# 💰 Cash: $2967.59
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 1, 'TSLA': 27}
# 📉 Total Portfolio Value: $9607.79
# 📊 Step: 270
# 💰 Cash: $2433.07
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 3, 'MSFT': 1, 'TSLA': 26}
# 📉 Total Portfolio Value: $9625.79
# 📊 Step: 271
# 💰 Cash: $2675.88
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 3, 'MSFT': 0, 'TSLA': 25}
# 📉 Total Portfolio Value: $9561.14
# 📊 Step: 272
# 💰 Cash: $2120.06
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 4, 'MSFT': 0, 'TSLA': 24}
# 📉 Total Portfolio Value: $9598.14
# 📊 Step: 273
# 💰 Cash: $1226.88
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 5, 'MSFT': 1, 'TSLA': 24}
# 📉 Total Portfolio Value: $9736.44
# 📊 Step: 274
# 💰 Cash: $250.40
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 25}
# 📉 Total Portfolio Value: $9863.74
# 📊 Step: 275
# 💰 Cash: $147.39
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 25}
# 📉 Total Portfolio Value: $9862.05
# 📊 Step: 276
# 💰 Cash: $603.87
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 5, 'MSFT': 1, 'TSLA': 26}
# 📉 Total Portfolio Value: $9793.86
# 📊 Step: 277
# 💰 Cash: $1418.97
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 4, 'MSFT': 1, 'TSLA': 25}
# 📉 Total Portfolio Value: $9995.93
# 📊 Step: 278
# 💰 Cash: $1675.97
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 4, 'MSFT': 2, 'TSLA': 24}
# 📉 Total Portfolio Value: $9936.58
# 📊 Step: 279
# 💰 Cash: $1930.27
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 4, 'MSFT': 3, 'TSLA': 23}
# 📉 Total Portfolio Value: $10045.98
# 📊 Step: 280
# 💰 Cash: $1392.90
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 5, 'MSFT': 3, 'TSLA': 22}
# 📉 Total Portfolio Value: $10241.95
# 📊 Step: 281
# 💰 Cash: $755.29
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 6, 'MSFT': 3, 'TSLA': 21}
# 📉 Total Portfolio Value: $10318.36
# 📊 Step: 282
# 💰 Cash: $1452.27
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 5, 'MSFT': 4, 'TSLA': 21}
# 📉 Total Portfolio Value: $10434.91
# 📊 Step: 283
# 💰 Cash: $1619.85
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 5, 'MSFT': 5, 'TSLA': 20}
# 📉 Total Portfolio Value: $10530.55
# 📊 Step: 284
# 💰 Cash: $795.45
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 4, 'TSLA': 21}
# 📉 Total Portfolio Value: $10641.25
# 📊 Step: 285
# 💰 Cash: $848.94
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 3, 'TSLA': 21}
# 📉 Total Portfolio Value: $10800.02
# 📊 Step: 286
# 💰 Cash: $246.55
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 2, 'TSLA': 21}
# 📉 Total Portfolio Value: $10700.80
# 📊 Step: 287
# 💰 Cash: $1294.91
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 6, 'MSFT': 1, 'TSLA': 20}
# 📉 Total Portfolio Value: $10451.97
# 📊 Step: 288
# 💰 Cash: $599.83
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 7, 'MSFT': 2, 'TSLA': 19}
# 📉 Total Portfolio Value: $10530.72
# 📊 Step: 289
# 💰 Cash: $477.75
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 2, 'TSLA': 20}
# 📉 Total Portfolio Value: $10568.18
# 📊 Step: 290
# 💰 Cash: $406.22
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 21}
# 📉 Total Portfolio Value: $10654.89
# 📊 Step: 291
# 💰 Cash: $1119.14
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $10603.43
# 📊 Step: 292
# 💰 Cash: $577.69
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 0, 'TSLA': 20}
# 📉 Total Portfolio Value: $10622.38
# 📊 Step: 293
# 💰 Cash: $238.93
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 7, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $10835.99
# 📊 Step: 294
# 💰 Cash: $476.52
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 7, 'MSFT': 0, 'TSLA': 20}
# 📉 Total Portfolio Value: $10994.40
# 📊 Step: 295
# 💰 Cash: $1488.63
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 19}
# 📉 Total Portfolio Value: $11113.60
# 📊 Step: 296
# 💰 Cash: $1881.92
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 5, 'MSFT': 0, 'TSLA': 20}
# 📉 Total Portfolio Value: $11363.55
# 📊 Step: 297
# 💰 Cash: $737.47
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $11133.55
# 📊 Step: 298
# 💰 Cash: $534.35
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 6, 'MSFT': 1, 'TSLA': 22}
# 📉 Total Portfolio Value: $10973.10
# 📊 Step: 299
# 💰 Cash: $392.94
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 1, 'TSLA': 23}
# 📉 Total Portfolio Value: $10958.69
# 📊 Step: 300
# 💰 Cash: $955.27
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 5, 'MSFT': 2, 'TSLA': 24}
# 📉 Total Portfolio Value: $10944.29
# 📊 Step: 301
# 💰 Cash: $817.89
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 2, 'TSLA': 25}
# 📉 Total Portfolio Value: $11151.39
# 📊 Step: 302
# 💰 Cash: $618.71
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 1, 'TSLA': 26}
# 📉 Total Portfolio Value: $11099.38
# 📊 Step: 303
# 💰 Cash: $422.21
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 0, 'TSLA': 27}
# 📉 Total Portfolio Value: $11193.98
# 📊 Step: 304
# 💰 Cash: $511.22
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 5, 'MSFT': 1, 'TSLA': 26}
# 📉 Total Portfolio Value: $11214.44
# 📊 Step: 305
# 💰 Cash: $364.82
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 1, 'TSLA': 27}
# 📉 Total Portfolio Value: $10981.45
# 📊 Step: 306
# 💰 Cash: $308.43
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 2, 'TSLA': 27}
# 📉 Total Portfolio Value: $11043.40
# 📊 Step: 307
# 💰 Cash: $308.43
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 2, 'TSLA': 27}
# 📉 Total Portfolio Value: $11023.82
# 📊 Step: 308
# 💰 Cash: $364.21
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 1, 'TSLA': 27}
# 📉 Total Portfolio Value: $10956.09
# 📊 Step: 309
# 💰 Cash: $58.68
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 2, 'TSLA': 28}
# 📉 Total Portfolio Value: $10924.91
# 📊 Step: 310
# 💰 Cash: $6.57
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 3, 'TSLA': 28}
# 📉 Total Portfolio Value: $10892.46
# 📊 Step: 311
# 💰 Cash: $260.31
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 3, 'TSLA': 27}
# 📉 Total Portfolio Value: $10810.12
# 📊 Step: 312
# 💰 Cash: $981.77
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 4, 'MSFT': 3, 'TSLA': 27}
# 📉 Total Portfolio Value: $10639.88
# 📊 Step: 313
# 💰 Cash: $226.81
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 4, 'TSLA': 27}
# 📉 Total Portfolio Value: $10466.21
# 📊 Step: 314
# 💰 Cash: $417.70
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 5, 'TSLA': 26}
# 📉 Total Portfolio Value: $10529.60
# 📊 Step: 315
# 💰 Cash: $839.70
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 4, 'MSFT': 6, 'TSLA': 27}
# 📉 Total Portfolio Value: $10244.78
# 📊 Step: 316
# 💰 Cash: $1548.14
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 3, 'MSFT': 6, 'TSLA': 27}
# 📉 Total Portfolio Value: $9990.59
# 📊 Step: 317
# 💰 Cash: $836.77
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 4, 'MSFT': 6, 'TSLA': 27}
# 📉 Total Portfolio Value: $9706.56
# 📊 Step: 318
# 💰 Cash: $333.59
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 6, 'TSLA': 26}
# 📉 Total Portfolio Value: $9850.01
# 📊 Step: 319
# 💰 Cash: $118.66
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 6, 'TSLA': 27}
# 📉 Total Portfolio Value: $9705.57
# 📊 Step: 320
# 💰 Cash: $118.66
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 6, 'TSLA': 27}
# 📉 Total Portfolio Value: $9756.31
# 📊 Step: 321
# 💰 Cash: $378.37
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 5, 'TSLA': 26}
# 📉 Total Portfolio Value: $9719.33
# 📊 Step: 322
# 💰 Cash: $1057.87
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 4, 'MSFT': 6, 'TSLA': 26}
# 📉 Total Portfolio Value: $9668.49
# 📊 Step: 323
# 💰 Cash: $967.53
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 4, 'MSFT': 6, 'TSLA': 26}
# 📉 Total Portfolio Value: $9661.71
# 📊 Step: 324
# 💰 Cash: $1316.74
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 4, 'MSFT': 5, 'TSLA': 25}
# 📉 Total Portfolio Value: $9704.34
# 📊 Step: 325
# 💰 Cash: $962.74
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 4, 'MSFT': 6, 'TSLA': 26}
# 📉 Total Portfolio Value: $9561.21
# 📊 Step: 326
# 💰 Cash: $1725.91
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 3, 'MSFT': 7, 'TSLA': 26}
# 📉 Total Portfolio Value: $9737.34
# 📊 Step: 327
# 💰 Cash: $1937.08
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 3, 'MSFT': 7, 'TSLA': 25}
# 📉 Total Portfolio Value: $9815.50
# 📊 Step: 328
# 💰 Cash: $956.24
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 4, 'MSFT': 8, 'TSLA': 26}
# 📉 Total Portfolio Value: $9975.32
# 📊 Step: 329
# 💰 Cash: $1847.61
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 3, 'MSFT': 9, 'TSLA': 25}
# 📉 Total Portfolio Value: $9855.13
# 📊 Step: 330
# 💰 Cash: $1080.33
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 4, 'MSFT': 10, 'TSLA': 25}
# 📉 Total Portfolio Value: $9976.10
# 📊 Step: 331
# 💰 Cash: $862.42
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 4, 'MSFT': 10, 'TSLA': 26}
# 📉 Total Portfolio Value: $10045.10
# 📊 Step: 332
# 💰 Cash: $1820.10
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 3, 'MSFT': 10, 'TSLA': 25}
# 📉 Total Portfolio Value: $10177.79
# 📊 Step: 333
# 💰 Cash: $2557.03
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 10, 'TSLA': 25}
# 📉 Total Portfolio Value: $10151.43
# 📊 Step: 334
# 💰 Cash: $1586.39
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 3, 'MSFT': 10, 'TSLA': 26}
# 📉 Total Portfolio Value: $10166.92
# 📊 Step: 335
# 💰 Cash: $890.54
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 4, 'MSFT': 9, 'TSLA': 26}
# 📉 Total Portfolio Value: $10068.59
# 📊 Step: 336
# 💰 Cash: $43.62
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 5, 'MSFT': 9, 'TSLA': 26}
# 📉 Total Portfolio Value: $10027.97
# 📊 Step: 337
# 💰 Cash: $262.58
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 5, 'MSFT': 9, 'TSLA': 25}
# 📉 Total Portfolio Value: $9980.66
# 📊 Step: 338
# 💰 Cash: $141.51
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 9, 'TSLA': 26}
# 📉 Total Portfolio Value: $9998.66
# 📊 Step: 339
# 💰 Cash: $604.39
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 4, 'MSFT': 8, 'TSLA': 27}
# 📉 Total Portfolio Value: $10317.76
# 📊 Step: 340
# 💰 Cash: $273.02
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 4, 'MSFT': 8, 'TSLA': 28}
# 📉 Total Portfolio Value: $10453.50
# 📊 Step: 341
# 💰 Cash: $733.53
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 3, 'MSFT': 7, 'TSLA': 29}
# 📉 Total Portfolio Value: $10272.82
# 📊 Step: 342
# 💰 Cash: $781.56
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 3, 'MSFT': 8, 'TSLA': 29}
# 📉 Total Portfolio Value: $9935.54
# 📊 Step: 343
# 💰 Cash: $682.73
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 3, 'MSFT': 8, 'TSLA': 29}
# 📉 Total Portfolio Value: $9889.74
# 📊 Step: 344
# 💰 Cash: $48.19
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 4, 'MSFT': 8, 'TSLA': 29}
# 📉 Total Portfolio Value: $9808.59
# 📊 Step: 345
# 💰 Cash: $516.65
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 3, 'MSFT': 9, 'TSLA': 30}
# 📉 Total Portfolio Value: $9885.71
# 📊 Step: 346
# 💰 Cash: $1516.23
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 2, 'MSFT': 8, 'TSLA': 29}
# 📉 Total Portfolio Value: $9882.92
# 📊 Step: 347
# 💰 Cash: $2310.47
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 1, 'MSFT': 9, 'TSLA': 28}
# 📉 Total Portfolio Value: $9785.04
# 📊 Step: 348
# 💰 Cash: $1949.54
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 1, 'MSFT': 10, 'TSLA': 29}
# 📉 Total Portfolio Value: $9908.07
# 📊 Step: 349
# 💰 Cash: $1073.78
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 2, 'MSFT': 9, 'TSLA': 30}
# 📉 Total Portfolio Value: $9924.19
# 📊 Step: 350
# 💰 Cash: $905.36
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 2, 'MSFT': 8, 'TSLA': 31}
# 📉 Total Portfolio Value: $9212.88
# 📊 Step: 351
# 💰 Cash: $93.78
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 3, 'MSFT': 8, 'TSLA': 32}
# 📉 Total Portfolio Value: $9226.77
# 📊 Step: 352
# 💰 Cash: $808.65
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 2, 'MSFT': 8, 'TSLA': 32}
# 📉 Total Portfolio Value: $9038.69
# 📊 Step: 353
# 💰 Cash: $951.88
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 2, 'MSFT': 7, 'TSLA': 32}
# 📉 Total Portfolio Value: $9190.85
# 📊 Step: 354
# 💰 Cash: $859.84
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 2, 'MSFT': 7, 'TSLA': 32}
# 📉 Total Portfolio Value: $9326.49
# 📊 Step: 355
# 💰 Cash: $1659.30
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 1, 'MSFT': 7, 'TSLA': 31}
# 📉 Total Portfolio Value: $9601.76
# 📊 Step: 356
# 💰 Cash: $2709.62
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 30}
# 📉 Total Portfolio Value: $9671.84
# 📊 Step: 357
# 💰 Cash: $2665.19
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 30}
# 📉 Total Portfolio Value: $9799.55
# 📊 Step: 358
# 💰 Cash: $3028.74
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 29}
# 📉 Total Portfolio Value: $9723.81
# 📊 Step: 359
# 💰 Cash: $2763.59
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 30}
# 📉 Total Portfolio Value: $9740.28
# 📊 Step: 360
# 💰 Cash: $2453.62
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 31}
# 📉 Total Portfolio Value: $9788.42
# 📊 Step: 361
# 💰 Cash: $1701.80
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 1, 'MSFT': 4, 'TSLA': 31}
# 📉 Total Portfolio Value: $9832.36
# 📊 Step: 362
# 💰 Cash: $1036.32
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 2, 'MSFT': 3, 'TSLA': 31}
# 📉 Total Portfolio Value: $10101.57
# 📊 Step: 363
# 💰 Cash: $1358.08
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 2, 'MSFT': 3, 'TSLA': 30}
# 📉 Total Portfolio Value: $10111.91
# 📊 Step: 364
# 💰 Cash: $894.43
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 3, 'MSFT': 4, 'TSLA': 29}
# 📉 Total Portfolio Value: $10040.89
# 📊 Step: 365
# 💰 Cash: $1943.31
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 2, 'MSFT': 4, 'TSLA': 28}
# 📉 Total Portfolio Value: $10030.29
# 📊 Step: 366
# 💰 Cash: $1997.05
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 2, 'MSFT': 3, 'TSLA': 28}
# 📉 Total Portfolio Value: $9998.17
# 📊 Step: 367
# 💰 Cash: $2908.00
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 1, 'MSFT': 2, 'TSLA': 27}
# 📉 Total Portfolio Value: $10177.36
# 📊 Step: 368
# 💰 Cash: $3833.49
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 26}
# 📉 Total Portfolio Value: $10149.13
# 📊 Step: 369
# 💰 Cash: $4005.66
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 25}
# 📉 Total Portfolio Value: $10238.18
# 📊 Step: 370
# 💰 Cash: $4389.89
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 24}
# 📉 Total Portfolio Value: $10048.15
# 📊 Step: 371
# 💰 Cash: $4455.16
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 23}
# 📉 Total Portfolio Value: $10089.63
# 📊 Step: 372
# 💰 Cash: $3752.45
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 1, 'MSFT': 3, 'TSLA': 23}
# 📉 Total Portfolio Value: $10262.41
# 📊 Step: 373
# 💰 Cash: $3885.12
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 1, 'MSFT': 3, 'TSLA': 22}
# 📉 Total Portfolio Value: $10248.94
# 📊 Step: 374
# 💰 Cash: $4171.39
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 1, 'MSFT': 2, 'TSLA': 21}
# 📉 Total Portfolio Value: $10255.83
# 📊 Step: 375
# 💰 Cash: $4648.68
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 22}
# 📉 Total Portfolio Value: $10308.09
# 📊 Step: 376
# 💰 Cash: $4600.55
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 22}
# 📉 Total Portfolio Value: $10400.34
# 📊 Step: 377
# 💰 Cash: $4422.44
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 23}
# 📉 Total Portfolio Value: $10299.50
# 📊 Step: 378
# 💰 Cash: $4249.01
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 24}
# 📉 Total Portfolio Value: $10224.21
# 📊 Step: 379
# 💰 Cash: $3723.99
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 23}
# 📉 Total Portfolio Value: $10196.21
# 📊 Step: 380
# 💰 Cash: $4134.36
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 24}
# 📉 Total Portfolio Value: $10313.13
# 📊 Step: 381
# 💰 Cash: $4134.36
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 24}
# 📉 Total Portfolio Value: $10308.40
# 📊 Step: 382
# 💰 Cash: $3904.33
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 25}
# 📉 Total Portfolio Value: $10216.30
# 📊 Step: 383
# 💰 Cash: $3149.41
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 1, 'MSFT': 3, 'TSLA': 25}
# 📉 Total Portfolio Value: $10293.73
# 📊 Step: 384
# 💰 Cash: $2869.72
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 1, 'MSFT': 2, 'TSLA': 26}
# 📉 Total Portfolio Value: $10201.15
# 📊 Step: 385
# 💰 Cash: $2003.21
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 2, 'MSFT': 3, 'TSLA': 26}
# 📉 Total Portfolio Value: $10181.82
# 📊 Step: 386
# 💰 Cash: $3036.32
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 1, 'MSFT': 3, 'TSLA': 25}
# 📉 Total Portfolio Value: $10198.34
# 📊 Step: 387
# 💰 Cash: $3960.80
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 24}
# 📉 Total Portfolio Value: $10206.20
# 📊 Step: 388
# 💰 Cash: $3960.80
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 24}
# 📉 Total Portfolio Value: $10156.04
# 📊 Step: 389
# 💰 Cash: $3793.98
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 24}
# 📉 Total Portfolio Value: $10146.52
# 📊 Step: 390
# 💰 Cash: $3960.76
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 24}
# 📉 Total Portfolio Value: $10152.28
# 📊 Step: 391
# 💰 Cash: $4017.59
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 23}
# 📉 Total Portfolio Value: $10188.59
# 📊 Step: 392
# 💰 Cash: $3217.94
# ...
# 📈 Holdings: {'AAPL': 8, 'GOOGL': 4, 'MSFT': 5, 'TSLA': 24}
# 📉 Total Portfolio Value: $14605.09
# 📊 Step: 874
# 💰 Cash: $644.63
# 📈 Holdings: {'AAPL': 8, 'GOOGL': 4, 'MSFT': 4, 'TSLA': 23}
# 📉 Total Portfolio Value: $14426.99
# 📊 Step: 875
# 💰 Cash: $1556.05
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 3, 'MSFT': 5, 'TSLA': 23}
# 📉 Total Portfolio Value: $14446.69
# 📊 Step: 876
# 💰 Cash: $1768.14
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 3, 'MSFT': 4, 'TSLA': 22}
# 📉 Total Portfolio Value: $14779.76
# 📊 Step: 877
# 💰 Cash: $3349.73
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 2, 'MSFT': 3, 'TSLA': 22}
# 📉 Total Portfolio Value: $14743.78
# 📊 Step: 878
# 💰 Cash: $2067.05
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 3, 'MSFT': 4, 'TSLA': 21}
# 📉 Total Portfolio Value: $14407.02
# 📊 Step: 879
# 💰 Cash: $1686.57
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 3, 'MSFT': 3, 'TSLA': 22}
# 📉 Total Portfolio Value: $14165.55
# 📊 Step: 880
# 💰 Cash: $1496.66
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 3, 'MSFT': 3, 'TSLA': 22}
# 📉 Total Portfolio Value: $14339.12
# 📊 Step: 881
# 💰 Cash: $2831.73
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 2, 'MSFT': 3, 'TSLA': 21}
# 📉 Total Portfolio Value: $14553.69
# 📊 Step: 882
# 💰 Cash: $2630.23
# 📈 Holdings: {'AAPL': 14, 'GOOGL': 2, 'MSFT': 3, 'TSLA': 21}
# 📉 Total Portfolio Value: $15679.00
# 📊 Step: 883
# 💰 Cash: $1147.13
# 📈 Holdings: {'AAPL': 14, 'GOOGL': 3, 'MSFT': 2, 'TSLA': 22}
# 📉 Total Portfolio Value: $15649.29
# 📊 Step: 884
# 💰 Cash: $465.13
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 4, 'MSFT': 2, 'TSLA': 21}
# 📉 Total Portfolio Value: $15531.77
# 📊 Step: 885
# 💰 Cash: $1461.75
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 3, 'MSFT': 3, 'TSLA': 22}
# 📉 Total Portfolio Value: $16391.77
# 📊 Step: 886
# 💰 Cash: $142.33
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 4, 'MSFT': 2, 'TSLA': 23}
# 📉 Total Portfolio Value: $16204.19
# 📊 Step: 887
# 💰 Cash: $622.16
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 4, 'MSFT': 1, 'TSLA': 22}
# 📉 Total Portfolio Value: $15841.25
# 📊 Step: 888
# 💰 Cash: $864.94
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 4, 'MSFT': 2, 'TSLA': 21}
# 📉 Total Portfolio Value: $15841.10
# 📊 Step: 889
# 💰 Cash: $607.98
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 4, 'MSFT': 3, 'TSLA': 22}
# 📉 Total Portfolio Value: $15856.89
# 📊 Step: 890
# 💰 Cash: $1856.62
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 3, 'MSFT': 3, 'TSLA': 22}
# 📉 Total Portfolio Value: $15705.30
# 📊 Step: 891
# 💰 Cash: $2867.31
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 2, 'MSFT': 4, 'TSLA': 23}
# 📉 Total Portfolio Value: $15444.42
# 📊 Step: 892
# 💰 Cash: $4330.56
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 1, 'MSFT': 5, 'TSLA': 22}
# 📉 Total Portfolio Value: $15392.60
# 📊 Step: 893
# 💰 Cash: $2893.18
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 2, 'MSFT': 5, 'TSLA': 22}
# 📉 Total Portfolio Value: $14759.58
# 📊 Step: 894
# 💰 Cash: $2981.10
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 2, 'MSFT': 5, 'TSLA': 21}
# 📉 Total Portfolio Value: $14806.65
# 📊 Step: 895
# 💰 Cash: $2350.33
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 2, 'MSFT': 6, 'TSLA': 22}
# 📉 Total Portfolio Value: $15083.31
# 📊 Step: 896
# 💰 Cash: $1241.98
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 3, 'MSFT': 7, 'TSLA': 22}
# 📉 Total Portfolio Value: $15098.28
# 📊 Step: 897
# 💰 Cash: $2141.62
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 2, 'MSFT': 8, 'TSLA': 22}
# 📉 Total Portfolio Value: $15072.50
# 📊 Step: 898
# 💰 Cash: $1348.49
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 3, 'MSFT': 9, 'TSLA': 21}
# 📉 Total Portfolio Value: $15191.32
# 📊 Step: 899
# 💰 Cash: $1348.49
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 3, 'MSFT': 9, 'TSLA': 21}
# 📉 Total Portfolio Value: $15205.71
# 📊 Step: 900
# 💰 Cash: $411.49
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 4, 'MSFT': 9, 'TSLA': 20}
# 📉 Total Portfolio Value: $15041.17
# 📊 Step: 901
# 💰 Cash: $1565.19
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 3, 'MSFT': 9, 'TSLA': 21}
# 📉 Total Portfolio Value: $15002.33
# 📊 Step: 902
# 💰 Cash: $1565.19
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 3, 'MSFT': 9, 'TSLA': 21}
# 📉 Total Portfolio Value: $14952.51
# 📊 Step: 903
# 💰 Cash: $197.67
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 4, 'MSFT': 8, 'TSLA': 21}
# 📉 Total Portfolio Value: $14862.30
# 📊 Step: 904
# 💰 Cash: $197.67
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 4, 'MSFT': 8, 'TSLA': 21}
# 📉 Total Portfolio Value: $14516.50
# 📊 Step: 905
# 💰 Cash: $1926.29
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 3, 'MSFT': 8, 'TSLA': 20}
# 📉 Total Portfolio Value: $14275.01
# 📊 Step: 906
# 💰 Cash: $1763.93
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 3, 'MSFT': 9, 'TSLA': 21}
# 📉 Total Portfolio Value: $14202.41
# 📊 Step: 907
# 💰 Cash: $2267.98
# 📈 Holdings: {'AAPL': 8, 'GOOGL': 3, 'MSFT': 9, 'TSLA': 20}
# 📉 Total Portfolio Value: $13809.84
# 📊 Step: 908
# 💰 Cash: $1311.69
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 4, 'MSFT': 9, 'TSLA': 20}
# 📉 Total Portfolio Value: $14234.66
# 📊 Step: 909
# 💰 Cash: $1488.24
# 📈 Holdings: {'AAPL': 8, 'GOOGL': 4, 'MSFT': 8, 'TSLA': 19}
# 📉 Total Portfolio Value: $14238.28
# 📊 Step: 910
# 💰 Cash: $1655.07
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 4, 'MSFT': 7, 'TSLA': 18}
# 📉 Total Portfolio Value: $14342.79
# 📊 Step: 911
# 💰 Cash: $704.54
# 📈 Holdings: {'AAPL': 8, 'GOOGL': 5, 'MSFT': 7, 'TSLA': 18}
# 📉 Total Portfolio Value: $14427.17
# 📊 Step: 912
# 💰 Cash: $2402.55
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 4, 'MSFT': 7, 'TSLA': 17}
# 📉 Total Portfolio Value: $14493.34
# 📊 Step: 913
# 💰 Cash: $1519.77
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 5, 'MSFT': 7, 'TSLA': 16}
# 📉 Total Portfolio Value: $14346.50
# 📊 Step: 914
# 💰 Cash: $894.91
# 📈 Holdings: {'AAPL': 8, 'GOOGL': 5, 'MSFT': 8, 'TSLA': 17}
# 📉 Total Portfolio Value: $14226.38
# 📊 Step: 915
# 💰 Cash: $278.50
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 5, 'MSFT': 9, 'TSLA': 18}
# 📉 Total Portfolio Value: $14502.84
# 📊 Step: 916
# 💰 Cash: $795.89
# 📈 Holdings: {'AAPL': 8, 'GOOGL': 5, 'MSFT': 9, 'TSLA': 17}
# 📉 Total Portfolio Value: $14607.72
# 📊 Step: 917
# 💰 Cash: $689.43
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 5, 'MSFT': 8, 'TSLA': 17}
# 📉 Total Portfolio Value: $14507.75
# 📊 Step: 918
# 💰 Cash: $2492.57
# 📈 Holdings: {'AAPL': 8, 'GOOGL': 4, 'MSFT': 7, 'TSLA': 16}
# 📉 Total Portfolio Value: $14574.70
# 📊 Step: 919
# 💰 Cash: $3751.02
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 3, 'MSFT': 7, 'TSLA': 15}
# 📉 Total Portfolio Value: $14648.40
# 📊 Step: 920
# 💰 Cash: $4608.27
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 2, 'MSFT': 8, 'TSLA': 15}
# 📉 Total Portfolio Value: $14756.13
# 📊 Step: 921
# 💰 Cash: $4298.69
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 2, 'MSFT': 8, 'TSLA': 16}
# 📉 Total Portfolio Value: $14798.51
# 📊 Step: 922
# 💰 Cash: $3173.90
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 3, 'MSFT': 8, 'TSLA': 15}
# 📉 Total Portfolio Value: $14164.79
# 📊 Step: 923
# 💰 Cash: $4001.84
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 2, 'MSFT': 9, 'TSLA': 16}
# 📉 Total Portfolio Value: $14930.45
# 📊 Step: 924
# 💰 Cash: $4556.80
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 1, 'MSFT': 10, 'TSLA': 17}
# 📉 Total Portfolio Value: $14784.64
# 📊 Step: 925
# 💰 Cash: $5649.29
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 11, 'TSLA': 17}
# 📉 Total Portfolio Value: $14712.60
# 📊 Step: 926
# 💰 Cash: $4732.56
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 1, 'MSFT': 11, 'TSLA': 16}
# 📉 Total Portfolio Value: $14395.48
# 📊 Step: 927
# 💰 Cash: $5129.59
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 1, 'MSFT': 12, 'TSLA': 15}
# 📉 Total Portfolio Value: $14039.42
# 📊 Step: 928
# 💰 Cash: $4111.55
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 2, 'MSFT': 11, 'TSLA': 14}
# 📉 Total Portfolio Value: $13835.82
# 📊 Step: 929
# 💰 Cash: $4793.14
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 1, 'MSFT': 11, 'TSLA': 15}
# 📉 Total Portfolio Value: $14064.48
# 📊 Step: 930
# 💰 Cash: $5282.81
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 1, 'MSFT': 11, 'TSLA': 14}
# 📉 Total Portfolio Value: $13735.37
# 📊 Step: 931
# 💰 Cash: $4703.41
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 1, 'MSFT': 12, 'TSLA': 15}
# 📉 Total Portfolio Value: $13636.37
# 📊 Step: 932
# 💰 Cash: $4559.72
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 1, 'MSFT': 13, 'TSLA': 16}
# 📉 Total Portfolio Value: $13910.47
# 📊 Step: 933
# 💰 Cash: $3366.28
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 2, 'MSFT': 14, 'TSLA': 15}
# 📉 Total Portfolio Value: $13797.09
# 📊 Step: 934
# 💰 Cash: $4361.12
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 1, 'MSFT': 15, 'TSLA': 15}
# 📉 Total Portfolio Value: $14196.00
# 📊 Step: 935
# 💰 Cash: $5881.94
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 16, 'TSLA': 14}
# 📉 Total Portfolio Value: $14112.50
# 📊 Step: 936
# 💰 Cash: $6043.01
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 17, 'TSLA': 13}
# 📉 Total Portfolio Value: $13910.58
# 📊 Step: 937
# 💰 Cash: $5982.40
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 0, 'MSFT': 18, 'TSLA': 12}
# 📉 Total Portfolio Value: $13909.31
# 📊 Step: 938
# 💰 Cash: $6091.06
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 0, 'MSFT': 17, 'TSLA': 12}
# 📉 Total Portfolio Value: $13954.62
# 📊 Step: 939
# 💰 Cash: $5461.29
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 1, 'MSFT': 17, 'TSLA': 11}
# 📉 Total Portfolio Value: $14322.20
# 📊 Step: 940
# 💰 Cash: $5353.19
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 1, 'MSFT': 18, 'TSLA': 11}
# 📉 Total Portfolio Value: $14006.65
# 📊 Step: 941
# 💰 Cash: $6439.22
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 0, 'MSFT': 17, 'TSLA': 12}
# 📉 Total Portfolio Value: $14476.44
# 📊 Step: 942
# 💰 Cash: $4800.97
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 1, 'MSFT': 17, 'TSLA': 13}
# 📉 Total Portfolio Value: $14600.33
# 📊 Step: 943
# 💰 Cash: $4584.67
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 1, 'MSFT': 17, 'TSLA': 13}
# 📉 Total Portfolio Value: $14497.01
# 📊 Step: 944
# 💰 Cash: $3884.79
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 2, 'MSFT': 17, 'TSLA': 12}
# 📉 Total Portfolio Value: $14478.92
# 📊 Step: 945
# 💰 Cash: $3048.58
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 3, 'MSFT': 17, 'TSLA': 12}
# 📉 Total Portfolio Value: $14810.25
# 📊 Step: 946
# 💰 Cash: $1401.82
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 4, 'MSFT': 17, 'TSLA': 13}
# 📉 Total Portfolio Value: $14910.88
# 📊 Step: 947
# 💰 Cash: $776.42
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 5, 'MSFT': 18, 'TSLA': 12}
# 📉 Total Portfolio Value: $14691.42
# 📊 Step: 948
# 💰 Cash: $1122.83
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 5, 'MSFT': 18, 'TSLA': 11}
# 📉 Total Portfolio Value: $14511.14
# 📊 Step: 949
# 💰 Cash: $2210.86
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 4, 'MSFT': 19, 'TSLA': 10}
# 📉 Total Portfolio Value: $14595.42
# 📊 Step: 950
# 💰 Cash: $3621.49
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 3, 'MSFT': 19, 'TSLA': 9}
# 📉 Total Portfolio Value: $14936.24
# 📊 Step: 951
# 💰 Cash: $2191.34
# 📈 Holdings: {'AAPL': 14, 'GOOGL': 4, 'MSFT': 20, 'TSLA': 9}
# 📉 Total Portfolio Value: $14886.32
# 📊 Step: 952
# 💰 Cash: $2160.17
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 4, 'MSFT': 19, 'TSLA': 10}
# 📉 Total Portfolio Value: $14713.30
# 📊 Step: 953
# 💰 Cash: $2050.60
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 4, 'MSFT': 20, 'TSLA': 10}
# 📉 Total Portfolio Value: $14222.45
# 📊 Step: 954
# 💰 Cash: $1526.69
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 5, 'MSFT': 20, 'TSLA': 9}
# 📉 Total Portfolio Value: $14260.67
# 📊 Step: 955
# 💰 Cash: $225.28
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 6, 'MSFT': 21, 'TSLA': 10}
# 📉 Total Portfolio Value: $14251.93
# 📊 Step: 956
# 💰 Cash: $38.48
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 6, 'MSFT': 21, 'TSLA': 10}
# 📉 Total Portfolio Value: $14498.98
# 📊 Step: 957
# 💰 Cash: $122.61
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 6, 'MSFT': 22, 'TSLA': 10}
# 📉 Total Portfolio Value: $14586.55
# 📊 Step: 958
# 💰 Cash: $1190.88
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 5, 'MSFT': 22, 'TSLA': 10}
# 📉 Total Portfolio Value: $14208.79
# 📊 Step: 959
# 💰 Cash: $268.08
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 6, 'MSFT': 21, 'TSLA': 10}
# 📉 Total Portfolio Value: $14008.37
# 📊 Step: 960
# 💰 Cash: $1469.04
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 5, 'MSFT': 21, 'TSLA': 9}
# 📉 Total Portfolio Value: $14016.57
# 📊 Step: 961
# 💰 Cash: $1233.96
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 5, 'MSFT': 20, 'TSLA': 10}
# 📉 Total Portfolio Value: $13771.64
# 📊 Step: 962
# 💰 Cash: $100.79
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 6, 'MSFT': 21, 'TSLA': 10}
# 📉 Total Portfolio Value: $14227.75
# 📊 Step: 963
# 💰 Cash: $100.79
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 6, 'MSFT': 21, 'TSLA': 10}
# 📉 Total Portfolio Value: $14194.50
# 📊 Step: 964
# 💰 Cash: $100.79
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 6, 'MSFT': 21, 'TSLA': 10}
# 📉 Total Portfolio Value: $14635.04
# 📊 Step: 965
# 💰 Cash: $448.66
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 6, 'MSFT': 21, 'TSLA': 9}
# 📉 Total Portfolio Value: $14555.26
# 📊 Step: 966
# 💰 Cash: $1091.88
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 5, 'MSFT': 22, 'TSLA': 10}
# 📉 Total Portfolio Value: $14727.47
# 📊 Step: 967
# 💰 Cash: $630.51
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 5, 'MSFT': 23, 'TSLA': 11}
# 📉 Total Portfolio Value: $14951.61
# 📊 Step: 968
# 💰 Cash: $692.09
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 5, 'MSFT': 24, 'TSLA': 10}
# 📉 Total Portfolio Value: $14502.89
# 📊 Step: 969
# 💰 Cash: $623.92
# 📈 Holdings: {'AAPL': 14, 'GOOGL': 5, 'MSFT': 23, 'TSLA': 10}
# 📉 Total Portfolio Value: $14602.37
# 📊 Step: 970
# 💰 Cash: $195.33
# 📈 Holdings: {'AAPL': 15, 'GOOGL': 5, 'MSFT': 22, 'TSLA': 11}
# 📉 Total Portfolio Value: $14199.30
# 📊 Step: 971
# 💰 Cash: $610.63
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 4, 'MSFT': 23, 'TSLA': 12}
# 📉 Total Portfolio Value: $14393.32
# 📊 Step: 972
# 💰 Cash: $503.04
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 4, 'MSFT': 24, 'TSLA': 12}
# 📉 Total Portfolio Value: $14455.00
# 📊 Step: 973
# 💰 Cash: $334.41
# 📈 Holdings: {'AAPL': 17, 'GOOGL': 4, 'MSFT': 24, 'TSLA': 12}
# 📉 Total Portfolio Value: $14521.16
# 📊 Step: 974
# 💰 Cash: $872.44
# 📈 Holdings: {'AAPL': 18, 'GOOGL': 3, 'MSFT': 24, 'TSLA': 13}
# 📉 Total Portfolio Value: $14695.24
# 📊 Step: 975
# 💰 Cash: $1775.03
# 📈 Holdings: {'AAPL': 19, 'GOOGL': 2, 'MSFT': 24, 'TSLA': 13}
# 📉 Total Portfolio Value: $14321.52
# 📊 Step: 976
# 💰 Cash: $2200.19
# 📈 Holdings: {'AAPL': 18, 'GOOGL': 2, 'MSFT': 25, 'TSLA': 12}
# 📉 Total Portfolio Value: $13955.70
# 📊 Step: 977
# 💰 Cash: $2980.31
# 📈 Holdings: {'AAPL': 18, 'GOOGL': 1, 'MSFT': 24, 'TSLA': 13}
# 📉 Total Portfolio Value: $13889.65
# 📊 Step: 978
# 💰 Cash: $2747.25
# 📈 Holdings: {'AAPL': 18, 'GOOGL': 1, 'MSFT': 23, 'TSLA': 14}
# 📉 Total Portfolio Value: $13725.18
# 📊 Step: 979
# 💰 Cash: $2919.33
# 📈 Holdings: {'AAPL': 19, 'GOOGL': 1, 'MSFT': 23, 'TSLA': 13}
# 📉 Total Portfolio Value: $13357.35
# 📊 Step: 980
# 💰 Cash: $2154.09
# 📈 Holdings: {'AAPL': 18, 'GOOGL': 2, 'MSFT': 22, 'TSLA': 13}
# 📉 Total Portfolio Value: $13167.80
# 📊 Step: 981
# 💰 Cash: $913.88
# 📈 Holdings: {'AAPL': 19, 'GOOGL': 3, 'MSFT': 23, 'TSLA': 13}
# 📉 Total Portfolio Value: $12662.72
# 📊 Step: 982
# 💰 Cash: $819.75
# 📈 Holdings: {'AAPL': 19, 'GOOGL': 3, 'MSFT': 24, 'TSLA': 13}
# 📉 Total Portfolio Value: $13602.14
# 📊 Step: 983
# 💰 Cash: $976.92
# 📈 Holdings: {'AAPL': 18, 'GOOGL': 3, 'MSFT': 24, 'TSLA': 13}
# 📉 Total Portfolio Value: $13484.33
# 📊 Step: 984
# 💰 Cash: $1035.72
# 📈 Holdings: {'AAPL': 19, 'GOOGL': 3, 'MSFT': 25, 'TSLA': 12}
# 📉 Total Portfolio Value: $13660.33
# 📊 Step: 985
# 💰 Cash: $1136.11
# 📈 Holdings: {'AAPL': 19, 'GOOGL': 3, 'MSFT': 24, 'TSLA': 12}
# 📉 Total Portfolio Value: $13699.34
# 📊 Step: 986
# 💰 Cash: $423.95
# 📈 Holdings: {'AAPL': 19, 'GOOGL': 4, 'MSFT': 24, 'TSLA': 11}
# 📉 Total Portfolio Value: $13481.35
# 📊 Step: 987
# 💰 Cash: $581.87
# 📈 Holdings: {'AAPL': 18, 'GOOGL': 4, 'MSFT': 24, 'TSLA': 11}
# 📉 Total Portfolio Value: $12884.74
# 📊 Step: 988
# 💰 Cash: $521.10
# 📈 Holdings: {'AAPL': 17, 'GOOGL': 4, 'MSFT': 23, 'TSLA': 12}
# 📉 Total Portfolio Value: $13510.47
# 📊 Step: 989
# 💰 Cash: $987.05
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 4, 'MSFT': 23, 'TSLA': 11}
# 📉 Total Portfolio Value: $13689.56
# 📊 Step: 990
# 💰 Cash: $839.12
# 📈 Holdings: {'AAPL': 17, 'GOOGL': 4, 'MSFT': 23, 'TSLA': 11}
# 📉 Total Portfolio Value: $13796.60
# 📊 Step: 991
# 💰 Cash: $736.32
# 📈 Holdings: {'AAPL': 17, 'GOOGL': 4, 'MSFT': 24, 'TSLA': 11}
# 📉 Total Portfolio Value: $13895.50
# 📊 Step: 992
# 💰 Cash: $1179.12
# 📈 Holdings: {'AAPL': 17, 'GOOGL': 4, 'MSFT': 23, 'TSLA': 10}
# 📉 Total Portfolio Value: $13941.55
# 📊 Step: 993
# 💰 Cash: $203.89
# 📈 Holdings: {'AAPL': 17, 'GOOGL': 5, 'MSFT': 22, 'TSLA': 10}
# 📉 Total Portfolio Value: $13849.38
# 📊 Step: 994
# 💰 Cash: $203.89
# 📈 Holdings: {'AAPL': 17, 'GOOGL': 5, 'MSFT': 22, 'TSLA': 10}
# 📉 Total Portfolio Value: $13600.55
# 📊 Step: 995
# 💰 Cash: $1357.45
# 📈 Holdings: {'AAPL': 17, 'GOOGL': 4, 'MSFT': 21, 'TSLA': 10}
# 📉 Total Portfolio Value: $13955.19
# 📊 Step: 996
# 💰 Cash: $615.37
# 📈 Holdings: {'AAPL': 17, 'GOOGL': 5, 'MSFT': 21, 'TSLA': 9}
# 📉 Total Portfolio Value: $14024.34
# 📊 Step: 997
# 💰 Cash: $615.37
# 📈 Holdings: {'AAPL': 17, 'GOOGL': 5, 'MSFT': 21, 'TSLA': 9}
# 📉 Total Portfolio Value: $14114.90
# 📊 Step: 998
# 💰 Cash: $2167.92
# 📈 Holdings: {'AAPL': 17, 'GOOGL': 4, 'MSFT': 20, 'TSLA': 8}
# 📉 Total Portfolio Value: $13835.34
# 📊 Step: 999
# 💰 Cash: $2470.18
# 📈 Holdings: {'AAPL': 17, 'GOOGL': 4, 'MSFT': 20, 'TSLA': 7}
# 📉 Total Portfolio Value: $13596.85
# 📊 Step: 1000
# 💰 Cash: $3895.36
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 3, 'MSFT': 21, 'TSLA': 6}
# 📉 Total Portfolio Value: $13577.76
#
# ==== 📊 Final Results ====
# 💰 Final Cash: $3895.36
# 📈 Total Portfolio Value: $19934.88
# 💵 Profit/Loss: $9934.88
# 📅 Trading Days Simulated: 1000
