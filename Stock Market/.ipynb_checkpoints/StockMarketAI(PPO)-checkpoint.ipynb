# %%
import os
import time
import requests
import pandas as pd
import numpy as np

class StockDataHandler:
    def __init__(self, tickers, api_key, outputsize="full", cache_dir="cached_data"):
        self.tickers = tickers
        self.api_key = api_key
        self.outputsize = outputsize  # Use "full" to get long-term data
        self.cache_dir = cache_dir
        os.makedirs(cache_dir, exist_ok=True)  # Ensure cache directory exists
        self.data = {}

    def fetch_data(self):
        """Fetch and cache 10 years of stock data from Alpha Vantage."""
        base_url = "https://www.alphavantage.co/query"
    
        for ticker in self.tickers:
            cache_file = os.path.join(self.cache_dir, f"{ticker}.csv")
    
            # ✅ **Check Cache First**
            if os.path.exists(cache_file):
                print(f"📂 Loading cached data for {ticker}...")
                df = pd.read_csv(cache_file, index_col=0, parse_dates=True)  # No squeezing
                recent_date = df.index.max()
    
                # **If cached data is recent, skip API call**
                if recent_date >= pd.Timestamp.today() - pd.DateOffset(days=7):  
                    self.data[ticker] = df["4. close"]  # Store the "close" price column properly
                    continue
    
            print(f"🌐 Fetching 10 years of data for {ticker} from API...")
            params = {
                "function": "TIME_SERIES_DAILY",
                "symbol": ticker,
                "outputsize": self.outputsize,  # "full" gets 20+ years
                "datatype": "json",
                "apikey": self.api_key
            }
    
            response = requests.get(base_url, params=params)
            data = response.json()
    
            if "Time Series (Daily)" not in data:
                print(f"❌ Error fetching {ticker}: {data.get('Note', 'No data available.')}")
                continue
    
            # ✅ Convert API Response to DataFrame
            df = pd.DataFrame.from_dict(data["Time Series (Daily)"], orient="index")
            df.index = pd.to_datetime(df.index)
            df = df.sort_index()
    
            # ✅ Keep Only the Last **10 Years**
            ten_years_ago = pd.Timestamp.today() - pd.DateOffset(years=10)
            df = df[df.index >= ten_years_ago]
    
            # ✅ Store Only "Close" Prices & Save to Cache
            df = df["4. close"].astype(float)  # Directly extract "close" column as Series
            df.to_csv(cache_file)
            self.data[ticker] = df  # ✅ Store correctly
    
            # 🕒 **Wait to avoid hitting API limit**
            time.sleep(12)  # Alpha Vantage allows ~5 calls/min


    def get_data(self):
        """Return stock data as a pandas DataFrame."""
        if not self.data:
            raise ValueError("No valid stock data found. Check API key and ticker symbols.")
    
        # Convert each ticker's cached data into a Pandas Series and flatten if needed
        for ticker in self.data:
            if isinstance(self.data[ticker], np.ndarray):
                self.data[ticker] = self.data[ticker].flatten()  # Ensure 1D
            if not isinstance(self.data[ticker], pd.Series):
                self.data[ticker] = pd.Series(self.data[ticker])  
    
        df = pd.DataFrame(self.data)
        df.dropna(how="all", inplace=True)  # Drop rows where all tickers have NaN
    
        if df.empty:
            raise ValueError("Stock data is empty after processing. Check cache or API response.")
    
        return df


# ✅ **Example Usage**
if __name__ == "__main__":
    tickers = ["AAPL", "GOOGL", "MSFT", "TSLA"]
    api_key = "H4OCDHK7VPMS5WXA"  # 🔑 Replace with your Alpha Vantage API key

    data_handler = StockDataHandler(tickers, api_key, outputsize="full")
    data_handler.fetch_data()

    try:
        df = data_handler.get_data()
        print(df.head())  # 📊 Preview stock data
    except ValueError as e:
        print(f"Error: {e}")
# Out:
# 📂 Loading cached data for AAPL...
# 🌐 Fetching 10 years of data for AAPL from API...
# 📂 Loading cached data for GOOGL...
# 🌐 Fetching 10 years of data for GOOGL from API...
# 📂 Loading cached data for MSFT...
# 🌐 Fetching 10 years of data for MSFT from API...
# 📂 Loading cached data for TSLA...
# 🌐 Fetching 10 years of data for TSLA from API...
#                AAPL   GOOGL    MSFT     TSLA
# 2015-02-17  127.830  545.01  43.580  204.350
# 2015-02-18  128.715  542.65  43.530  204.460
# 2015-02-19  128.450  546.45  43.500  211.705
# 2015-02-20  129.495  541.80  43.855  217.110
# 2015-02-23  133.000  535.00  44.150  207.335

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import gym
from gym import spaces

class StockTradingEnv(gym.Env):
    def __init__(self, tickers, stock_data, initial_cash=10000):
        super(StockTradingEnv, self).__init__()
        self.tickers = [t for t in tickers if t in stock_data.columns]  # Only use tickers with data
        self.df = stock_data[self.tickers].copy().sort_index()  # Ensure oldest data first
        self.initial_cash = initial_cash
        self.cash = initial_cash
        self.shares = {ticker: 0 for ticker in self.tickers}
        self.current_step = 0

        # ✅ Check if we have data before proceeding
        if self.df.empty:
            raise ValueError("❌ No stock data available in the DataFrame!")

        # ✅ Define action and observation spaces
        self.action_space = spaces.MultiDiscrete([3] * len(self.tickers))  # 0 = Hold, 1 = Buy, 2 = Sell
        self.observation_space = spaces.Box(low=0, high=np.inf, shape=(len(self.tickers) * 2 + 1,), dtype=np.float32)
        
        # Track portfolio value over time
        self.portfolio_values = []

    def reset(self):
        """Reset environment to initial state."""
        self.cash = self.initial_cash
        self.shares = {ticker: 0 for ticker in self.tickers}
        self.current_step = 0
        self.portfolio_values = []  # Reset the portfolio values list
        return self._get_obs()

    def step(self, action):
        """Execute a step in the environment based on the action taken for multiple stocks."""
        if self.current_step >= len(self.df) - 1:
            return self._get_obs(), 0, True, {}  # Return last state if we're out of data

        prices = self.df.iloc[self.current_step]

        for i, ticker in enumerate(self.tickers):
            if action[i] == 1 and self.cash >= prices[ticker]:  # Buy stock
                self.shares[ticker] += 1
                self.cash -= prices[ticker]
            elif action[i] == 2 and self.shares[ticker] > 0:  # Sell stock
                self.shares[ticker] -= 1
                self.cash += prices[ticker]

        # Move to next step
        self.current_step += 1
        done = self.current_step >= len(self.df) - 1

        # ✅ Reward = Portfolio Value Change (to encourage profit)
        portfolio_value = self.cash + sum(self.shares[t] * prices[t] for t in self.tickers)
        reward = portfolio_value - self.initial_cash  # Profit = reward

        # Track portfolio value over time
        self.portfolio_values.append(portfolio_value)

        return self._get_obs(), reward, done, {}

    def _get_obs(self):
        """Return observation: cash balance + stock prices + shares owned for all stocks."""
        prices = np.array([self.df.iloc[self.current_step][t] for t in self.tickers], dtype=np.float32)
        holdings = np.array([self.shares[t] for t in self.tickers], dtype=np.float32)

        obs = np.concatenate(([self.cash], prices, holdings), axis=0)
        return obs

    def render(self):
        """Prints current cash, stock holdings, and total portfolio value."""
        portfolio_value = self.cash + sum(self.shares[t] * self.df.iloc[self.current_step][t] for t in self.tickers)

        print(f"📊 Step: {self.current_step}")
        print(f"💰 Cash: ${self.cash:.2f}")
        print("📈 Holdings:", {t: self.shares[t] for t in self.tickers})
        print(f"📉 Total Portfolio Value: ${portfolio_value:.2f}")

    def seed(self, seed=None):
        """Sets the random seed for reproducibility."""
        np.random.seed(seed)

    def plot_portfolio_growth(self):
        """Plot portfolio growth over time."""
        plt.plot(self.portfolio_values)
        plt.title("Portfolio Growth Over Time")
        plt.xlabel("Time Steps")
        plt.ylabel("Portfolio Value ($)")
        plt.grid(True)
        plt.show()

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
#from data_handler import StockDataHandler
#from trading_env import StockTradingEnv

# ✅ Step 1: Load or Fetch Stock Data
tickers = ["AAPL", "GOOGL", "MSFT", "TSLA"]
api_key = "I3QFMBJXM0I1YYSF"

data_handler = StockDataHandler(tickers, api_key, outputsize="full")

try:
    df = data_handler.get_data()  # Try loading cached data
except ValueError:
    data_handler.fetch_data()  # Fetch new data if cache is missing
    df = data_handler.get_data()

# ✅ Step 2: Create the RL Training Environment
env = make_vec_env(lambda: StockTradingEnv(tickers, df), n_envs=1)

# ✅ Step 3: Train the AI Model
model = PPO(
    "MlpPolicy",           # MLP (Multi-Layer Perceptron) policy network
    env,                    # The environment you're training in
    learning_rate=2.5e-4,   # The learning rate of the optimizer
    n_steps=2048,           # The number of steps to run for each environment per update
    batch_size=64,          # The batch size used for training
    n_epochs=10,            # Number of epochs per update (how many times to optimize the model on the sampled data)
    gamma=0.99,             # The discount factor for future rewards
    gae_lambda=0.95,        # The factor for Generalized Advantage Estimation (GAE)
    ent_coef=0.01,          # Coefficient for the entropy bonus (encourages exploration)
    vf_coef=0.5,            # Coefficient for the value function loss
    max_grad_norm=0.5,      # Gradient clipping to prevent gradient explosion
    clip_range=0.2,         # The clip range for the PPO objective to stabilize training
    target_kl=0.01,         # Target KL divergence for early stopping
    verbose=1,              # Display training information
    tensorboard_log="./ppo_tensorboard", # Optional: Log to TensorBoard for monitoring
    seed=42,                # For reproducibility, set the random seed
)
model.learn(total_timesteps=500000)  # Adjust timesteps for better learning
model.save("stock_trading_ppo")

# ✅ Step 4: Load the Trained Model for Evaluation or Further Training
model = PPO.load("stock_trading_ppo")
# Out:
# 📂 Loading cached data for AAPL...
# 📂 Loading cached data for GOOGL...
# 📂 Loading cached data for MSFT...
# 📂 Loading cached data for TSLA...
# Using cpu device
# C:\Users\pched\anaconda3\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Logging to ./ppo_tensorboard\PPO_3
# -----------------------------
# | time/              |      |
# |    fps             | 1367 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 1.91e+07      |
# | time/                   |               |
# |    fps                  | 1101          |
# |    iterations           | 2             |
# |    time_elapsed         | 3             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 1.0404037e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 4.17e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 9.11e+09      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -5.43e-05     |
# |    value_loss           | 2.78e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 1.59e+07      |
# | time/                   |               |
# |    fps                  | 1038          |
# |    iterations           | 3             |
# |    time_elapsed         | 5             |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 1.8211431e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -2.03e-06     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 9.15e+09      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -8.23e-05     |
# |    value_loss           | 2.38e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 1.63e+07      |
# | time/                   |               |
# |    fps                  | 1006          |
# |    iterations           | 4             |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 6.7138753e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 5.96e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 7.54e+09      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000176     |
# |    value_loss           | 1.14e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 1.75e+07      |
# | time/                   |               |
# |    fps                  | 990           |
# |    iterations           | 5             |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 1.1902303e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 7.99e+09      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -6.46e-05     |
# |    value_loss           | 1.62e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 1.75e+07      |
# | time/                   |               |
# |    fps                  | 980           |
# |    iterations           | 6             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 4.0663872e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.17e+10      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -3.73e-05     |
# |    value_loss           | 4.58e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 1.92e+07     |
# | time/                   |              |
# |    fps                  | 973          |
# |    iterations           | 7            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 9.634823e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.64e+10     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -6.4e-05     |
# |    value_loss           | 5.98e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.41e+07      |
# | time/                   |               |
# |    fps                  | 969           |
# |    iterations           | 8             |
# |    time_elapsed         | 16            |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 3.4709228e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.26e+10      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -2.59e-05     |
# |    value_loss           | 1.01e+11      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.2e+07      |
# | time/                   |              |
# |    fps                  | 965          |
# |    iterations           | 9            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 4.033791e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.73e+10     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -3.6e-05     |
# |    value_loss           | 1.18e+11     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.15e+07     |
# | time/                   |              |
# |    fps                  | 963          |
# |    iterations           | 10           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 9.941548e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7.41e+09     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.000204    |
# |    value_loss           | 1.01e+10     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.52e+03    |
# |    ep_rew_mean          | 2.15e+07    |
# | time/                   |             |
# |    fps                  | 960         |
# |    iterations           | 11          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 6.50296e-07 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.39       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 1.63e+10    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -4.59e-05   |
# |    value_loss           | 2.74e+10    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.11e+07      |
# | time/                   |               |
# |    fps                  | 958           |
# |    iterations           | 12            |
# |    time_elapsed         | 25            |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 1.9016734e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 8.42e+09      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -9.88e-05     |
# |    value_loss           | 2.68e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.1e+07       |
# | time/                   |               |
# |    fps                  | 957           |
# |    iterations           | 13            |
# |    time_elapsed         | 27            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 4.4351327e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.28e+10      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -3.58e-05     |
# |    value_loss           | 4.67e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.05e+07      |
# | time/                   |               |
# |    fps                  | 956           |
# |    iterations           | 14            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 1.3015233e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.97e+09      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -6.83e-05     |
# |    value_loss           | 1.34e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.11e+07      |
# | time/                   |               |
# |    fps                  | 955           |
# |    iterations           | 15            |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 3.5073026e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.8e+09       |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.00011      |
# |    value_loss           | 1.06e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.06e+07     |
# | time/                   |              |
# |    fps                  | 954          |
# |    iterations           | 16           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 9.412179e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.76e+10     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -6.82e-05    |
# |    value_loss           | 7.3e+10      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.06e+07      |
# | time/                   |               |
# |    fps                  | 953           |
# |    iterations           | 17            |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 1.0881922e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.9e+09       |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -5.35e-05     |
# |    value_loss           | 1.73e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.29e+07      |
# | time/                   |               |
# |    fps                  | 952           |
# |    iterations           | 18            |
# |    time_elapsed         | 38            |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 2.2971653e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 6.62e+10      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -2.37e-05     |
# |    value_loss           | 1.47e+11      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.3e+07      |
# | time/                   |              |
# |    fps                  | 951          |
# |    iterations           | 19           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 4.838221e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7e+10        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -4.78e-05    |
# |    value_loss           | 1.52e+11     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.26e+07     |
# | time/                   |              |
# |    fps                  | 951          |
# |    iterations           | 20           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 9.651412e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.34e+10     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -5.18e-05    |
# |    value_loss           | 3.13e+10     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.36e+07     |
# | time/                   |              |
# |    fps                  | 951          |
# |    iterations           | 21           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 9.413343e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 8.29e+09     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -5.78e-05    |
# |    value_loss           | 2.44e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.36e+07      |
# | time/                   |               |
# |    fps                  | 950           |
# |    iterations           | 22            |
# |    time_elapsed         | 47            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 1.9054278e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 6.42e+10      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -3.1e-05      |
# |    value_loss           | 1.49e+11      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.55e+07     |
# | time/                   |              |
# |    fps                  | 950          |
# |    iterations           | 23           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 7.532071e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.35e+11     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -1.54e-05    |
# |    value_loss           | 2.26e+11     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.53e+07      |
# | time/                   |               |
# |    fps                  | 949           |
# |    iterations           | 24            |
# |    time_elapsed         | 51            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 3.9162114e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 6.58e+10      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -5.02e-05     |
# |    value_loss           | 1.29e+11      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.46e+07     |
# | time/                   |              |
# |    fps                  | 949          |
# |    iterations           | 25           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 1.077319e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.77e+09     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000248    |
# |    value_loss           | 9.56e+09     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.39e+07     |
# | time/                   |              |
# |    fps                  | 948          |
# |    iterations           | 26           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 5.457754e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 4.23e+09     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000167    |
# |    value_loss           | 1.28e+10     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.39e+07     |
# | time/                   |              |
# |    fps                  | 948          |
# |    iterations           | 27           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 4.251895e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.35e+09     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000114    |
# |    value_loss           | 6.83e+09     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.34e+07      |
# | time/                   |               |
# |    fps                  | 948           |
# |    iterations           | 28            |
# |    time_elapsed         | 60            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 1.9638974e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 8.22e+09      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -9.05e-05     |
# |    value_loss           | 1.58e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.39e+07     |
# | time/                   |              |
# |    fps                  | 947          |
# |    iterations           | 29           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 7.163035e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.55e+10     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -4.94e-05    |
# |    value_loss           | 8.35e+10     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.45e+07     |
# | time/                   |              |
# |    fps                  | 946          |
# |    iterations           | 30           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 9.466021e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.42e+10     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -6.28e-05    |
# |    value_loss           | 4.96e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.44e+07      |
# | time/                   |               |
# |    fps                  | 946           |
# |    iterations           | 31            |
# |    time_elapsed         | 67            |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 2.5430927e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.49e+10      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -2.55e-05     |
# |    value_loss           | 1.01e+11      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.43e+07     |
# | time/                   |              |
# |    fps                  | 946          |
# |    iterations           | 32           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 6.322516e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.38e+10     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -3.99e-05    |
# |    value_loss           | 4.53e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.43e+07      |
# | time/                   |               |
# |    fps                  | 946           |
# |    iterations           | 33            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 7.7325967e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.58e+10      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -5.84e-05     |
# |    value_loss           | 4.86e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.38e+07      |
# | time/                   |               |
# |    fps                  | 945           |
# |    iterations           | 34            |
# |    time_elapsed         | 73            |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 2.9718212e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.16e+09      |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -8.17e-05     |
# |    value_loss           | 8.47e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.35e+07      |
# | time/                   |               |
# |    fps                  | 945           |
# |    iterations           | 35            |
# |    time_elapsed         | 75            |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 1.8723076e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.22e+09      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -7.61e-05     |
# |    value_loss           | 1.19e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.3e+07      |
# | time/                   |              |
# |    fps                  | 945          |
# |    iterations           | 36           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 8.995208e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.34e+09     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000177    |
# |    value_loss           | 5.94e+09     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.3e+07       |
# | time/                   |               |
# |    fps                  | 945           |
# |    iterations           | 37            |
# |    time_elapsed         | 80            |
# |    total_timesteps      | 75776         |
# | train/                  |               |
# |    approx_kl            | 3.0967349e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 8.99e+09      |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -0.000114     |
# |    value_loss           | 1.86e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.3e+07       |
# | time/                   |               |
# |    fps                  | 944           |
# |    iterations           | 38            |
# |    time_elapsed         | 82            |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 5.7023135e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.45e+10      |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -4.18e-05     |
# |    value_loss           | 3.03e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.26e+07      |
# | time/                   |               |
# |    fps                  | 944           |
# |    iterations           | 39            |
# |    time_elapsed         | 84            |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 4.4082117e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.59e+09      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.000143     |
# |    value_loss           | 7.68e+09      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.26e+07      |
# | time/                   |               |
# |    fps                  | 944           |
# |    iterations           | 40            |
# |    time_elapsed         | 86            |
# |    total_timesteps      | 81920         |
# | train/                  |               |
# |    approx_kl            | 1.2381643e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.6e+10       |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -6.48e-05     |
# |    value_loss           | 5.11e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.31e+07      |
# | time/                   |               |
# |    fps                  | 943           |
# |    iterations           | 41            |
# |    time_elapsed         | 88            |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 2.3203029e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.81e+10      |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.000102     |
# |    value_loss           | 3.08e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.32e+07      |
# | time/                   |               |
# |    fps                  | 943           |
# |    iterations           | 42            |
# |    time_elapsed         | 91            |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 1.2718374e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 5.94e+10      |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -1.6e-05      |
# |    value_loss           | 1.12e+11      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.3e+07       |
# | time/                   |               |
# |    fps                  | 942           |
# |    iterations           | 43            |
# |    time_elapsed         | 93            |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 3.4057302e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.95e+10      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -3.29e-05     |
# |    value_loss           | 7e+10         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.3e+07       |
# | time/                   |               |
# |    fps                  | 942           |
# |    iterations           | 44            |
# |    time_elapsed         | 95            |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 1.3559475e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.32e+10      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -6.02e-05     |
# |    value_loss           | 3.32e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.31e+07     |
# | time/                   |              |
# |    fps                  | 942          |
# |    iterations           | 45           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 5.274778e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.08e+10     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -4.47e-05    |
# |    value_loss           | 4.82e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.32e+07      |
# | time/                   |               |
# |    fps                  | 941           |
# |    iterations           | 46            |
# |    time_elapsed         | 100           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 1.5191035e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.41e+10      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -7.99e-05     |
# |    value_loss           | 2.46e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.3e+07       |
# | time/                   |               |
# |    fps                  | 941           |
# |    iterations           | 47            |
# |    time_elapsed         | 102           |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 1.0041113e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.23e+10      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -4.78e-05     |
# |    value_loss           | 3.28e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.31e+07      |
# | time/                   |               |
# |    fps                  | 940           |
# |    iterations           | 48            |
# |    time_elapsed         | 104           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 1.5775731e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.25e+10      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -6.83e-05     |
# |    value_loss           | 2.18e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.31e+07     |
# | time/                   |              |
# |    fps                  | 940          |
# |    iterations           | 49           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 5.438924e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 2.73e+10     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -4.57e-05    |
# |    value_loss           | 5.28e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.32e+07      |
# | time/                   |               |
# |    fps                  | 940           |
# |    iterations           | 50            |
# |    time_elapsed         | 108           |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 4.3283217e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 3.02e+10      |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -4.06e-05     |
# |    value_loss           | 6.44e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.36e+07     |
# | time/                   |              |
# |    fps                  | 939          |
# |    iterations           | 51           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 3.585301e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 5.18e+10     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -2.72e-05    |
# |    value_loss           | 7.89e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.33e+07      |
# | time/                   |               |
# |    fps                  | 939           |
# |    iterations           | 52            |
# |    time_elapsed         | 113           |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 4.5084744e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.4e+10       |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -2.54e-05     |
# |    value_loss           | 5.08e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.33e+07     |
# | time/                   |              |
# |    fps                  | 939          |
# |    iterations           | 53           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 8.774805e-06 |
# |    clip_fraction        | 0            |
# ...
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.19e+10      |
# |    n_updates            | 2270          |
# |    policy_gradient_loss | -9.02e-05     |
# |    value_loss           | 4.27e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.38e+07      |
# | time/                   |               |
# |    fps                  | 934           |
# |    iterations           | 229           |
# |    time_elapsed         | 501           |
# |    total_timesteps      | 468992        |
# | train/                  |               |
# |    approx_kl            | 1.8203864e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 9.92e+09      |
# |    n_updates            | 2280          |
# |    policy_gradient_loss | -8.23e-05     |
# |    value_loss           | 2.63e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.36e+07     |
# | time/                   |              |
# |    fps                  | 934          |
# |    iterations           | 230          |
# |    time_elapsed         | 503          |
# |    total_timesteps      | 471040       |
# | train/                  |              |
# |    approx_kl            | 1.583976e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.18e+10     |
# |    n_updates            | 2290         |
# |    policy_gradient_loss | -6.34e-05    |
# |    value_loss           | 1.86e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.35e+07      |
# | time/                   |               |
# |    fps                  | 934           |
# |    iterations           | 231           |
# |    time_elapsed         | 506           |
# |    total_timesteps      | 473088        |
# | train/                  |               |
# |    approx_kl            | 5.3009717e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 6.87e+09      |
# |    n_updates            | 2300          |
# |    policy_gradient_loss | -0.000162     |
# |    value_loss           | 1.31e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.35e+07     |
# | time/                   |              |
# |    fps                  | 934          |
# |    iterations           | 232          |
# |    time_elapsed         | 508          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 5.388574e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.27e+10     |
# |    n_updates            | 2310         |
# |    policy_gradient_loss | -3e-05       |
# |    value_loss           | 2.4e+10      |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.35e+07      |
# | time/                   |               |
# |    fps                  | 934           |
# |    iterations           | 233           |
# |    time_elapsed         | 510           |
# |    total_timesteps      | 477184        |
# | train/                  |               |
# |    approx_kl            | 1.0431162e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.91e+09      |
# |    n_updates            | 2320          |
# |    policy_gradient_loss | -0.000234     |
# |    value_loss           | 9.27e+09      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.34e+07     |
# | time/                   |              |
# |    fps                  | 934          |
# |    iterations           | 234          |
# |    time_elapsed         | 512          |
# |    total_timesteps      | 479232       |
# | train/                  |              |
# |    approx_kl            | 6.758666e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 7.62e+09     |
# |    n_updates            | 2330         |
# |    policy_gradient_loss | -0.000211    |
# |    value_loss           | 1.45e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.35e+07      |
# | time/                   |               |
# |    fps                  | 934           |
# |    iterations           | 235           |
# |    time_elapsed         | 514           |
# |    total_timesteps      | 481280        |
# | train/                  |               |
# |    approx_kl            | 2.2240274e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 6.67e+09      |
# |    n_updates            | 2340          |
# |    policy_gradient_loss | -0.000114     |
# |    value_loss           | 1.38e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.37e+07      |
# | time/                   |               |
# |    fps                  | 934           |
# |    iterations           | 236           |
# |    time_elapsed         | 516           |
# |    total_timesteps      | 483328        |
# | train/                  |               |
# |    approx_kl            | 5.0940434e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 4.59e+10      |
# |    n_updates            | 2350          |
# |    policy_gradient_loss | -4.38e-05     |
# |    value_loss           | 9.11e+10      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.37e+07     |
# | time/                   |              |
# |    fps                  | 934          |
# |    iterations           | 237          |
# |    time_elapsed         | 519          |
# |    total_timesteps      | 485376       |
# | train/                  |              |
# |    approx_kl            | 2.264278e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.02e+11     |
# |    n_updates            | 2360         |
# |    policy_gradient_loss | -3.32e-05    |
# |    value_loss           | 1.98e+11     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.37e+07      |
# | time/                   |               |
# |    fps                  | 934           |
# |    iterations           | 238           |
# |    time_elapsed         | 521           |
# |    total_timesteps      | 487424        |
# | train/                  |               |
# |    approx_kl            | 2.4604378e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.72e+10      |
# |    n_updates            | 2370          |
# |    policy_gradient_loss | -2.89e-05     |
# |    value_loss           | 5.38e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.37e+07      |
# | time/                   |               |
# |    fps                  | 934           |
# |    iterations           | 239           |
# |    time_elapsed         | 523           |
# |    total_timesteps      | 489472        |
# | train/                  |               |
# |    approx_kl            | 2.7969363e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.00025       |
# |    loss                 | 2.55e+10      |
# |    n_updates            | 2380          |
# |    policy_gradient_loss | -0.000114     |
# |    value_loss           | 3.63e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.36e+07      |
# | time/                   |               |
# |    fps                  | 934           |
# |    iterations           | 240           |
# |    time_elapsed         | 525           |
# |    total_timesteps      | 491520        |
# | train/                  |               |
# |    approx_kl            | 2.5554036e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.04e+10      |
# |    n_updates            | 2390          |
# |    policy_gradient_loss | -9.29e-05     |
# |    value_loss           | 2.03e+10      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.38e+07      |
# | time/                   |               |
# |    fps                  | 934           |
# |    iterations           | 241           |
# |    time_elapsed         | 528           |
# |    total_timesteps      | 493568        |
# | train/                  |               |
# |    approx_kl            | 1.0137446e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.00025       |
# |    loss                 | 8.96e+09      |
# |    n_updates            | 2400          |
# |    policy_gradient_loss | -5.3e-05      |
# |    value_loss           | 4.04e+10      |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 2.52e+03       |
# |    ep_rew_mean          | 2.38e+07       |
# | time/                   |                |
# |    fps                  | 934            |
# |    iterations           | 242            |
# |    time_elapsed         | 530            |
# |    total_timesteps      | 495616         |
# | train/                  |                |
# |    approx_kl            | 1.18714524e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -4.39          |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.00025        |
# |    loss                 | 6.78e+10       |
# |    n_updates            | 2410           |
# |    policy_gradient_loss | -1.29e-05      |
# |    value_loss           | 1.25e+11       |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.38e+07     |
# | time/                   |              |
# |    fps                  | 934          |
# |    iterations           | 243          |
# |    time_elapsed         | 532          |
# |    total_timesteps      | 497664       |
# | train/                  |              |
# |    approx_kl            | 8.776551e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.89e+10     |
# |    n_updates            | 2420         |
# |    policy_gradient_loss | -7.24e-05    |
# |    value_loss           | 7.61e+10     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52e+03     |
# |    ep_rew_mean          | 2.37e+07     |
# | time/                   |              |
# |    fps                  | 934          |
# |    iterations           | 244          |
# |    time_elapsed         | 534          |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 5.211041e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.39        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 1.79e+10     |
# |    n_updates            | 2430         |
# |    policy_gradient_loss | -4.89e-05    |
# |    value_loss           | 3.25e+10     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 2.52e+03      |
# |    ep_rew_mean          | 2.36e+07      |
# | time/                   |               |
# |    fps                  | 934           |
# |    iterations           | 245           |
# |    time_elapsed         | 536           |
# |    total_timesteps      | 501760        |
# | train/                  |               |
# |    approx_kl            | 1.0162184e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -4.39         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.00025       |
# |    loss                 | 1.34e+10      |
# |    n_updates            | 2440          |
# |    policy_gradient_loss | -6.18e-05     |
# |    value_loss           | 5.63e+10      |
# -------------------------------------------

# %%
from stable_baselines3 import PPO

class TradingAgent:
    def __init__(self, model_path="stock_trading_ppo"):
        """Initialize the trading agent with a trained PPO model."""
        try:
            self.model = PPO.load(model_path)  # ✅ Load trained AI model
            print("✅ Successfully loaded AI trading model.")
        except Exception as e:
            print(f"❌ Error loading model: {e}")
            self.model = None  # Ensure model is None if loading fails

    def act(self, obs):
        """Use the trained RL model to make decisions instead of random choices."""
        if self.model is None:
            raise ValueError("❌ No trained AI model found. Ensure PPO model is trained and saved.")

        action, _ = self.model.predict(obs)  # ✅ Predict using PPO
        return action

# %%
# Load stock data (Use Cached Data if Available)
tickers = ["AAPL", "GOOGL", "MSFT", "TSLA"]
api_key = "I3QFMBJXM0I1YYSF"  # Replace with your real API key
data_handler = StockDataHandler(tickers, api_key, outputsize="full")

# ✅ Check if cached data exists, otherwise fetch new data
try:
    df = data_handler.get_data()  # Load cached data
except ValueError:
    data_handler.fetch_data()  # Fetch new data
    df = data_handler.get_data()

# ✅ Create Trading Environment
env = StockTradingEnv(tickers, df)
agent = TradingAgent("stock_trading_ppo")  # Change to "llm" to use an LLM-powered agent

# ✅ Run Simulation
obs = env.reset()
for _ in range(750):
    action = agent.act(obs)  # Get action from agent
    obs, reward, done, _ = env.step(action)  # Take a step
    env.render()  # Show results
    if done:
        break

# ✅ Calculate Final Portfolio Value
final_cash = env.cash
portfolio_value = final_cash + sum(env.shares[t] * df.iloc[-1][t] for t in tickers)

print("\n==== 📊 Final Results ====")
print(f"💰 Final Cash: ${final_cash:.2f}")
print(f"📈 Total Portfolio Value: ${portfolio_value:.2f}")
print(f"💵 Profit/Loss: ${portfolio_value - env.initial_cash:.2f}")
print(f"📅 Trading Days Simulated: {env.current_step}")

# Plot portfolio growth
env.plot_portfolio_growth()
# Out:
# 📂 Loading cached data for AAPL...
# 📂 Loading cached data for GOOGL...
# 📂 Loading cached data for MSFT...
# 📂 Loading cached data for TSLA...
# ✅ Successfully loaded AI trading model.
# 📊 Step: 1
# 💰 Cash: $10000.00
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 0}
# 📉 Total Portfolio Value: $10000.00
# 📊 Step: 2
# 💰 Cash: $9328.64
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 1, 'MSFT': 0, 'TSLA': 0}
# 📉 Total Portfolio Value: $10003.53
# 📊 Step: 3
# 💰 Cash: $9875.09
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 0}
# 📉 Total Portfolio Value: $10004.58
# 📊 Step: 4
# 💰 Cash: $9787.47
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 1}
# 📉 Total Portfolio Value: $9994.81
# 📊 Step: 5
# 💰 Cash: $9580.14
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 2}
# 📉 Total Portfolio Value: $9988.36
# 📊 Step: 6
# 💰 Cash: $9536.05
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 2}
# 📉 Total Portfolio Value: $9987.56
# 📊 Step: 7
# 💰 Cash: $8828.95
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 1, 'MSFT': 0, 'TSLA': 3}
# 📉 Total Portfolio Value: $10009.81
# 📊 Step: 8
# 💰 Cash: $9344.18
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 3}
# 📉 Total Portfolio Value: $9998.05
# 📊 Step: 9
# 💰 Cash: $9300.33
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 3}
# 📉 Total Portfolio Value: $9980.07
# 📊 Step: 10
# 💰 Cash: $9368.57
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 2}
# 📉 Total Portfolio Value: $9983.60
# 📊 Step: 11
# 💰 Cash: $9125.73
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 3}
# 📉 Total Portfolio Value: $9990.74
# 📊 Step: 12
# 💰 Cash: $9008.78
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 4}
# 📉 Total Portfolio Value: $9983.74
# 📊 Step: 13
# 💰 Cash: $9209.41
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 3}
# 📉 Total Portfolio Value: $9960.49
# 📊 Step: 14
# 💰 Cash: $9167.05
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 3}
# 📉 Total Portfolio Value: $9953.93
# 📊 Step: 15
# 💰 Cash: $8849.03
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 4}
# 📉 Total Portfolio Value: $9944.97
# 📊 Step: 16
# 💰 Cash: $7974.35
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 1, 'MSFT': 5, 'TSLA': 5}
# 📉 Total Portfolio Value: $9953.12
# 📊 Step: 17
# 💰 Cash: $7418.66
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 2, 'MSFT': 5, 'TSLA': 5}
# 📉 Total Portfolio Value: $9950.35
# 📊 Step: 18
# 💰 Cash: $7609.73
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 2, 'MSFT': 5, 'TSLA': 4}
# 📉 Total Portfolio Value: $9924.53
# 📊 Step: 19
# 💰 Cash: $7338.84
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 2, 'MSFT': 4, 'TSLA': 5}
# 📉 Total Portfolio Value: $9981.70
# 📊 Step: 20
# 💰 Cash: $7576.10
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 2, 'MSFT': 3, 'TSLA': 4}
# 📉 Total Portfolio Value: $9976.44
# 📊 Step: 21
# 💰 Cash: $6950.80
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 3, 'MSFT': 3, 'TSLA': 5}
# 📉 Total Portfolio Value: $10037.27
# 📊 Step: 22
# 💰 Cash: $6822.33
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 3, 'MSFT': 3, 'TSLA': 5}
# 📉 Total Portfolio Value: $10000.93
# 📊 Step: 23
# 💰 Cash: $6386.15
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 4, 'MSFT': 3, 'TSLA': 5}
# 📉 Total Portfolio Value: $10016.79
# 📊 Step: 24
# 💰 Cash: $6188.07
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 4, 'MSFT': 3, 'TSLA': 6}
# 📉 Total Portfolio Value: $10030.32
# 📊 Step: 25
# 💰 Cash: $5949.54
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 5, 'MSFT': 3, 'TSLA': 5}
# 📉 Total Portfolio Value: $10101.23
# 📊 Step: 26
# 💰 Cash: $5865.75
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 5, 'MSFT': 2, 'TSLA': 5}
# 📉 Total Portfolio Value: $10001.93
# 📊 Step: 27
# 💰 Cash: $5227.83
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 6, 'MSFT': 2, 'TSLA': 6}
# 📉 Total Portfolio Value: $9958.76
# 📊 Step: 28
# 💰 Cash: $5103.59
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 2, 'TSLA': 6}
# 📉 Total Portfolio Value: $9887.33
# 📊 Step: 29
# 💰 Cash: $5722.89
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 5, 'MSFT': 2, 'TSLA': 5}
# 📉 Total Portfolio Value: $9942.45
# 📊 Step: 30
# 💰 Cash: $6243.07
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 4, 'MSFT': 3, 'TSLA': 5}
# 📉 Total Portfolio Value: $9900.97
# 📊 Step: 31
# 💰 Cash: $6013.64
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 4, 'MSFT': 4, 'TSLA': 6}
# 📉 Total Portfolio Value: $9872.77
# 📊 Step: 32
# 💰 Cash: $6054.36
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 4, 'MSFT': 3, 'TSLA': 6}
# 📉 Total Portfolio Value: $9862.43
# 📊 Step: 33
# 💰 Cash: $6410.97
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 4, 'MSFT': 2, 'TSLA': 5}
# 📉 Total Portfolio Value: $9940.06
# 📊 Step: 34
# 💰 Cash: $7040.73
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 3, 'MSFT': 3, 'TSLA': 5}
# 📉 Total Portfolio Value: $9942.16
# 📊 Step: 35
# 💰 Cash: $6921.96
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 3, 'MSFT': 4, 'TSLA': 6}
# 📉 Total Portfolio Value: $9980.18
# 📊 Step: 36
# 💰 Cash: $7470.80
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 4, 'TSLA': 6}
# 📉 Total Portfolio Value: $9993.30
# 📊 Step: 37
# 💰 Cash: $7470.80
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 4, 'TSLA': 6}
# 📉 Total Portfolio Value: $10000.16
# 📊 Step: 38
# 💰 Cash: $6922.26
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 3, 'MSFT': 4, 'TSLA': 6}
# 📉 Total Portfolio Value: $9993.90
# 📊 Step: 39
# 💰 Cash: $7134.27
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 2, 'MSFT': 4, 'TSLA': 7}
# 📉 Total Portfolio Value: $9958.95
# 📊 Step: 40
# 💰 Cash: $7053.11
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 4, 'TSLA': 8}
# 📉 Total Portfolio Value: $9966.85
# 📊 Step: 41
# 💰 Cash: $6346.49
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 3, 'MSFT': 3, 'TSLA': 9}
# 📉 Total Portfolio Value: $9963.83
# 📊 Step: 42
# 💰 Cash: $6683.31
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 3, 'TSLA': 10}
# 📉 Total Portfolio Value: $9941.54
# 📊 Step: 43
# 💰 Cash: $7464.46
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 1, 'MSFT': 2, 'TSLA': 9}
# 📉 Total Portfolio Value: $9942.23
# 📊 Step: 44
# 💰 Cash: $6757.56
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 1, 'TSLA': 10}
# 📉 Total Portfolio Value: $9980.15
# 📊 Step: 45
# 💰 Cash: $6590.79
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 0, 'TSLA': 11}
# 📉 Total Portfolio Value: $10102.99
# 📊 Step: 46
# 💰 Cash: $6920.53
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 1, 'MSFT': 0, 'TSLA': 12}
# 📉 Total Portfolio Value: $10101.19
# 📊 Step: 47
# 💰 Cash: $7086.38
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 13}
# 📉 Total Portfolio Value: $10104.05
# 📊 Step: 48
# 💰 Cash: $7046.10
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 14}
# 📉 Total Portfolio Value: $10287.80
# 📊 Step: 49
# 💰 Cash: $6711.53
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 1, 'MSFT': 0, 'TSLA': 13}
# 📉 Total Portfolio Value: $10272.14
# 📊 Step: 50
# 💰 Cash: $7045.42
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 14}
# 📉 Total Portfolio Value: $10299.72
# 📊 Step: 51
# 💰 Cash: $7045.42
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 14}
# 📉 Total Portfolio Value: $10210.12
# 📊 Step: 52
# 💰 Cash: $7045.42
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 14}
# 📉 Total Portfolio Value: $10209.84
# 📊 Step: 53
# 💰 Cash: $6819.39
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 15}
# 📉 Total Portfolio Value: $10277.04
# 📊 Step: 54
# 💰 Cash: $6771.15
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 15}
# 📉 Total Portfolio Value: $10313.00
# 📊 Step: 55
# 💰 Cash: $6585.80
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 16}
# 📉 Total Portfolio Value: $10272.68
# 📊 Step: 56
# 💰 Cash: $6816.23
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 15}
# 📉 Total Portfolio Value: $10368.23
# 📊 Step: 57
# 💰 Cash: $6102.23
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 15}
# 📉 Total Portfolio Value: $10375.70
# 📊 Step: 58
# 💰 Cash: $5425.66
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 2, 'MSFT': 1, 'TSLA': 15}
# 📉 Total Portfolio Value: $10409.58
# 📊 Step: 59
# 💰 Cash: $5059.85
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 2, 'MSFT': 1, 'TSLA': 16}
# 📉 Total Portfolio Value: $10478.10
# 📊 Step: 60
# 💰 Cash: $4687.35
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 3, 'MSFT': 0, 'TSLA': 15}
# 📉 Total Portfolio Value: $10457.56
# 📊 Step: 61
# 💰 Cash: $3904.68
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 4, 'MSFT': 0, 'TSLA': 16}
# 📉 Total Portfolio Value: $10522.88
# 📊 Step: 62
# 💰 Cash: $3775.73
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 4, 'MSFT': 0, 'TSLA': 16}
# 📉 Total Portfolio Value: $10586.98
# 📊 Step: 63
# 💰 Cash: $3301.01
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 5, 'MSFT': 1, 'TSLA': 15}
# 📉 Total Portfolio Value: $10594.76
# 📊 Step: 64
# 💰 Cash: $2884.53
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 6, 'MSFT': 1, 'TSLA': 15}
# 📉 Total Portfolio Value: $10585.24
# 📊 Step: 65
# 💰 Cash: $2554.90
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 16}
# 📉 Total Portfolio Value: $10559.92
# 📊 Step: 66
# 💰 Cash: $2084.87
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 16}
# 📉 Total Portfolio Value: $10616.83
# 📊 Step: 67
# 💰 Cash: $2283.07
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 7, 'MSFT': 2, 'TSLA': 15}
# 📉 Total Portfolio Value: $10637.16
# 📊 Step: 68
# 💰 Cash: $2329.97
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 15}
# 📉 Total Portfolio Value: $10566.82
# 📊 Step: 69
# 💰 Cash: $1699.75
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 8, 'MSFT': 0, 'TSLA': 15}
# 📉 Total Portfolio Value: $10637.47
# 📊 Step: 70
# 💰 Cash: $2079.23
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 8, 'MSFT': 0, 'TSLA': 14}
# 📉 Total Portfolio Value: $10691.87
# 📊 Step: 71
# 💰 Cash: $1959.56
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 8, 'MSFT': 0, 'TSLA': 15}
# 📉 Total Portfolio Value: $10605.24
# 📊 Step: 72
# 💰 Cash: $1116.58
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 9, 'MSFT': 1, 'TSLA': 16}
# 📉 Total Portfolio Value: $10620.04
# 📊 Step: 73
# 💰 Cash: $1033.27
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 9, 'MSFT': 0, 'TSLA': 16}
# 📉 Total Portfolio Value: $10642.22
# 📊 Step: 74
# 💰 Cash: $914.88
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 9, 'MSFT': 0, 'TSLA': 17}
# 📉 Total Portfolio Value: $10665.80
# 📊 Step: 75
# 💰 Cash: $1589.04
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 8, 'MSFT': 0, 'TSLA': 16}
# 📉 Total Portfolio Value: $10584.08
# 📊 Step: 76
# 💰 Cash: $1037.35
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 9, 'MSFT': 0, 'TSLA': 16}
# 📉 Total Portfolio Value: $10612.61
# 📊 Step: 77
# 💰 Cash: $1415.14
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 9, 'MSFT': 0, 'TSLA': 15}
# 📉 Total Portfolio Value: $10662.01
# 📊 Step: 78
# 💰 Cash: $1542.94
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 9, 'MSFT': 0, 'TSLA': 15}
# 📉 Total Portfolio Value: $10644.64
# 📊 Step: 79
# 💰 Cash: $1128.20
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 10, 'MSFT': 0, 'TSLA': 15}
# 📉 Total Portfolio Value: $10672.46
# 📊 Step: 80
# 💰 Cash: $453.78
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 11, 'MSFT': 0, 'TSLA': 16}
# 📉 Total Portfolio Value: $10655.37
# 📊 Step: 81
# 💰 Cash: $582.37
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 11, 'MSFT': 0, 'TSLA': 16}
# 📉 Total Portfolio Value: $10615.58
# 📊 Step: 82
# 💰 Cash: $706.01
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 10, 'MSFT': 1, 'TSLA': 17}
# 📉 Total Portfolio Value: $10564.87
# 📊 Step: 83
# 💰 Cash: $706.01
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 10, 'MSFT': 1, 'TSLA': 17}
# 📉 Total Portfolio Value: $10631.18
# 📊 Step: 84
# 💰 Cash: $1378.48
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 9, 'MSFT': 1, 'TSLA': 17}
# 📉 Total Portfolio Value: $10770.82
# 📊 Step: 85
# 💰 Cash: $2139.52
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 8, 'MSFT': 2, 'TSLA': 16}
# 📉 Total Portfolio Value: $10872.64
# 📊 Step: 86
# 💰 Cash: $2259.21
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 3, 'TSLA': 17}
# 📉 Total Portfolio Value: $10889.42
# 📊 Step: 87
# 💰 Cash: $1824.00
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 7, 'MSFT': 4, 'TSLA': 18}
# 📉 Total Portfolio Value: $10858.12
# 📊 Step: 88
# 💰 Cash: $923.15
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 8, 'MSFT': 3, 'TSLA': 19}
# 📉 Total Portfolio Value: $11034.82
# 📊 Step: 89
# 💰 Cash: $1190.82
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 8, 'MSFT': 3, 'TSLA': 18}
# 📉 Total Portfolio Value: $10953.68
# 📊 Step: 90
# 💰 Cash: $1099.40
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 8, 'MSFT': 2, 'TSLA': 19}
# 📉 Total Portfolio Value: $11016.31
# 📊 Step: 91
# 💰 Cash: $714.60
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 9, 'MSFT': 1, 'TSLA': 19}
# 📉 Total Portfolio Value: $10938.86
# 📊 Step: 92
# 💰 Cash: $828.56
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 8, 'MSFT': 2, 'TSLA': 20}
# 📉 Total Portfolio Value: $10736.76
# 📊 Step: 93
# 💰 Cash: $646.70
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 8, 'MSFT': 3, 'TSLA': 21}
# 📉 Total Portfolio Value: $10858.35
# 📊 Step: 94
# 💰 Cash: $1043.90
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 3, 'TSLA': 22}
# 📉 Total Portfolio Value: $10901.64
# 📊 Step: 95
# 💰 Cash: $725.31
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 8, 'MSFT': 4, 'TSLA': 21}
# 📉 Total Portfolio Value: $11162.05
# 📊 Step: 96
# 💰 Cash: $1508.27
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 5, 'TSLA': 20}
# 📉 Total Portfolio Value: $11143.96
# 📊 Step: 97
# 💰 Cash: $1706.38
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 4, 'TSLA': 19}
# 📉 Total Portfolio Value: $10949.20
# 📊 Step: 98
# 💰 Cash: $1750.68
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 3, 'TSLA': 19}
# 📉 Total Portfolio Value: $10642.11
# 📊 Step: 99
# 💰 Cash: $2591.58
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 6, 'MSFT': 2, 'TSLA': 18}
# 📉 Total Portfolio Value: $10711.15
# 📊 Step: 100
# 💰 Cash: $1713.46
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 19}
# 📉 Total Portfolio Value: $10821.25
# 📊 Step: 101
# 💰 Cash: $2696.61
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 18}
# 📉 Total Portfolio Value: $10971.53
# 📊 Step: 102
# 💰 Cash: $3084.43
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 17}
# 📉 Total Portfolio Value: $11105.56
# 📊 Step: 103
# 💰 Cash: $2818.78
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 18}
# 📉 Total Portfolio Value: $11059.06
# 📊 Step: 104
# 💰 Cash: $3139.60
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 0, 'TSLA': 19}
# 📉 Total Portfolio Value: $11215.42
# 📊 Step: 105
# 💰 Cash: $2804.50
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 18}
# 📉 Total Portfolio Value: $11946.10
# 📊 Step: 106
# 💰 Cash: $3504.12
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 0, 'TSLA': 18}
# 📉 Total Portfolio Value: $12049.00
# 📊 Step: 107
# 💰 Cash: $3372.05
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 5, 'MSFT': 0, 'TSLA': 18}
# 📉 Total Portfolio Value: $11781.41
# 📊 Step: 108
# 💰 Cash: $2943.47
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 17}
# 📉 Total Portfolio Value: $11793.08
# 📊 Step: 109
# 💰 Cash: $1980.50
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 0, 'TSLA': 18}
# 📉 Total Portfolio Value: $11638.37
# 📊 Step: 110
# 💰 Cash: $1572.97
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 8, 'MSFT': 0, 'TSLA': 17}
# 📉 Total Portfolio Value: $11447.60
# 📊 Step: 111
# 💰 Cash: $1402.53
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 8, 'MSFT': 1, 'TSLA': 17}
# 📉 Total Portfolio Value: $11260.75
# 📊 Step: 112
# 💰 Cash: $2183.57
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 17}
# 📉 Total Portfolio Value: $11471.85
# 📊 Step: 113
# 💰 Cash: $2060.19
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 17}
# 📉 Total Portfolio Value: $11467.41
# 📊 Step: 114
# 💰 Cash: $3108.43
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 6, 'MSFT': 1, 'TSLA': 16}
# 📉 Total Portfolio Value: $11533.68
# 📊 Step: 115
# 💰 Cash: $3299.73
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 15}
# 📉 Total Portfolio Value: $11479.58
# 📊 Step: 116
# 💰 Cash: $2474.23
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 15}
# 📉 Total Portfolio Value: $11429.25
# 📊 Step: 117
# 💰 Cash: $2997.40
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 1, 'TSLA': 16}
# 📉 Total Portfolio Value: $11502.38
# 📊 Step: 118
# 💰 Cash: $3773.32
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 5, 'MSFT': 1, 'TSLA': 16}
# 📉 Total Portfolio Value: $11624.83
# 📊 Step: 119
# 💰 Cash: $3387.79
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 5, 'MSFT': 1, 'TSLA': 17}
# 📉 Total Portfolio Value: $11199.63
# 📊 Step: 120
# 💰 Cash: $2879.39
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 17}
# 📉 Total Portfolio Value: $11103.92
# 📊 Step: 121
# 💰 Cash: $3006.38
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 16}
# 📉 Total Portfolio Value: $11082.90
# 📊 Step: 122
# 💰 Cash: $2221.82
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 0, 'TSLA': 17}
# 📉 Total Portfolio Value: $11202.70
# 📊 Step: 123
# 💰 Cash: $2514.85
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 1, 'TSLA': 18}
# 📉 Total Portfolio Value: $11227.95
# 📊 Step: 124
# 💰 Cash: $2323.42
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 19}
# 📉 Total Portfolio Value: $11280.47
# 📊 Step: 125
# 💰 Cash: $1919.03
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 6, 'MSFT': 1, 'TSLA': 20}
# 📉 Total Portfolio Value: $11313.13
# 📊 Step: 126
# 💰 Cash: $1635.77
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 7, 'MSFT': 0, 'TSLA': 19}
# 📉 Total Portfolio Value: $11573.67
# 📊 Step: 127
# 💰 Cash: $1266.49
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 8, 'MSFT': 1, 'TSLA': 18}
# 📉 Total Portfolio Value: $11633.06
# 📊 Step: 128
# 💰 Cash: $2002.49
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 0, 'TSLA': 18}
# 📉 Total Portfolio Value: $11570.28
# 📊 Step: 129
# 💰 Cash: $1862.25
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 0, 'TSLA': 19}
# 📉 Total Portfolio Value: $11220.03
# 📊 Step: 130
# 💰 Cash: $2299.55
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 20}
# 📉 Total Portfolio Value: $10779.13
# 📊 Step: 131
# 💰 Cash: $2068.78
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $10373.71
# 📊 Step: 132
# 💰 Cash: $2686.89
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $10369.87
# 📊 Step: 133
# 💰 Cash: $3299.36
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 4, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $10659.96
# 📊 Step: 134
# 💰 Cash: $3189.67
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 4, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $11077.22
# 📊 Step: 135
# 💰 Cash: $3076.75
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 4, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $11160.17
# 📊 Step: 136
# 💰 Cash: $3076.75
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 4, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $11123.81
# 📊 Step: 137
# 💰 Cash: $2521.71
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 5, 'MSFT': 1, 'TSLA': 20}
# 📉 Total Portfolio Value: $10807.09
# 📊 Step: 138
# 💰 Cash: $1695.34
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $11103.31
# 📊 Step: 139
# 💰 Cash: $1559.99
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 22}
# 📉 Total Portfolio Value: $11005.57
# 📊 Step: 140
# 💰 Cash: $1168.51
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 7, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $10870.30
# 📊 Step: 141
# 💰 Cash: $430.28
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 8, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $11129.82
# 📊 Step: 142
# 💰 Cash: $317.97
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 8, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $11132.96
# 📊 Step: 143
# 💰 Cash: $559.25
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 22}
# 📉 Total Portfolio Value: $11189.51
# 📊 Step: 144
# 💰 Cash: $1302.95
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 6, 'MSFT': 2, 'TSLA': 21}
# 📉 Total Portfolio Value: $11262.01
# 📊 Step: 145
# 💰 Cash: $1710.88
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 6, 'MSFT': 1, 'TSLA': 20}
# 📉 Total Portfolio Value: $11309.09
# 📊 Step: 146
# 💰 Cash: $2268.51
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 5, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $11383.95
# 📊 Step: 147
# 💰 Cash: $2384.79
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 5, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $11568.87
# 📊 Step: 148
# 💰 Cash: $2627.35
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 4, 'MSFT': 1, 'TSLA': 22}
# 📉 Total Portfolio Value: $11579.50
# 📊 Step: 149
# 💰 Cash: $2523.45
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 4, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $11501.74
# 📊 Step: 150
# 💰 Cash: $3401.51
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 3, 'MSFT': 1, 'TSLA': 22}
# 📉 Total Portfolio Value: $11604.59
# 📊 Step: 151
# 💰 Cash: $3848.40
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 2, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $11496.62
# 📊 Step: 152
# 💰 Cash: $4388.20
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 1, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $11503.15
# 📊 Step: 153
# 💰 Cash: $3576.72
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 2, 'MSFT': 1, 'TSLA': 23}
# 📉 Total Portfolio Value: $11557.21
# 📊 Step: 154
# 💰 Cash: $3768.75
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 2, 'MSFT': 0, 'TSLA': 22}
# 📉 Total Portfolio Value: $11389.33
# 📊 Step: 155
# 💰 Cash: $4665.81
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 1, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $11181.73
# 📊 Step: 156
# 💰 Cash: $5607.64
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 20}
# 📉 Total Portfolio Value: $11129.38
# 📊 Step: 157
# 💰 Cash: $5760.14
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 20}
# 📉 Total Portfolio Value: $11167.94
# 📊 Step: 158
# 💰 Cash: $5511.74
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $10987.54
# 📊 Step: 159
# 💰 Cash: $4715.55
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 21}
# 📉 Total Portfolio Value: $11168.98
# 📊 Step: 160
# 💰 Cash: $5574.54
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 20}
# 📉 Total Portfolio Value: $11144.70
# 📊 Step: 161
# 💰 Cash: $5217.61
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 21}
# 📉 Total Portfolio Value: $11049.63
# 📊 Step: 162
# 💰 Cash: $5022.90
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 22}
# 📉 Total Portfolio Value: $10837.50
# 📊 Step: 163
# 💰 Cash: $5180.48
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 22}
# 📉 Total Portfolio Value: $10715.82
# 📊 Step: 164
# 💰 Cash: $5180.48
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 22}
# 📉 Total Portfolio Value: $10596.26
# 📊 Step: 165
# 💰 Cash: $5513.29
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $10486.87
# 📊 Step: 166
# 💰 Cash: $5401.69
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $10564.89
# 📊 Step: 167
# 💰 Cash: $5247.34
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 22}
# 📉 Total Portfolio Value: $10506.22
# 📊 Step: 168
# 💰 Cash: $4396.73
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 1, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $10627.32
# 📊 Step: 169
# 💰 Cash: $5089.75
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $10755.14
# 📊 Step: 170
# 💰 Cash: $4230.95
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 24}
# 📉 Total Portfolio Value: $10788.11
# 📊 Step: 171
# 💰 Cash: $4050.47
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 1, 'MSFT': 0, 'TSLA': 25}
# 📉 Total Portfolio Value: $10397.53
# 📊 Step: 172
# 💰 Cash: $4517.44
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 26}
# 📉 Total Portfolio Value: $10321.06
# 📊 Step: 173
# 💰 Cash: $4356.48
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 26}
# 📉 Total Portfolio Value: $10371.23
# 📊 Step: 174
# 💰 Cash: $4192.95
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 26}
# 📉 Total Portfolio Value: $10330.43
# 📊 Step: 175
# 💰 Cash: $4312.03
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 26}
# 📉 Total Portfolio Value: $10478.41
# 📊 Step: 176
# 💰 Cash: $4266.30
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 27}
# 📉 Total Portfolio Value: $10343.09
# 📊 Step: 177
# 💰 Cash: $4591.20
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 26}
# 📉 Total Portfolio Value: $10420.68
# 📊 Step: 178
# 💰 Cash: $4432.22
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 27}
# 📉 Total Portfolio Value: $10387.29
# 📊 Step: 179
# 💰 Cash: $4046.70
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 28}
# 📉 Total Portfolio Value: $10251.88
# 📊 Step: 180
# 💰 Cash: $3994.06
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 28}
# 📉 Total Portfolio Value: $10450.20
# 📊 Step: 181
# 💰 Cash: $3392.17
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 27}
# 📉 Total Portfolio Value: $10310.87
# 📊 Step: 182
# 💰 Cash: $4417.76
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 26}
# 📉 Total Portfolio Value: $10914.94
# 📊 Step: 183
# 💰 Cash: $4539.76
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 26}
# 📉 Total Portfolio Value: $10916.38
# 📊 Step: 184
# 💰 Cash: $4186.16
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 25}
# 📉 Total Portfolio Value: $10932.74
# 📊 Step: 185
# 💰 Cash: $3369.64
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 2, 'MSFT': 2, 'TSLA': 25}
# 📉 Total Portfolio Value: $10741.32
# 📊 Step: 186
# 💰 Cash: $3715.54
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 2, 'TSLA': 24}
# 📉 Total Portfolio Value: $10535.08
# 📊 Step: 187
# 💰 Cash: $4473.80
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 1, 'MSFT': 2, 'TSLA': 24}
# 📉 Total Portfolio Value: $10604.27
# 📊 Step: 188
# 💰 Cash: $3592.44
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 2, 'MSFT': 2, 'TSLA': 24}
# 📉 Total Portfolio Value: $10438.42
# 📊 Step: 189
# 💰 Cash: $4020.31
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 1, 'MSFT': 2, 'TSLA': 25}
# 📉 Total Portfolio Value: $10270.49
# 📊 Step: 190
# 💰 Cash: $3185.39
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 2, 'MSFT': 2, 'TSLA': 26}
# 📉 Total Portfolio Value: $10479.99
# 📊 Step: 191
# 💰 Cash: $3875.40
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 26}
# 📉 Total Portfolio Value: $10465.73
# 📊 Step: 192
# 💰 Cash: $3068.70
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 2, 'MSFT': 0, 'TSLA': 26}
# 📉 Total Portfolio Value: $10688.41
# 📊 Step: 193
# 💰 Cash: $2254.84
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 3, 'MSFT': 1, 'TSLA': 26}
# 📉 Total Portfolio Value: $10711.74
# 📊 Step: 194
# 💰 Cash: $2541.48
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 3, 'MSFT': 2, 'TSLA': 25}
# 📉 Total Portfolio Value: $10719.71
# 📊 Step: 195
# 💰 Cash: $3473.38
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 2, 'MSFT': 1, 'TSLA': 24}
# 📉 Total Portfolio Value: $10660.22
# 📊 Step: 196
# 💰 Cash: $3754.69
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 2, 'MSFT': 2, 'TSLA': 23}
# 📉 Total Portfolio Value: $10659.96
# 📊 Step: 197
# 💰 Cash: $3581.56
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 2, 'MSFT': 3, 'TSLA': 23}
# 📉 Total Portfolio Value: $10916.96
# 📊 Step: 198
# 💰 Cash: $4580.46
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 1, 'MSFT': 3, 'TSLA': 22}
# 📉 Total Portfolio Value: $10963.07
# 📊 Step: 199
# 💰 Cash: $5412.30
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 21}
# 📉 Total Portfolio Value: $10938.36
# 📊 Step: 200
# 💰 Cash: $4825.36
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 1, 'MSFT': 5, 'TSLA': 20}
# 📉 Total Portfolio Value: $11098.41
# 📊 Step: 201
# 💰 Cash: $4161.42
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 2, 'MSFT': 5, 'TSLA': 19}
# 📉 Total Portfolio Value: $10982.38
# 📊 Step: 202
# 💰 Cash: $4277.13
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 2, 'MSFT': 5, 'TSLA': 18}
# 📉 Total Portfolio Value: $10964.51
# 📊 Step: 203
# 💰 Cash: $3802.64
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 3, 'MSFT': 6, 'TSLA': 17}
# 📉 Total Portfolio Value: $10987.34
# 📊 Step: 204
# 💰 Cash: $4756.32
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 2, 'MSFT': 7, 'TSLA': 16}
# 📉 Total Portfolio Value: $10982.45
# 📊 Step: 205
# 💰 Cash: $4270.27
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 3, 'MSFT': 6, 'TSLA': 15}
# 📉 Total Portfolio Value: $10922.38
# 📊 Step: 206
# 💰 Cash: $5216.34
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 2, 'MSFT': 7, 'TSLA': 14}
# 📉 Total Portfolio Value: $10847.68
# 📊 Step: 207
# 💰 Cash: $4936.84
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 2, 'MSFT': 8, 'TSLA': 15}
# 📉 Total Portfolio Value: $10885.98
# 📊 Step: 208
# 💰 Cash: $4648.87
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 2, 'MSFT': 7, 'TSLA': 16}
# 📉 Total Portfolio Value: $10679.53
# 📊 Step: 209
# 💰 Cash: $5015.03
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 1, 'MSFT': 8, 'TSLA': 17}
# 📉 Total Portfolio Value: $10721.91
# 📊 Step: 210
# 💰 Cash: $4307.63
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 2, 'MSFT': 7, 'TSLA': 17}
# 📉 Total Portfolio Value: $10746.17
# 📊 Step: 211
# 💰 Cash: $5233.41
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 1, 'MSFT': 6, 'TSLA': 17}
# 📉 Total Portfolio Value: $11001.49
# 📊 Step: 212
# 💰 Cash: $4289.35
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 2, 'MSFT': 7, 'TSLA': 17}
# 📉 Total Portfolio Value: $10949.40
# 📊 Step: 213
# 💰 Cash: $3861.89
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 3, 'MSFT': 7, 'TSLA': 16}
# 📉 Total Portfolio Value: $10834.89
# 📊 Step: 214
# 💰 Cash: $3809.99
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 3, 'MSFT': 6, 'TSLA': 16}
# 📉 Total Portfolio Value: $10893.64
# 📊 Step: 215
# 💰 Cash: $4338.23
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 2, 'MSFT': 6, 'TSLA': 17}
# 📉 Total Portfolio Value: $10864.35
# 📊 Step: 216
# 💰 Cash: $5387.19
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 1, 'MSFT': 7, 'TSLA': 16}
# 📉 Total Portfolio Value: $10873.30
# 📊 Step: 217
# 💰 Cash: $6320.13
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 16}
# 📉 Total Portfolio Value: $10883.42
# 📊 Step: 218
# 💰 Cash: $6033.89
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 0, 'MSFT': 7, 'TSLA': 17}
# 📉 Total Portfolio Value: $10851.79
# 📊 Step: 219
# 💰 Cash: $5927.07
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 0, 'MSFT': 7, 'TSLA': 17}
# 📉 Total Portfolio Value: $11007.59
# 📊 Step: 220
# 💰 Cash: $4967.82
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 1, 'MSFT': 8, 'TSLA': 17}
# 📉 Total Portfolio Value: $11007.37
# 📊 Step: 221
# 💰 Cash: $3939.43
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 2, 'MSFT': 8, 'TSLA': 18}
# 📉 Total Portfolio Value: $10996.29
# 📊 Step: 222
# 💰 Cash: $3345.95
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 3, 'MSFT': 9, 'TSLA': 17}
# 📉 Total Portfolio Value: $10652.89
# 📊 Step: 223
# 💰 Cash: $3721.83
# 📈 Holdings: {'AAPL': 8, 'GOOGL': 2, 'MSFT': 10, 'TSLA': 18}
# 📉 Total Portfolio Value: $10638.81
# 📊 Step: 224
# 💰 Cash: $4380.65
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 1, 'MSFT': 10, 'TSLA': 18}
# 📉 Total Portfolio Value: $10529.50
# 📊 Step: 225
# 💰 Cash: $3793.71
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 2, 'MSFT': 9, 'TSLA': 17}
# 📉 Total Portfolio Value: $10375.79
# 📊 Step: 226
# 💰 Cash: $3578.06
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 2, 'MSFT': 9, 'TSLA': 18}
# 📉 Total Portfolio Value: $10278.45
# 📊 Step: 227
# 💰 Cash: $2583.82
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 3, 'MSFT': 10, 'TSLA': 19}
# 📉 Total Portfolio Value: $10240.48
# 📊 Step: 228
# 💰 Cash: $3675.57
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 2, 'MSFT': 9, 'TSLA': 18}
# 📉 Total Portfolio Value: $10320.37
# 📊 Step: 229
# 💰 Cash: $3575.61
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 2, 'MSFT': 9, 'TSLA': 18}
# 📉 Total Portfolio Value: $10058.99
# 📊 Step: 230
# 💰 Cash: $2953.43
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 3, 'MSFT': 9, 'TSLA': 18}
# 📉 Total Portfolio Value: $10232.51
# 📊 Step: 231
# 💰 Cash: $3837.89
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 2, 'MSFT': 10, 'TSLA': 17}
# 📉 Total Portfolio Value: $10127.77
# 📊 Step: 232
# 💰 Cash: $3586.76
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 2, 'MSFT': 9, 'TSLA': 18}
# 📉 Total Portfolio Value: $10131.52
# 📊 Step: 233
# 💰 Cash: $2771.02
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 3, 'MSFT': 9, 'TSLA': 18}
# 📉 Total Portfolio Value: $10025.10
# 📊 Step: 234
# 💰 Cash: $3438.46
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 2, 'MSFT': 8, 'TSLA': 19}
# 📉 Total Portfolio Value: $10058.07
# 📊 Step: 235
# 💰 Cash: $2808.09
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 3, 'MSFT': 8, 'TSLA': 19}
# 📉 Total Portfolio Value: $10224.02
# 📊 Step: 236
# 💰 Cash: $2062.63
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 4, 'MSFT': 8, 'TSLA': 19}
# 📉 Total Portfolio Value: $10037.61
# 📊 Step: 237
# 💰 Cash: $2552.22
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 3, 'MSFT': 7, 'TSLA': 20}
# 📉 Total Portfolio Value: $9989.88
# 📊 Step: 238
# 💰 Cash: $3631.73
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 2, 'MSFT': 6, 'TSLA': 19}
# 📉 Total Portfolio Value: $9788.32
# 📊 Step: 239
# 💰 Cash: $2914.15
# 📈 Holdings: {'AAPL': 9, 'GOOGL': 3, 'MSFT': 6, 'TSLA': 19}
# 📉 Total Portfolio Value: $9922.49
# 📊 Step: 240
# 💰 Cash: $2766.48
# 📈 Holdings: {'AAPL': 8, 'GOOGL': 3, 'MSFT': 7, 'TSLA': 20}
# 📉 Total Portfolio Value: $10038.88
# 📊 Step: 241
# 💰 Cash: $3527.83
# 📈 Holdings: {'AAPL': 8, 'GOOGL': 2, 'MSFT': 7, 'TSLA': 20}
# 📉 Total Portfolio Value: $10162.58
# 📊 Step: 242
# 💰 Cash: $4252.80
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 1, 'MSFT': 6, 'TSLA': 21}
# 📉 Total Portfolio Value: $9851.45
# 📊 Step: 243
# 💰 Cash: $4199.80
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 1, 'MSFT': 7, 'TSLA': 21}
# 📉 Total Portfolio Value: $9631.83
# 📊 Step: 244
# 💰 Cash: $5070.50
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 0, 'MSFT': 8, 'TSLA': 20}
# 📉 Total Portfolio Value: $9669.30
# 📊 Step: 245
# 💰 Cash: $4567.80
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 1, 'MSFT': 7, 'TSLA': 19}
# 📉 Total Portfolio Value: $9370.22
# 📊 Step: 246
# 💰 Cash: $3751.60
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 2, 'MSFT': 6, 'TSLA': 20}
# 📉 Total Portfolio Value: $9081.25
# 📊 Step: 247
# 💰 Cash: $3702.19
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 2, 'MSFT': 7, 'TSLA': 20}
# 📉 Total Portfolio Value: $9079.12
# 📊 Step: 248
# 💰 Cash: $4209.25
# 📈 Holdings: {'AAPL': 8, 'GOOGL': 1, 'MSFT': 6, 'TSLA': 21}
# 📉 Total Portfolio Value: $8985.59
# 📊 Step: 249
# 💰 Cash: $3502.71
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 2, 'MSFT': 5, 'TSLA': 22}
# 📉 Total Portfolio Value: $9130.12
# 📊 Step: 250
# 💰 Cash: $2689.89
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 3, 'MSFT': 6, 'TSLA': 23}
# 📉 Total Portfolio Value: $9151.42
# 📊 Step: 251
# 💰 Cash: $3547.82
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 2, 'MSFT': 6, 'TSLA': 22}
# 📉 Total Portfolio Value: $9283.22
# 📊 Step: 252
# 💰 Cash: $3593.37
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 2, 'MSFT': 7, 'TSLA': 22}
# 📉 Total Portfolio Value: $9625.81
# 📊 Step: 253
# 💰 Cash: $2843.26
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 3, 'MSFT': 6, 'TSLA': 23}
# 📉 Total Portfolio Value: $9529.68
# 📊 Step: 254
# 💰 Cash: $3683.47
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 2, 'MSFT': 5, 'TSLA': 22}
# 📉 Total Portfolio Value: $9531.75
# 📊 Step: 255
# 💰 Cash: $3727.69
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 2, 'MSFT': 6, 'TSLA': 22}
# 📉 Total Portfolio Value: $9799.49
# 📊 Step: 256
# 💰 Cash: $4359.86
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 1, 'MSFT': 6, 'TSLA': 22}
# 📉 Total Portfolio Value: $9756.30
# 📊 Step: 257
# 💰 Cash: $3414.18
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 2, 'MSFT': 7, 'TSLA': 23}
# 📉 Total Portfolio Value: $9813.00
# 📊 Step: 258
# 💰 Cash: $4103.54
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 1, 'MSFT': 6, 'TSLA': 24}
# 📉 Total Portfolio Value: $10030.62
# 📊 Step: 259
# 💰 Cash: $4155.64
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 1, 'MSFT': 5, 'TSLA': 24}
# 📉 Total Portfolio Value: $10092.80
# 📊 Step: 260
# 💰 Cash: $3718.03
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 2, 'MSFT': 5, 'TSLA': 23}
# 📉 Total Portfolio Value: $10111.33
# 📊 Step: 261
# 💰 Cash: $4289.13
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 1, 'MSFT': 6, 'TSLA': 24}
# 📉 Total Portfolio Value: $10020.24
# 📊 Step: 262
# 💰 Cash: $3886.42
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 2, 'MSFT': 5, 'TSLA': 23}
# 📉 Total Portfolio Value: $10062.70
# 📊 Step: 263
# 💰 Cash: $4228.46
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 4, 'TSLA': 22}
# 📉 Total Portfolio Value: $10207.32
# 📊 Step: 264
# 💰 Cash: $5054.29
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 1, 'MSFT': 4, 'TSLA': 21}
# 📉 Total Portfolio Value: $10317.48
# 📊 Step: 265
# 💰 Cash: $5008.29
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 1, 'MSFT': 3, 'TSLA': 22}
# 📉 Total Portfolio Value: $10390.56
# 📊 Step: 266
# 💰 Cash: $4854.03
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 1, 'MSFT': 2, 'TSLA': 23}
# 📉 Total Portfolio Value: $10330.66
# 📊 Step: 267
# 💰 Cash: $4703.08
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 24}
# 📉 Total Portfolio Value: $10490.61
# 📊 Step: 268
# 💰 Cash: $5481.33
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 24}
# 📉 Total Portfolio Value: $10405.65
# 📊 Step: 269
# 💰 Cash: $4697.11
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 24}
# 📉 Total Portfolio Value: $10475.05
# 📊 Step: 270
# 💰 Cash: $4159.74
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 1, 'TSLA': 23}
# 📉 Total Portfolio Value: $10661.84
# 📊 Step: 271
# 💰 Cash: $4428.06
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 2, 'MSFT': 0, 'TSLA': 22}
# 📉 Total Portfolio Value: $10732.68
# 📊 Step: 272
# 💰 Cash: $3895.83
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 3, 'MSFT': 0, 'TSLA': 21}
# 📉 Total Portfolio Value: $10828.44
# 📊 Step: 273
# 💰 Cash: $2978.15
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 4, 'MSFT': 1, 'TSLA': 21}
# 📉 Total Portfolio Value: $10926.51
# 📊 Step: 274
# 💰 Cash: $1942.15
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 5, 'MSFT': 0, 'TSLA': 22}
# 📉 Total Portfolio Value: $11051.32
# 📊 Step: 275
# 💰 Cash: $1080.82
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 6, 'MSFT': 0, 'TSLA': 22}
# 📉 Total Portfolio Value: $11214.55
# 📊 Step: 276
# 💰 Cash: $1550.80
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 5, 'MSFT': 1, 'TSLA': 23}
# 📉 Total Portfolio Value: $11112.80
# 📊 Step: 277
# 💰 Cash: $2438.37
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 4, 'MSFT': 1, 'TSLA': 22}
# 📉 Total Portfolio Value: $10843.86
# 📊 Step: 278
# 💰 Cash: $2713.11
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 4, 'MSFT': 2, 'TSLA': 21}
# 📉 Total Portfolio Value: $10940.65
# 📊 Step: 279
# 💰 Cash: $2992.32
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 4, 'MSFT': 3, 'TSLA': 20}
# 📉 Total Portfolio Value: $10981.64
# 📊 Step: 280
# 💰 Cash: $2469.30
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 5, 'MSFT': 3, 'TSLA': 19}
# 📉 Total Portfolio Value: $11050.71
# 📊 Step: 281
# 💰 Cash: $1825.86
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 6, 'MSFT': 3, 'TSLA': 18}
# 📉 Total Portfolio Value: $11013.75
# 📊 Step: 282
# 💰 Cash: $2539.15
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 5, 'MSFT': 4, 'TSLA': 18}
# 📉 Total Portfolio Value: $11037.40
# 📊 Step: 283
# 💰 Cash: $2713.69
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 5, 'MSFT': 5, 'TSLA': 17}
# 📉 Total Portfolio Value: $11208.89
# 📊 Step: 284
# 💰 Cash: $1871.99
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 4, 'TSLA': 18}
# 📉 Total Portfolio Value: $11352.49
# 📊 Step: 285
# 💰 Cash: $1927.42
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 3, 'TSLA': 18}
# 📉 Total Portfolio Value: $11460.60
# 📊 Step: 286
# 💰 Cash: $1333.22
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 2, 'TSLA': 18}
# 📉 Total Portfolio Value: $11708.47
# 📊 Step: 287
# 💰 Cash: $2421.83
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 6, 'MSFT': 1, 'TSLA': 17}
# 📉 Total Portfolio Value: $11517.95
# 📊 Step: 288
# 💰 Cash: $1755.91
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 7, 'MSFT': 2, 'TSLA': 16}
# 📉 Total Portfolio Value: $11399.48
# 📊 Step: 289
# 💰 Cash: $855.03
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 8, 'MSFT': 2, 'TSLA': 17}
# 📉 Total Portfolio Value: $11381.63
# 📊 Step: 290
# 💰 Cash: $10.90
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 9, 'MSFT': 1, 'TSLA': 18}
# 📉 Total Portfolio Value: $11405.19
# 📊 Step: 291
# 💰 Cash: $829.87
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 8, 'MSFT': 0, 'TSLA': 18}
# 📉 Total Portfolio Value: $11586.69
# 📊 Step: 292
# 💰 Cash: $312.49
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 9, 'MSFT': 0, 'TSLA': 17}
# 📉 Total Portfolio Value: $11572.62
# 📊 Step: 293
# 💰 Cash: $200.39
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 9, 'MSFT': 0, 'TSLA': 17}
# 📉 Total Portfolio Value: $11656.91
# 📊 Step: 294
# 💰 Cash: $454.90
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 9, 'MSFT': 0, 'TSLA': 16}
# 📉 Total Portfolio Value: $11713.58
# 📊 Step: 295
# 💰 Cash: $1496.46
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 8, 'MSFT': 0, 'TSLA': 15}
# 📉 Total Portfolio Value: $11523.92
# 📊 Step: 296
# 💰 Cash: $1918.43
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 7, 'MSFT': 0, 'TSLA': 16}
# 📉 Total Portfolio Value: $11556.65
# 📊 Step: 297
# 💰 Cash: $786.41
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 8, 'MSFT': 0, 'TSLA': 17}
# 📉 Total Portfolio Value: $11565.25
# 📊 Step: 298
# 💰 Cash: $588.31
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 8, 'MSFT': 1, 'TSLA': 18}
# 📉 Total Portfolio Value: $11321.11
# 📊 Step: 299
# 💰 Cash: $440.24
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 8, 'MSFT': 1, 'TSLA': 19}
# 📉 Total Portfolio Value: $11319.69
# 📊 Step: 300
# 💰 Cash: $983.60
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 2, 'TSLA': 20}
# 📉 Total Portfolio Value: $11238.87
# 📊 Step: 301
# 💰 Cash: $729.86
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 2, 'TSLA': 21}
# 📉 Total Portfolio Value: $11162.83
# 📊 Step: 302
# 💰 Cash: $529.33
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 22}
# 📉 Total Portfolio Value: $10964.27
# 📊 Step: 303
# 💰 Cash: $331.52
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 0, 'TSLA': 23}
# 📉 Total Portfolio Value: $10824.16
# 📊 Step: 304
# 💰 Cash: $428.67
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 22}
# 📉 Total Portfolio Value: $10893.39
# 📊 Step: 305
# 💰 Cash: $280.51
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 23}
# 📉 Total Portfolio Value: $10632.73
# 📊 Step: 306
# 💰 Cash: $230.73
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 2, 'TSLA': 23}
# 📉 Total Portfolio Value: $10428.94
# 📊 Step: 307
# 💰 Cash: $230.73
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 2, 'TSLA': 23}
# 📉 Total Portfolio Value: $10198.77
# 📊 Step: 308
# 💰 Cash: $280.67
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 1, 'TSLA': 23}
# 📉 Total Portfolio Value: $10350.71
# 📊 Step: 309
# 💰 Cash: $15.35
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 2, 'TSLA': 24}
# 📉 Total Portfolio Value: $10233.48
# 📊 Step: 310
# 💰 Cash: $15.35
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 2, 'TSLA': 24}
# 📉 Total Portfolio Value: $10301.61
# 📊 Step: 311
# 💰 Cash: $224.04
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 2, 'TSLA': 23}
# 📉 Total Portfolio Value: $10246.07
# 📊 Step: 312
# 💰 Cash: $954.59
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 2, 'TSLA': 23}
# 📉 Total Portfolio Value: $10193.47
# 📊 Step: 313
# 💰 Cash: $175.01
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 3, 'TSLA': 23}
# 📉 Total Portfolio Value: $10177.09
# 📊 Step: 314
# 💰 Cash: $331.54
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 4, 'TSLA': 22}
# 📉 Total Portfolio Value: $10233.34
# 📊 Step: 315
# 💰 Cash: $801.72
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 5, 'TSLA': 23}
# 📉 Total Portfolio Value: $10082.59
# 📊 Step: 316
# 💰 Cash: $1521.91
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 5, 'TSLA': 23}
# 📉 Total Portfolio Value: $10241.77
# 📊 Step: 317
# 💰 Cash: $800.13
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 5, 'TSLA': 23}
# 📉 Total Portfolio Value: $10293.42
# 📊 Step: 318
# 💰 Cash: $300.03
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 5, 'TSLA': 22}
# 📉 Total Portfolio Value: $10451.26
# 📊 Step: 319
# 💰 Cash: $79.75
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 5, 'TSLA': 23}
# 📉 Total Portfolio Value: $10323.71
# 📊 Step: 320
# 💰 Cash: $79.75
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 5, 'TSLA': 23}
# 📉 Total Portfolio Value: $10480.84
# 📊 Step: 321
# 💰 Cash: $349.25
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 4, 'TSLA': 22}
# 📉 Total Portfolio Value: $10555.19
# 📊 Step: 322
# 💰 Cash: $1035.23
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 5, 'TSLA': 22}
# 📉 Total Portfolio Value: $10668.90
# 📊 Step: 323
# 💰 Cash: $934.82
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 6, 'MSFT': 5, 'TSLA': 22}
# 📉 Total Portfolio Value: $10689.25
# 📊 Step: 324
# 💰 Cash: $562.93
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 4, 'TSLA': 21}
# 📉 Total Portfolio Value: $10704.71
# 📊 Step: 325
# 💰 Cash: $186.84
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 5, 'TSLA': 22}
# 📉 Total Portfolio Value: $10619.09
# 📊 Step: 326
# 💰 Cash: $980.91
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 6, 'TSLA': 22}
# 📉 Total Portfolio Value: $10578.53
# 📊 Step: 327
# 💰 Cash: $1199.87
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 6, 'TSLA': 21}
# 📉 Total Portfolio Value: $10524.56
# 📊 Step: 328
# 💰 Cash: $193.23
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 7, 'TSLA': 22}
# 📉 Total Portfolio Value: $10523.52
# 📊 Step: 329
# 💰 Cash: $1091.84
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 8, 'TSLA': 21}
# 📉 Total Portfolio Value: $10774.32
# 📊 Step: 330
# 💰 Cash: $308.65
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 9, 'TSLA': 21}
# 📉 Total Portfolio Value: $10923.44
# 📊 Step: 331
# 💰 Cash: $73.13
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 9, 'TSLA': 22}
# 📉 Total Portfolio Value: $10781.27
# 📊 Step: 332
# 💰 Cash: $1045.01
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 9, 'TSLA': 21}
# 📉 Total Portfolio Value: $10502.06
# 📊 Step: 333
# 💰 Cash: $1778.20
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 5, 'MSFT': 9, 'TSLA': 21}
# 📉 Total Portfolio Value: $10464.13
# 📊 Step: 334
# 💰 Cash: $828.45
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 6, 'MSFT': 9, 'TSLA': 22}
# 📉 Total Portfolio Value: $10405.54
# 📊 Step: 335
# 💰 Cash: $145.03
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 8, 'TSLA': 22}
# 📉 Total Portfolio Value: $10457.28
# 📊 Step: 336
# 💰 Cash: $47.89
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 8, 'TSLA': 22}
# 📉 Total Portfolio Value: $10412.77
# 📊 Step: 337
# 💰 Cash: $265.82
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 7, 'MSFT': 8, 'TSLA': 21}
# 📉 Total Portfolio Value: $10216.81
# 📊 Step: 338
# 💰 Cash: $145.68
# 📈 Holdings: {'AAPL': 0, 'GOOGL': 7, 'MSFT': 8, 'TSLA': 22}
# 📉 Total Portfolio Value: $10322.55
# 📊 Step: 339
# 💰 Cash: $587.08
# 📈 Holdings: {'AAPL': 1, 'GOOGL': 6, 'MSFT': 7, 'TSLA': 23}
# 📉 Total Portfolio Value: $10345.63
# 📊 Step: 340
# 💰 Cash: $271.56
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 7, 'TSLA': 24}
# 📉 Total Portfolio Value: $9802.25
# 📊 Step: 341
# 💰 Cash: $740.81
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 5, 'MSFT': 6, 'TSLA': 25}
# 📉 Total Portfolio Value: $9824.92
# 📊 Step: 342
# 💰 Cash: $785.00
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 5, 'MSFT': 7, 'TSLA': 25}
# 📉 Total Portfolio Value: $9575.36
# 📊 Step: 343
# 💰 Cash: $6.40
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 6, 'MSFT': 7, 'TSLA': 25}
# 📉 Total Portfolio Value: $9672.12
# 📊 Step: 344
# 💰 Cash: $50.01
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 6, 'MSFT': 8, 'TSLA': 25}
# 📉 Total Portfolio Value: $9825.02
# 📊 Step: 345
# 💰 Cash: $490.04
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 5, 'MSFT': 9, 'TSLA': 26}
# 📉 Total Portfolio Value: $10074.59
# 📊 Step: 346
# 💰 Cash: $1445.96
# 📈 Holdings: {'AAPL': 2, 'GOOGL': 4, 'MSFT': 8, 'TSLA': 25}
# 📉 Total Portfolio Value: $10167.64
# 📊 Step: 347
# 💰 Cash: $2215.00
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 3, 'MSFT': 9, 'TSLA': 24}
# 📉 Total Portfolio Value: $10289.86
# 📊 Step: 348
# 💰 Cash: $1851.45
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 3, 'MSFT': 10, 'TSLA': 25}
# 📉 Total Portfolio Value: $10207.28
# 📊 Step: 349
# 💰 Cash: $983.75
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 4, 'MSFT': 9, 'TSLA': 26}
# 📉 Total Portfolio Value: $10239.61
# 📊 Step: 350
# 💰 Cash: $820.69
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 4, 'MSFT': 8, 'TSLA': 27}
# 📉 Total Portfolio Value: $10274.91
# 📊 Step: 351
# 💰 Cash: $209.37
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 5, 'MSFT': 8, 'TSLA': 27}
# 📉 Total Portfolio Value: $10359.77
# 📊 Step: 352
# 💰 Cash: $830.47
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 4, 'MSFT': 8, 'TSLA': 27}
# 📉 Total Portfolio Value: $10616.97
# 📊 Step: 353
# 💰 Cash: $980.04
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 4, 'MSFT': 7, 'TSLA': 27}
# 📉 Total Portfolio Value: $10640.36
# 📊 Step: 354
# 💰 Cash: $882.62
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 4, 'MSFT': 7, 'TSLA': 27}
# 📉 Total Portfolio Value: $10570.90
# 📊 Step: 355
# 💰 Cash: $1737.76
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 3, 'MSFT': 7, 'TSLA': 26}
# 📉 Total Portfolio Value: $10575.07
# 📊 Step: 356
# 💰 Cash: $2847.62
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 2, 'MSFT': 6, 'TSLA': 25}
# 📉 Total Portfolio Value: $10546.20
# 📊 Step: 357
# 💰 Cash: $2802.54
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 2, 'MSFT': 5, 'TSLA': 25}
# 📉 Total Portfolio Value: $10734.14
# 📊 Step: 358
# 💰 Cash: $3935.78
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 1, 'MSFT': 4, 'TSLA': 24}
# 📉 Total Portfolio Value: $10707.27
# 📊 Step: 359
# 💰 Cash: $3657.43
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 1, 'MSFT': 5, 'TSLA': 25}
# 📉 Total Portfolio Value: $10802.90
# 📊 Step: 360
# 💰 Cash: $4086.19
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 26}
# 📉 Total Portfolio Value: $10595.34
# 📊 Step: 361
# 💰 Cash: $3288.15
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 1, 'MSFT': 4, 'TSLA': 26}
# 📉 Total Portfolio Value: $10644.69
# 📊 Step: 362
# 💰 Cash: $2585.44
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 2, 'MSFT': 3, 'TSLA': 26}
# 📉 Total Portfolio Value: $10834.97
# 📊 Step: 363
# 💰 Cash: $2912.79
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 2, 'MSFT': 3, 'TSLA': 25}
# 📉 Total Portfolio Value: $10819.47
# 📊 Step: 364
# 💰 Cash: $2424.56
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 3, 'MSFT': 4, 'TSLA': 24}
# 📉 Total Portfolio Value: $10830.79
# 📊 Step: 365
# 💰 Cash: $3517.97
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 2, 'MSFT': 4, 'TSLA': 23}
# 📉 Total Portfolio Value: $10891.54
# 📊 Step: 366
# 💰 Cash: $3574.18
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 2, 'MSFT': 3, 'TSLA': 23}
# 📉 Total Portfolio Value: $11039.70
# 📊 Step: 367
# 💰 Cash: $4552.78
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 1, 'MSFT': 2, 'TSLA': 22}
# 📉 Total Portfolio Value: $10951.30
# 📊 Step: 368
# 💰 Cash: $5527.15
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 21}
# 📉 Total Portfolio Value: $10886.01
# 📊 Step: 369
# 💰 Cash: $5697.77
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 20}
# 📉 Total Portfolio Value: $10864.61
# 📊 Step: 370
# 💰 Cash: $6086.32
# 📈 Holdings: {'AAPL': 3, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 19}
# 📉 Total Portfolio Value: $10957.69
# 📊 Step: 371
# 💰 Cash: $6153.67
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 18}
# 📉 Total Portfolio Value: $10955.97
# 📊 Step: 372
# 💰 Cash: $5404.70
# 📈 Holdings: {'AAPL': 4, 'GOOGL': 1, 'MSFT': 3, 'TSLA': 18}
# 📉 Total Portfolio Value: $10888.47
# 📊 Step: 373
# 💰 Cash: $5522.49
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 1, 'MSFT': 3, 'TSLA': 17}
# 📉 Total Portfolio Value: $10942.98
# 📊 Step: 374
# 💰 Cash: $5809.77
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 1, 'MSFT': 2, 'TSLA': 16}
# 📉 Total Portfolio Value: $10884.70
# 📊 Step: 375
# 💰 Cash: $6334.59
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 17}
# 📉 Total Portfolio Value: $10872.61
# 📊 Step: 376
# 💰 Cash: $6284.96
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 17}
# 📉 Total Portfolio Value: $10885.29
# 📊 Step: 377
# 💰 Cash: $6117.29
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 18}
# 📉 Total Portfolio Value: $10892.91
# 📊 Step: 378
# 💰 Cash: $5949.82
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 19}
# 📉 Total Portfolio Value: $10854.69
# 📊 Step: 379
# 💰 Cash: $5424.18
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 18}
# 📉 Total Portfolio Value: $10851.58
# 📊 Step: 380
# 💰 Cash: $5839.58
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 19}
# 📉 Total Portfolio Value: $10855.95
# 📊 Step: 381
# 💰 Cash: $5839.58
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 19}
# 📉 Total Portfolio Value: $10885.98
# 📊 Step: 382
# 💰 Cash: $5614.58
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 20}
# 📉 Total Portfolio Value: $10839.58
# 📊 Step: 383
# 💰 Cash: $4868.47
# 📈 Holdings: {'AAPL': 5, 'GOOGL': 1, 'MSFT': 3, 'TSLA': 20}
# 📉 Total Portfolio Value: $10879.78
# 📊 Step: 384
# 💰 Cash: $4592.67
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 1, 'MSFT': 2, 'TSLA': 21}
# 📉 Total Portfolio Value: $10825.37
# 📊 Step: 385
# 💰 Cash: $3741.12
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 2, 'MSFT': 3, 'TSLA': 21}
# 📉 Total Portfolio Value: $10783.81
# 📊 Step: 386
# 💰 Cash: $4753.38
# 📈 Holdings: {'AAPL': 6, 'GOOGL': 1, 'MSFT': 3, 'TSLA': 20}
# 📉 Total Portfolio Value: $10762.13
# 📊 Step: 387
# 💰 Cash: $5659.65
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 19}
# 📉 Total Portfolio Value: $10670.49
# 📊 Step: 388
# 💰 Cash: $5659.65
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 19}
# 📉 Total Portfolio Value: $10590.78
# 📊 Step: 389
# 💰 Cash: $5495.76
# 📈 Holdings: {'AAPL': 8, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 19}
# 📉 Total Portfolio Value: $10602.59
# 📊 Step: 390
# 💰 Cash: $5659.32
# 📈 Holdings: {'AAPL': 7, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 19}
# 📉 Total Portfolio Value: $10393.83
# 📊 Step: 391
# 💰 Cash: $5695.77
# 📈 Holdings: {'AAPL': 8, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 18}
# ...
# 📉 Total Portfolio Value: $15386.08
# 📊 Step: 623
# 💰 Cash: $425.08
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 35}
# 📉 Total Portfolio Value: $15354.96
# 📊 Step: 624
# 💰 Cash: $228.72
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 36}
# 📉 Total Portfolio Value: $15734.34
# 📊 Step: 625
# 💰 Cash: $228.72
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 36}
# 📉 Total Portfolio Value: $15683.34
# 📊 Step: 626
# 💰 Cash: $301.19
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 36}
# 📉 Total Portfolio Value: $15316.48
# 📊 Step: 627
# 💰 Cash: $74.46
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 36}
# 📉 Total Portfolio Value: $15434.44
# 📊 Step: 628
# 💰 Cash: $231.94
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 36}
# 📉 Total Portfolio Value: $15688.48
# 📊 Step: 629
# 💰 Cash: $435.89
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 35}
# 📉 Total Portfolio Value: $15657.56
# 📊 Step: 630
# 💰 Cash: $308.38
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 36}
# 📉 Total Portfolio Value: $15672.79
# 📊 Step: 631
# 💰 Cash: $758.59
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 35}
# 📉 Total Portfolio Value: $15246.65
# 📊 Step: 632
# 💰 Cash: $1038.11
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 0, 'MSFT': 7, 'TSLA': 34}
# 📉 Total Portfolio Value: $15091.68
# 📊 Step: 633
# 💰 Cash: $184.42
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 1, 'MSFT': 6, 'TSLA': 34}
# 📉 Total Portfolio Value: $14754.74
# 📊 Step: 634
# 💰 Cash: $269.48
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 1, 'MSFT': 7, 'TSLA': 34}
# 📉 Total Portfolio Value: $14925.70
# 📊 Step: 635
# 💰 Cash: $109.70
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 1, 'MSFT': 7, 'TSLA': 34}
# 📉 Total Portfolio Value: $15315.28
# 📊 Step: 636
# 💰 Cash: $182.42
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 1, 'MSFT': 6, 'TSLA': 34}
# 📉 Total Portfolio Value: $15307.04
# 📊 Step: 637
# 💰 Cash: $109.73
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 1, 'MSFT': 7, 'TSLA': 34}
# 📉 Total Portfolio Value: $15142.13
# 📊 Step: 638
# 💰 Cash: $690.46
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 1, 'MSFT': 6, 'TSLA': 33}
# 📉 Total Portfolio Value: $15077.05
# 📊 Step: 639
# 💰 Cash: $344.80
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 1, 'MSFT': 6, 'TSLA': 34}
# 📉 Total Portfolio Value: $15158.19
# 📊 Step: 640
# 💰 Cash: $254.94
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 1, 'MSFT': 5, 'TSLA': 34}
# 📉 Total Portfolio Value: $15373.59
# 📊 Step: 641
# 💰 Cash: $180.93
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 1, 'MSFT': 6, 'TSLA': 34}
# 📉 Total Portfolio Value: $15489.39
# 📊 Step: 642
# 💰 Cash: $255.70
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 1, 'MSFT': 5, 'TSLA': 34}
# 📉 Total Portfolio Value: $15465.54
# 📊 Step: 643
# 💰 Cash: $17.71
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 1, 'MSFT': 6, 'TSLA': 34}
# 📉 Total Portfolio Value: $15231.87
# 📊 Step: 644
# 💰 Cash: $609.60
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 35}
# 📉 Total Portfolio Value: $15051.47
# 📊 Step: 645
# 💰 Cash: $954.13
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 34}
# 📉 Total Portfolio Value: $15256.03
# 📊 Step: 646
# 💰 Cash: $718.53
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 0, 'MSFT': 7, 'TSLA': 34}
# 📉 Total Portfolio Value: $14974.18
# 📊 Step: 647
# 💰 Cash: $633.88
# 📈 Holdings: {'AAPL': 14, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 34}
# 📉 Total Portfolio Value: $15708.90
# 📊 Step: 648
# 💰 Cash: $761.31
# 📈 Holdings: {'AAPL': 15, 'GOOGL': 0, 'MSFT': 7, 'TSLA': 33}
# 📉 Total Portfolio Value: $15667.72
# 📊 Step: 649
# 💰 Cash: $484.74
# 📈 Holdings: {'AAPL': 14, 'GOOGL': 0, 'MSFT': 8, 'TSLA': 34}
# 📉 Total Portfolio Value: $15773.34
# 📊 Step: 650
# 💰 Cash: $400.30
# 📈 Holdings: {'AAPL': 15, 'GOOGL': 0, 'MSFT': 7, 'TSLA': 34}
# 📉 Total Portfolio Value: $16137.65
# 📊 Step: 651
# 💰 Cash: $852.71
# 📈 Holdings: {'AAPL': 15, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 33}
# 📉 Total Portfolio Value: $16236.50
# 📊 Step: 652
# 💰 Cash: $472.90
# 📈 Holdings: {'AAPL': 15, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 34}
# 📉 Total Portfolio Value: $16393.91
# 📊 Step: 653
# 💰 Cash: $389.39
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 34}
# 📉 Total Portfolio Value: $16059.67
# 📊 Step: 654
# 💰 Cash: $389.39
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 34}
# 📉 Total Portfolio Value: $15974.15
# 📊 Step: 655
# 💰 Cash: $158.38
# 📈 Holdings: {'AAPL': 17, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 34}
# 📉 Total Portfolio Value: $15671.59
# 📊 Step: 656
# 💰 Cash: $604.04
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 0, 'MSFT': 7, 'TSLA': 33}
# 📉 Total Portfolio Value: $15141.12
# 📊 Step: 657
# 💰 Cash: $178.54
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 0, 'MSFT': 8, 'TSLA': 34}
# 📉 Total Portfolio Value: $14903.08
# 📊 Step: 658
# 💰 Cash: $101.25
# 📈 Holdings: {'AAPL': 17, 'GOOGL': 0, 'MSFT': 7, 'TSLA': 34}
# 📉 Total Portfolio Value: $14955.95
# 📊 Step: 659
# 💰 Cash: $254.39
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 0, 'MSFT': 7, 'TSLA': 34}
# 📉 Total Portfolio Value: $14832.00
# 📊 Step: 660
# 💰 Cash: $328.24
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 34}
# 📉 Total Portfolio Value: $14770.34
# 📊 Step: 661
# 💰 Cash: $593.97
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 0, 'MSFT': 7, 'TSLA': 33}
# 📉 Total Portfolio Value: $14837.62
# 📊 Step: 662
# 💰 Cash: $1163.68
# 📈 Holdings: {'AAPL': 15, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 32}
# 📉 Total Portfolio Value: $14847.45
# 📊 Step: 663
# 💰 Cash: $668.34
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 33}
# 📉 Total Portfolio Value: $15074.20
# 📊 Step: 664
# 💰 Cash: $742.60
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 33}
# 📉 Total Portfolio Value: $15287.06
# 📊 Step: 665
# 💰 Cash: $667.91
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 33}
# 📉 Total Portfolio Value: $15335.86
# 📊 Step: 666
# 💰 Cash: $588.49
# 📈 Holdings: {'AAPL': 17, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 33}
# 📉 Total Portfolio Value: $15385.63
# 📊 Step: 667
# 💰 Cash: $307.61
# 📈 Holdings: {'AAPL': 17, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 34}
# 📉 Total Portfolio Value: $14922.01
# 📊 Step: 668
# 💰 Cash: $806.39
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 33}
# 📉 Total Portfolio Value: $15340.42
# 📊 Step: 669
# 💰 Cash: $218.61
# 📈 Holdings: {'AAPL': 17, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 34}
# 📉 Total Portfolio Value: $15318.46
# 📊 Step: 670
# 💰 Cash: $218.61
# 📈 Holdings: {'AAPL': 17, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 34}
# 📉 Total Portfolio Value: $15349.33
# 📊 Step: 671
# 💰 Cash: $807.41
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 33}
# 📉 Total Portfolio Value: $15363.02
# 📊 Step: 672
# 💰 Cash: $729.92
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 33}
# 📉 Total Portfolio Value: $15246.05
# 📊 Step: 673
# 💰 Cash: $807.57
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 33}
# 📉 Total Portfolio Value: $15425.20
# 📊 Step: 674
# 💰 Cash: $968.04
# 📈 Holdings: {'AAPL': 15, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 33}
# 📉 Total Portfolio Value: $15543.33
# 📊 Step: 675
# 💰 Cash: $890.43
# 📈 Holdings: {'AAPL': 15, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 33}
# 📉 Total Portfolio Value: $15229.41
# 📊 Step: 676
# 💰 Cash: $1398.22
# 📈 Holdings: {'AAPL': 14, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 32}
# 📉 Total Portfolio Value: $15022.97
# 📊 Step: 677
# 💰 Cash: $1319.41
# 📈 Holdings: {'AAPL': 14, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 32}
# 📉 Total Portfolio Value: $14763.41
# 📊 Step: 678
# 💰 Cash: $1812.60
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 31}
# 📉 Total Portfolio Value: $14785.60
# 📊 Step: 679
# 💰 Cash: $1318.55
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 1, 'MSFT': 6, 'TSLA': 30}
# 📉 Total Portfolio Value: $14433.91
# 📊 Step: 680
# 💰 Cash: $405.72
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 2, 'MSFT': 5, 'TSLA': 30}
# 📉 Total Portfolio Value: $14456.38
# 📊 Step: 681
# 💰 Cash: $992.32
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 1, 'MSFT': 4, 'TSLA': 31}
# 📉 Total Portfolio Value: $14427.85
# 📊 Step: 682
# 💰 Cash: $587.64
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 1, 'MSFT': 5, 'TSLA': 32}
# 📉 Total Portfolio Value: $14450.14
# 📊 Step: 683
# 💰 Cash: $351.45
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 1, 'MSFT': 4, 'TSLA': 33}
# 📉 Total Portfolio Value: $14855.22
# 📊 Step: 684
# 💰 Cash: $800.74
# 📈 Holdings: {'AAPL': 14, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 34}
# 📉 Total Portfolio Value: $14469.82
# 📊 Step: 685
# 💰 Cash: $871.75
# 📈 Holdings: {'AAPL': 15, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 33}
# 📉 Total Portfolio Value: $13773.28
# 📊 Step: 686
# 💰 Cash: $1086.96
# 📈 Holdings: {'AAPL': 15, 'GOOGL': 0, 'MSFT': 7, 'TSLA': 32}
# 📉 Total Portfolio Value: $14058.32
# 📊 Step: 687
# 💰 Cash: $1343.60
# 📈 Holdings: {'AAPL': 14, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 32}
# 📉 Total Portfolio Value: $13978.88
# 📊 Step: 688
# 💰 Cash: $1130.60
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 0, 'MSFT': 7, 'TSLA': 33}
# 📉 Total Portfolio Value: $14092.67
# 📊 Step: 689
# 💰 Cash: $168.75
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 1, 'MSFT': 8, 'TSLA': 33}
# 📉 Total Portfolio Value: $14063.27
# 📊 Step: 690
# 💰 Cash: $84.19
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 1, 'MSFT': 9, 'TSLA': 33}
# 📉 Total Portfolio Value: $13997.95
# 📊 Step: 691
# 💰 Cash: $175.98
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 1, 'MSFT': 10, 'TSLA': 33}
# 📉 Total Portfolio Value: $13978.87
# 📊 Step: 692
# 💰 Cash: $175.98
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 1, 'MSFT': 10, 'TSLA': 33}
# 📉 Total Portfolio Value: $14378.35
# 📊 Step: 693
# 💰 Cash: $433.88
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 1, 'MSFT': 9, 'TSLA': 33}
# 📉 Total Portfolio Value: $14132.47
# 📊 Step: 694
# 💰 Cash: $178.49
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 1, 'MSFT': 10, 'TSLA': 33}
# 📉 Total Portfolio Value: $14177.48
# 📊 Step: 695
# 💰 Cash: $406.81
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 1, 'MSFT': 11, 'TSLA': 32}
# 📉 Total Portfolio Value: $14252.58
# 📊 Step: 696
# 💰 Cash: $719.31
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 1, 'MSFT': 11, 'TSLA': 31}
# 📉 Total Portfolio Value: $14299.80
# 📊 Step: 697
# 💰 Cash: $492.01
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 1, 'MSFT': 12, 'TSLA': 32}
# 📉 Total Portfolio Value: $14096.51
# 📊 Step: 698
# 💰 Cash: $1526.67
# 📈 Holdings: {'AAPL': 10, 'GOOGL': 0, 'MSFT': 12, 'TSLA': 32}
# 📉 Total Portfolio Value: $14432.63
# 📊 Step: 699
# 💰 Cash: $1119.44
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 0, 'MSFT': 11, 'TSLA': 33}
# 📉 Total Portfolio Value: $14274.01
# 📊 Step: 700
# 💰 Cash: $1027.59
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 10, 'TSLA': 33}
# 📉 Total Portfolio Value: $14372.98
# 📊 Step: 701
# 💰 Cash: $229.30
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 1, 'MSFT': 9, 'TSLA': 33}
# 📉 Total Portfolio Value: $14425.86
# 📊 Step: 702
# 💰 Cash: $455.89
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 1, 'MSFT': 8, 'TSLA': 32}
# 📉 Total Portfolio Value: $14436.66
# 📊 Step: 703
# 💰 Cash: $396.29
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 1, 'MSFT': 7, 'TSLA': 33}
# 📉 Total Portfolio Value: $14030.15
# 📊 Step: 704
# 💰 Cash: $1039.99
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 34}
# 📉 Total Portfolio Value: $14108.11
# 📊 Step: 705
# 💰 Cash: $987.16
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 35}
# 📉 Total Portfolio Value: $14018.56
# 📊 Step: 706
# 💰 Cash: $731.85
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 35}
# 📉 Total Portfolio Value: $13937.93
# 📊 Step: 707
# 💰 Cash: $337.93
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 36}
# 📉 Total Portfolio Value: $13884.40
# 📊 Step: 708
# 💰 Cash: $560.04
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 35}
# 📉 Total Portfolio Value: $14217.95
# 📊 Step: 709
# 💰 Cash: $1125.09
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 34}
# 📉 Total Portfolio Value: $14151.54
# 📊 Step: 710
# 💰 Cash: $873.28
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 34}
# 📉 Total Portfolio Value: $14294.47
# 📊 Step: 711
# 💰 Cash: $873.28
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 34}
# 📉 Total Portfolio Value: $14812.31
# 📊 Step: 712
# 💰 Cash: $700.61
# 📈 Holdings: {'AAPL': 14, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 34}
# 📉 Total Portfolio Value: $15212.91
# 📊 Step: 713
# 💰 Cash: $869.94
# 📈 Holdings: {'AAPL': 15, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 33}
# 📉 Total Portfolio Value: $15154.08
# 📊 Step: 714
# 💰 Cash: $1208.97
# 📈 Holdings: {'AAPL': 15, 'GOOGL': 0, 'MSFT': 6, 'TSLA': 32}
# 📉 Total Portfolio Value: $15112.89
# 📊 Step: 715
# 💰 Cash: $151.50
# 📈 Holdings: {'AAPL': 15, 'GOOGL': 1, 'MSFT': 6, 'TSLA': 32}
# 📉 Total Portfolio Value: $15344.55
# 📊 Step: 716
# 💰 Cash: $238.35
# 📈 Holdings: {'AAPL': 15, 'GOOGL': 1, 'MSFT': 5, 'TSLA': 32}
# 📉 Total Portfolio Value: $15245.48
# 📊 Step: 717
# 💰 Cash: $61.93
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 1, 'MSFT': 5, 'TSLA': 32}
# 📉 Total Portfolio Value: $14958.70
# 📊 Step: 718
# 💰 Cash: $147.76
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 1, 'MSFT': 4, 'TSLA': 32}
# 📉 Total Portfolio Value: $14880.36
# 📊 Step: 719
# 💰 Cash: $1635.82
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 31}
# 📉 Total Portfolio Value: $14973.94
# 📊 Step: 720
# 💰 Cash: $1389.66
# 📈 Holdings: {'AAPL': 16, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 32}
# 📉 Total Portfolio Value: $14767.24
# 📊 Step: 721
# 💰 Cash: $1479.16
# 📈 Holdings: {'AAPL': 15, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 32}
# 📉 Total Portfolio Value: $14447.19
# 📊 Step: 722
# 💰 Cash: $327.91
# 📈 Holdings: {'AAPL': 15, 'GOOGL': 1, 'MSFT': 4, 'TSLA': 32}
# 📉 Total Portfolio Value: $14262.43
# 📊 Step: 723
# 💰 Cash: $1473.82
# 📈 Holdings: {'AAPL': 15, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 32}
# 📉 Total Portfolio Value: $14388.70
# 📊 Step: 724
# 💰 Cash: $1559.18
# 📈 Holdings: {'AAPL': 14, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 32}
# 📉 Total Portfolio Value: $14233.76
# 📊 Step: 725
# 💰 Cash: $1162.29
# 📈 Holdings: {'AAPL': 14, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 33}
# 📉 Total Portfolio Value: $14581.17
# 📊 Step: 726
# 💰 Cash: $1655.08
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 0, 'MSFT': 5, 'TSLA': 32}
# 📉 Total Portfolio Value: $14477.82
# 📊 Step: 727
# 💰 Cash: $1741.43
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 0, 'MSFT': 4, 'TSLA': 32}
# 📉 Total Portfolio Value: $14407.10
# 📊 Step: 728
# 💰 Cash: $418.16
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 1, 'MSFT': 3, 'TSLA': 33}
# 📉 Total Portfolio Value: $14515.16
# 📊 Step: 729
# 💰 Cash: $1036.87
# 📈 Holdings: {'AAPL': 14, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 34}
# 📉 Total Portfolio Value: $15180.55
# 📊 Step: 730
# 💰 Cash: $1461.56
# 📈 Holdings: {'AAPL': 14, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 33}
# 📉 Total Portfolio Value: $15090.39
# 📊 Step: 731
# 💰 Cash: $1795.25
# 📈 Holdings: {'AAPL': 14, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 32}
# 📉 Total Portfolio Value: $15124.55
# 📊 Step: 732
# 💰 Cash: $947.22
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 32}
# 📉 Total Portfolio Value: $15240.39
# 📊 Step: 733
# 💰 Cash: $2484.42
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 31}
# 📉 Total Portfolio Value: $15211.52
# 📊 Step: 734
# 💰 Cash: $2307.33
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 31}
# 📉 Total Portfolio Value: $15316.36
# 📊 Step: 735
# 💰 Cash: $1264.98
# 📈 Holdings: {'AAPL': 13, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 31}
# 📉 Total Portfolio Value: $15584.48
# 📊 Step: 736
# 💰 Cash: $2583.18
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 31}
# 📉 Total Portfolio Value: $15506.07
# 📊 Step: 737
# 💰 Cash: $2927.75
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 30}
# 📉 Total Portfolio Value: $15659.87
# 📊 Step: 738
# 💰 Cash: $2756.19
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 31}
# 📉 Total Portfolio Value: $15693.16
# 📊 Step: 739
# 💰 Cash: $2847.80
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 31}
# 📉 Total Portfolio Value: $15731.73
# 📊 Step: 740
# 💰 Cash: $2670.76
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 31}
# 📉 Total Portfolio Value: $15483.99
# 📊 Step: 741
# 💰 Cash: $2670.76
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 31}
# 📉 Total Portfolio Value: $15190.92
# 📊 Step: 742
# 💰 Cash: $2749.54
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 31}
# 📉 Total Portfolio Value: $15358.56
# 📊 Step: 743
# 💰 Cash: $2500.75
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 0, 'MSFT': 0, 'TSLA': 32}
# 📉 Total Portfolio Value: $15533.27
# 📊 Step: 744
# 💰 Cash: $1889.34
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 33}
# 📉 Total Portfolio Value: $15397.78
# 📊 Step: 745
# 💰 Cash: $1889.34
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 1, 'TSLA': 33}
# 📉 Total Portfolio Value: $15685.74
# 📊 Step: 746
# 💰 Cash: $707.12
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 1, 'MSFT': 1, 'TSLA': 33}
# 📉 Total Portfolio Value: $15521.58
# 📊 Step: 747
# 💰 Cash: $780.64
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 1, 'MSFT': 2, 'TSLA': 33}
# 📉 Total Portfolio Value: $15192.65
# 📊 Step: 748
# 💰 Cash: $1303.81
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 3, 'TSLA': 34}
# 📉 Total Portfolio Value: $14772.11
# 📊 Step: 749
# 💰 Cash: $1881.43
# 📈 Holdings: {'AAPL': 11, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 33}
# 📉 Total Portfolio Value: $14878.43
# 📊 Step: 750
# 💰 Cash: $1718.40
# 📈 Holdings: {'AAPL': 12, 'GOOGL': 0, 'MSFT': 2, 'TSLA': 33}
# 📉 Total Portfolio Value: $15197.10
#
# ==== 📊 Final Results ====
# 💰 Final Cash: $1718.40
# 📈 Total Portfolio Value: $17213.18
# 💵 Profit/Loss: $7213.18
# 📅 Trading Days Simulated: 750
